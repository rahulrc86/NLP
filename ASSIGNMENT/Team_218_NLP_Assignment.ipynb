# %%
"""
================================================================================
TITLE         : NLP Assignment 1 | 
GROUP NUMBER  : 
GROUP MEMBERS :
S.No.   BITS_ID           NAME--------------------------------------------------
1.      2024ac05382       HAREESH KUMAR K
2.      2024ac05361       RAHUL CHANDRAN
3.      2025aa05099       JAPNEET SINGH
4.      2025AA05970       Sasanka Jandyala
-------------------------------------------------------------
ASSIGNMENT OVERVIEW: 
================================================================================
"""
# Out:
# '\n================================================================================\nTITLE         : NLP Assignment 1 | \nGROUP NUMBER  : \nGROUP MEMBERS :\nS.No.   BITS_ID           NAME--------------------------------------------------\n1.      2024ac05382       HAREESH KUMAR K\n2.      2024ac05361       RAHUL CHANDRAN\n3.                        JAPNEET SINGH\n-------------------------------------------------------------\nASSIGNMENT OVERVIEW: \n================================================================================\n'

# %% [markdown]
# ## Cell 1 - Download and perform EDA on NLTK Brown Dataset
# ### Part 1 - Data Preprocessing and EDA

# %%
# Configure Necessary Imports in accordance to the requirements of the assignment
import nltk
from collections import Counter
import pandas as pd

# %%
# Download the brown corpus if not already downloaded
nltk.download('brown')
# Verify the import and availability of the brown corpus
from nltk.corpus import brown
print("Brown Corpus Categories:", brown.categories())
# Load the tagged sentences from the brown corpus for training and testing
train_data = brown.tagged_sents(categories="government")
test_data = brown.tagged_sents(categories="humor")
# Extract some metrics from the training data
sent_train_data_count = len(train_data)
token_train_data_count = sum(len(sent) for sent in train_data)
print("Number of training sentences:", sent_train_data_count)
print("Number of training tokens:", token_train_data_count)
print("First training sentence:", train_data[0])
print("Token count ", token_train_data_count)

# Extract the tag counts and vocabulary from the training data followed by 
# a data preprocessing step.
tag_counts = Counter()
word_counts = Counter()
vocab = set()
clean_train_data = []
for sent in train_data:
    cleaned_sent = []
    for word, tag in sent:
        cleaned_sent.append((word.lower(), tag))
    clean_train_data.append(cleaned_sent)

for sent in clean_train_data:
    for word, tag in sent:
        tag_counts[tag] += 1
        word_counts[word.lower()] += 1
        vocab.add(word.lower())

print("Tag counts:", tag_counts)
print("Word frequencies:", word_counts)
print("Vocabulary size:", len(vocab))
print("Vocabulary:", sorted(vocab))
# Out:
# Brown Corpus Categories: ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# Number of training sentences: 3032
# Number of training tokens: 70117
# First training sentence: [('The', 'AT'), ('Office', 'NN-TL'), ('of', 'IN-TL'), ('Business', 'NN-TL'), ('Economics', 'NN-TL'), ('(', '('), ('OBE', 'NP'), (')', ')'), ('of', 'IN'), ('the', 'AT'), ('U.S.', 'NP-TL'), ('Department', 'NN-TL'), ('of', 'IN-TL'), ('Commerce', 'NN-TL'), ('provides', 'VBZ'), ('basic', 'JJ'), ('measures', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('national', 'JJ'), ('economy', 'NN'), ('and', 'CC'), ('current', 'JJ'), ('analysis', 'NN'), ('of', 'IN'), ('short-run', 'NN'), ('changes', 'NNS'), ('in', 'IN'), ('the', 'AT'), ('economic', 'JJ'), ('situation', 'NN'), ('and', 'CC'), ('business', 'NN'), ('outlook', 'NN'), ('.', '.')]
# Token count  70117
# Tag counts: Counter({'NN': 9877, 'IN': 8596, 'AT': 5716, 'NNS': 4535, 'JJ': 4173, ',': 3381, '.': 2778, 'CC': 2449, 'VBN': 2190, 'NN-TL': 1917, 'VB': 1833, 'RB': 1547, 'CD': 1335, 'NP': 1247, 'CS': 1172, 'VBG': 1013, 'MD': 983, 'TO': 928, 'PP$': 715, 'BEZ': 648, 'AP': 641, 'DT': 611, 'BE': 596, 'JJ-TL': 486, 'NNS-TL': 479, 'NP-TL': 458, 'PPSS': 429, 'VBZ': 421, 'PPS': 421, 'BER': 416, 'VBD': 405, 'IN-TL': 359, 'QL': 348, 'WDT': 317, 'NN-HL': 255, ')': 240, '(': 236, '.-HL': 227, 'HV': 223, 'BEDZ': 223, 'DTS': 217, 'DTI': 211, '*': 207, 'PPO': 203, 'VBN-TL': 186, 'ABN': 175, 'HVZ': 153, 'CD-HL': 153, 'WRB': 143, 'NP-HL': 140, '--': 139, 'WPS': 137, 'RP': 132, 'BEN': 130, 'BED': 126, '``': 125, "''": 122, 'NNS-HL': 119, 'CD-TL': 115, 'AT-TL': 112, 'OD': 107, '(-HL': 106, ')-HL': 105, ':': 101, 'JJR': 101, 'EX': 96, 'CC-TL': 90, 'IN-HL': 88, 'NN$': 77, 'NN$-TL': 76, 'NN-TL-HL': 66, 'ABX': 62, 'JJT': 62, 'JJ-HL': 61, 'NP$': 57, 'NR': 53, 'DO': 51, 'RBR': 49, 'HVD': 46, 'PN': 42, 'AT-HL': 41, 'BEG': 41, 'NIL': 40, 'VBG-HL': 29, 'JJS': 28, ',-HL': 27, 'PPLS': 26, 'CC-HL': 21, 'PPL': 21, 'VB-HL': 19, 'NPS': 19, 'DOD': 18, 'NNS$': 18, 'ABL': 17, 'VBG-TL': 16, 'WPO': 15, 'VBN-HL': 14, 'MD*': 14, 'DOZ': 14, 'WP$': 14, 'MD-HL': 13, 'WQL': 12, 'OD-TL': 12, 'JJ-TL-HL': 10, 'BEM': 10, 'NNS$-TL': 10, 'RBT': 10, 'PP$-TL': 10, 'CD-TL-HL': 9, 'AP-HL': 8, 'WRB-HL': 8, "'": 7, 'TO-HL': 6, 'HVG': 6, 'NP-TL-HL': 6, 'NR-TL': 6, 'PPSS-HL': 5, 'RB-HL': 5, 'FW-NN-TL': 5, 'FW-NNS': 5, 'BE-HL': 5, 'PPS-TL': 4, 'BEZ-TL': 4, 'DTX': 4, 'VB-TL': 4, 'BEZ-HL': 4, 'AT-TL-HL': 4, 'PN$': 4, 'NR$': 4, ':-HL': 4, 'VBN-TL-HL': 4, 'NNS-TL-HL': 4, 'WDT-HL': 4, 'WPS-TL': 3, 'PP$-HL': 3, 'HVN': 3, 'CS-HL': 3, 'IN-TL-HL': 3, 'NN-NC': 3, 'VBN-TL-NC': 3, 'NNS-TL-NC': 3, 'NN-TL-NC': 3, 'QLP': 3, 'FW-IN': 3, 'NP$-TL': 3, 'FW-VB': 3, 'PPS-HL': 3, 'NR-HL': 3, 'DOZ-TL': 2, 'MD-TL': 2, 'VBZ-HL': 2, 'RP-HL': 2, 'FW-JJ-TL': 2, 'FW-IN-TL': 2, 'JJ-NC': 2, 'FW-NN$': 2, 'FW-NN': 2, 'FW-CC': 2, 'FW-RB': 2, 'WPO-TL': 1, '*-HL': 1, 'DTS-HL': 1, 'CD$': 1, 'FW-AT-TL': 1, 'DT-TL': 1, 'VBZ-TL': 1, 'FW-NNS-TL': 1, 'FW-NN$-TL': 1, 'FW-PPO+IN': 1, 'DO*': 1, 'OD-HL': 1, 'PPSS-TL': 1, 'TO-TL': 1, 'FW-DTS': 1, 'PPS+BEZ': 1, 'NNS$-TL-HL': 1})
# Word frequencies: Counter({'the': 4621, ',': 3405, 'of': 3059, '.': 2493, 'and': 1948, 'to': 1859, 'in': 1467, 'a': 971, 'for': 858, 'is': 657, 'be': 603, 'that': 503, 'as': 480, ';': 444, 'this': 440, 'by': 438, 'on': 425, 'are': 416, 'or': 400, 'with': 376, ')': 345, '(': 342, 'it': 324, 'which': 265, 'at': 253, 'from': 249, 'will': 244, 'an': 227, 'have': 223, 'was': 223, 'not': 208, 'other': 200, 'state': 196, 'such': 195, 'year': 183, 'states': 180, 'may': 179, 'their': 178, 'all': 169, 'he': 169, 'our': 164, 'these': 156, 'united': 155, 'has': 153, 'its': 150, 'new': 150, 'any': 149, 'his': 149, 'we': 145, '--': 139, 'been': 130, 'more': 126, 'were': 126, 'development': 125, '``': 125, 'one': 125, "''": 122, 'would': 120, 'they': 119, 'can': 119, 'but': 119, 'made': 118, 'than': 117, 'business': 115, 'government': 115, 'if': 113, 'should': 113, ':': 110, '1': 107, 'years': 106, 'time': 104, 'must': 102, 'under': 101, 'fiscal': 100, 'shall': 99, 'there': 98, 'i': 97, 'general': 94, 'tax': 90, 'also': 89, 'service': 88, 'program': 87, 'many': 86, 'use': 86, '2': 86, 'you': 86, 'act': 85, 'so': 83, 'department': 81, 'during': 80, 'each': 77, 'who': 77, 'about': 77, 'rhode': 76, 'only': 73, 'property': 72, 'two': 71, 'no': 71, 'island': 70, 'some': 68, 'when': 68, 'small': 67, 'national': 66, '1960': 66, 'into': 65, 'mr.': 65, 'board': 64, 'them': 63, 'both': 62, 'those': 62, 'first': 62, '?': 62, 'through': 60, 'local': 58, 'what': 58, 'out': 58, 'per': 56, 'research': 56, 'period': 56, 'american': 56, 'most': 55, 'services': 55, 'over': 55, 'your': 55, 'million': 55, '1961': 55, 'secretary': 55, 'income': 54, 'now': 54, 'military': 53, 'day': 53, 'shelter': 53, 'available': 52, 'upon': 52, 'make': 52, 'public': 52, 'medical': 52, 'production': 51, 'federal': 51, 'interest': 51, 'section': 51, 'provide': 51, 'same': 51, 'world': 51, 'do': 51, 'great': 51, '&': 51, 'peace': 51, 'had': 49, 'brown': 49, 'where': 48, 'president': 48, '3': 47, 'within': 46, 'necessary': 46, 'report': 46, 'between': 46, 'corps': 46, 'stations': 46, 'assistance': 45, 'important': 45, 'work': 45, 'projects': 45, 'policy': 45, 'administration': 44, 'industrial': 44, 'own': 44, 'because': 44, 'du': 44, 'amount': 43, 'planning': 43, 'after': 43, 'total': 43, 'agreement': 43, 'present': 42, 'before': 42, 'being': 42, 'several': 42, 'information': 41, 'part': 41, 'well': 41, 'men': 41, 'system': 40, 'foreign': 40, 'b': 40, 'college': 40, 'used': 40, 'forces': 40, 'problems': 39, 'management': 38, 'equipment': 38, 'basis': 38, 'purposes': 38, 'division': 38, 'country': 38, 'could': 38, 'vehicles': 38, 'however': 37, 'allotment': 37, 'motors': 37, 'faculty': 37, 'programs': 36, 'activities': 36, 'sales': 36, 'above': 36, 'countries': 36, 'since': 36, 'take': 36, 'control': 36, 'required': 35, 'provided': 35, 'number': 35, 'up': 35, 'plan': 35, 'commission': 35, 'student': 35, 'operation': 34, 'congress': 34, 'large': 34, 'cost': 34, '1959': 34, '4': 34, 'problem': 34, 'action': 34, 'economic': 33, 'york': 33, 'funds': 33, 'pay': 33, 'support': 33, 'interference': 33, 'need': 33, 'payment': 33, 'increase': 33, 'machine': 33, 'defense': 33, 'aid': 32, 'market': 32, 'facilities': 32, 'developed': 32, 'members': 32, 'claim': 32, 'see': 32, 'june': 32, 'protection': 32, 'file': 32, 'skywave': 32, 'plant': 31, 'form': 31, 'personal': 31, 'set': 31, 'less': 31, 'even': 31, 'america': 31, 'respect': 31, 'pathology': 31, 'return': 31, 'further': 30, 'addition': 30, 'financial': 30, 'possible': 30, 'india': 30, 'place': 30, 'home': 30, 'people': 30, 'towns': 30, 'pont': 30, 'u.s.': 29, 'payments': 29, 'washington': 29, 'proposed': 29, 'areas': 29, 'much': 29, 'particular': 29, 'personnel': 29, 'my': 29, 'times': 29, 'miles': 29, 'increased': 29, 'due': 29, 'determine': 29, 'court': 29, 'sharpe': 29, 'carleton': 29, 'office': 28, 'commerce': 28, 'products': 28, 'resources': 28, '30': 28, 'conditions': 28, '5': 28, 'c': 28, 'district': 28, 's.': 28, 'another': 28, 's ...
# Vocabulary size: 7361
# Vocabulary: ['!', '$.027', '$.07', '$.076', '$.09', '$0.9', '$1', '$1,000', '$1,276', '$1,390', '$1,500', '$1,961,000', '$1.0', '$1.1', '$1.6', '$1.7', '$1.8', '$1.9', '$10.1', '$10.3', '$10.8', '$100', '$11,900,000', '$12.1', '$14', '$15', '$17,000', '$17,000,000', '$18.9', '$184', '$187', '$19.3', '$2', '$2,323,867', '$2,412,616', '$2,461,000', '$2,557,111', '$2.09', '$2.82', '$20,000', '$200', '$222', '$23,000,000', '$24,926,615', '$3,500,000', '$3,825', '$3.11', '$300', '$31,179,816', '$32,000', '$350,000', '$380', '$395,000', '$4', '$4,000', '$4,000,000', '$4,500,000', '$4,753', '$4.9', '$40,000', '$450', '$450,000', '$5,000', '$5.4', '$50', '$500', '$538', '$56', '$581', '$6', '$600', '$625,561', '$63.8', '$65,000', '$70,000', '$700', '$720', '$75,000,000', '$8,313,514', '$800', '$9.2', '$94', '&', "'", "''", "'30s", '(', ')', '**yl', ',', '-', '--', '.', '0.001', '0.1', '0.1-mv./m.', '0.10', '0.5-mv./m.', '1', '1,000', '1,418,000', '1-a', '1-o', '1.00', '1.5', '1.8', '1/3', '10', '10,000', '10,500', '10,517', '10-gallon', '10-year', '10.4', '100', '100%', '1001', '104', '1040', '1040a', '105,000', '106,500', '11', '11%', '11,000', '113', '114', '1184', '11th', '12', '123', '124', '125', '125th', '126', '12a', '13', '13,200', '130', '1310', '135', '139', '14', '14-1/2', '140', '143', '144', '1450', '15', '15%', '15-', '15.0', '15.4', '15.5', '150-milliampere', '154', '1550', '1581', '15th', '16', '16,000', '16.7', '1600', '161', '162,400', '164', '1665', '1665.32', '1667.36', '1680', '17', '1707', '171', '175,000', '1776', '17th', '18', '1810', '1819', '1830', '1831', '1833', '1838', "1840's", '1848', '185', "1850's", '1853', '1855', '1858', '185th', '186', '1861', '1868', '1876', '188', '1892', '1899', '19', '1907', '1910', '1913', '1917', '1920', "1920's", '1920s', '1922', '1923', '1933', '1935', '1936', '1938', '1938-1939', '1938-39', '1940', '1942', '1943', '1946', '1947', '1948', '1949', '1950', "1950's", '1950-1953', '1951', '1951-1956', '1952', '1952-1958', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1959-1960', '1959-60', '1960', "1960's", '1960-1961', '1961', '1962', '1963', '1963-1972', '1964', '1965', '1967', '1972', '1:00', '2', '2,489,000', '2.1', '2.1.6', '2.16', '20', '20%', '20-to-1', '200', '2000', '20th', '21', '21-cm', '21st', '22', '22,000', '22nd', '23', '236', '239', '23d', '23rd', '24', '24,400', '24th', '25', '25%', '25-liter', '25.1%', '250', '250,000', '254', '26', '26,500', '268,900', '2688', '269', '27', '270,000', '28', '29', '29th', '2d', '2nd', '3', '3,500', '3.190', '3.3', '3.5', '30', '30%', '30,000', '300', '300,000', '31', '31st', '32', '327', '328', '33', '33-1/3%', '332', '334', '346', '348', '35', '35%', '350,000', '353', '354', '36', '36-a', '360,000', '361', '362', '365', '37', '37,470', '375', '379,900', '38', '385', '389', '39', '39,000', '392', '4', '4%', '4,427', '4-cell', '4-d', '4-inch', '4.2', '4.21', '40', '40%', '40,000', '40,000,000', '400,000', '400-401', '407', '412', '412-413', '42', '430,000', '431', '44', '44,000', '442', '45', '45%', '452', '462', '47', '47.6', '480', '4th', '5', '5,000', '5-1/2', '5-6', '5-day', '5-percent', '5.4865771', '5.6', '5.7', '5.8', '50', '50%', '50-50', '50-percent', '525', '54', '54,320', '540', '541', '542,250', '55', '56,000', '565', '589', '5th', '6', '6%', '6(j)', '6,000', '6,768', '6-1/2', '6-inch', '6-year', '6.2', '6.3', '60', '60%', "60's", '60-66', '60-80', '600', '601', '603', '604,622', '605', '606', '607', '607-608', '61', '613', '619,000', '62', '62-63', '63', '63,000,000', '63-64', '635', '63d', '64-66', '64-page', '642', '643', '65', '66', '66th', '6th', '7', '7%', '7,000', '7,500', '7,827', '70', '70%', '70,000', '701', '72', '73', '75', '75%', '76', '762', '78th', '79,400', '795,586', '7th', '8', '8,000', '8-b-2', '8-inch', '80', '80,000', '81,000', '817', '82', '821,220', '825,000', '83rd', '870,000', '885', '899', '8th', '9', '9.4', '90', '91', '92.5', '954', '97', ':', ';', '?', '[', ']', '``', 'a', "a's" ...
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\rahul\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
#plot POS tag distribution of the top 20 most common tags
top_tags = tag_counts.most_common(20)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.bar([tag for tag, freq in top_tags], [freq for tag, freq in top_tags])
plt.xlabel("POS Tags")
plt.ylabel("Frequency")
plt.title("Distribution of POS Tags")
plt.xticks(rotation=45)
plt.show()

# %%
# Get Frequency of words less than or equal to 2
low_freq_words = {word: freq for word, freq in word_counts.items() if freq <= 2}
print("Words with frequency <= 2:", low_freq_words)
# replace low frequency words in the training data with <UNK>
train_data_unk = []

for sent in clean_train_data:
    new_sent = [(word if word.lower() not in low_freq_words else "<UNK>", tag) for word, tag in sent]
    train_data_unk.append(new_sent)
# Pad the sentences in the training data with <START> and <END> tokens
train_data_padded = []
for sent in train_data_unk:
    new_sent = [("<START>", "<START>")] + sent + [("<END>", "<END>")]
    train_data_padded.append(new_sent)
print("Sample padded sentence:", train_data_padded[0])
print("Length of padded training data:", len(train_data_padded[0]))
# Out:
# Words with frequency <= 2: {'obe': 1, 'short-run': 2, 'develops': 1, 'analyzes': 1, 'indicators': 1, 'presenting': 2, 'economists': 2, 'periodical': 2, 'statistical': 2, 'supplements': 1, 'dealt': 2, 'managers': 1, 'enterprises': 2, 'know-how': 1, 'cosponsors': 1, "sba's": 2, 'personalized': 1, 'one-day': 1, 'streamlined': 1, 'chambers': 2, 'semi-processed': 1, 'adaptable': 1, 'exploitation': 1, 'arise': 2, 'undertook': 1, 'urgently': 2, 'locate': 2, 'competitively': 1, 'reviewing': 1, 'identifying': 2, 'publicized': 1, 'releases': 1, 'flyers': 1, 'principally': 2, 'contacted': 1, '8-b-2': 1, 'authorizes': 1, 'voluntarily': 1, 'register': 1, 'avail': 1, "registrants'": 1, 'budgetary': 2, 'atlanta': 2, 'ga.': 2, 'mass.': 2, 'dallas': 2, 'tex.': 2, 'denver': 2, 'colo.': 2, 'detroit': 2, 'mich.': 2, 'mo.': 2, 'minneapolis': 2, 'minn.': 2, 'n.y.': 2, 'pa.': 2, 'va.': 2, 'san': 2, 'francisco': 2, 'seattle': 2, 'wash.': 2, 'topics': 2, 'selling': 1, 'lending': 2, 'pools': 1, 'wholesalers': 1, 'retailers': 2, 'establishments': 1, 'unavailable': 1, 'defined': 2, 'independently': 1, 'stipulate': 1, 'secured': 2, 'chance': 1, 'repay': 2, 'anticipated': 2, 'borrowed': 2, 'borrower': 1, '$350,000': 1, 'repayable': 1, 'installments': 2, '5-1/2': 1, 'annum': 1, 'pooling': 1, 'supervises': 1, 'coordinates': 1, 'composed': 2, 'long-': 1, 'encourages': 1, 'provdied': 1, 'outlined': 2, "farmers'": 2, 'borrow': 2, 'furnishing': 1, '44': 2, '36-a': 1, 'ome': 2, 'explore': 2, '32': 1, 'mineral': 1, 'applicants': 1, 'ordinarily': 1, 'sole': 2, 'expense': 2, 'explored': 2, 'one-half': 2, 'progresses': 1, 'pays': 2, 'owns': 2, 'repaid': 2, 'obligation': 2, '5-percent': 1, 'certifies': 1, 'nonexistent': 1, 'pakistan': 1, 'so-called': 1, 'lists': 1, 'ministries': 1, 'rarely': 2, 'imposed': 2, 'administer': 1, 'definition': 1, 'conditional': 2, 'consistency': 2, 'adapted': 1, 'assembling': 2, 'surveying': 1, 'sectors': 2, 'designing': 2, 'mechanisms': 1, 'inflation': 2, 'implementation': 2, 'applying': 1, 'stages': 2, 'recipient': 2, 'frustration': 1, 'primitive': 1, 'acceptable': 1, 'plain': 1, 'spectrum': 1, 'relied': 2, 'priorities': 2, 'depart': 1, 'granting': 2, 'stressing': 1, 'vitally': 1, 'thrust': 1, 'marginal': 1, 'margin': 2, 'marshall': 2, 'decisive': 1, 'complement': 2, 'incentives': 2, 'remake': 1, 'image': 1, 'recipients': 2, 'devise': 2, 'sovereignty': 1, 'defects': 1, 'factories': 2, 'genuinely': 1, 'blunt': 2, 'suggesting': 2, 'occur': 1, 'mobilizing': 1, 'equitably': 1, 'monetary': 2, 'regulatory': 2, 'attract': 2, 'managerial': 1, 'luxury': 1, 'foreseeing': 1, 'balance-of-payments': 1, 'infant': 2, 'spur': 1, 'exports': 2, 'nationals': 2, 'tapping': 1, 'energies': 2, 'longrun': 1, 'stability': 1, 'favoritism': 2, 'mores': 1, 'officialdom': 1, 'integral': 2, 'routine': 2, 'unwarranted': 1, 'unfriendly': 2, 'dishonesty': 1, 'tolerance': 1, 'diversion': 1, 'generates': 1, 'anti-american': 1, 'sentiment': 2, 'peculiarly': 1, 'damaging': 1, 'successes': 2, 'winning': 1, 'traced': 1, 'identification': 2, 'correct': 1, 'regimes': 2, 'pro-western': 1, 'honest': 2, 'politically': 2, 'uncomfortable': 1, 'responding': 2, 'tailored': 1, 'withhold': 1, 'willing': 2, 'skillful': 1, 'diplomacy': 2, 'encouragement': 2, 'press': 1, 'reform': 1, 'monolithic': 1, 'inadequacy': 1, 'deem': 1, 'wise': 2, 'ultimately': 2, 'termination': 1, 'focusing': 1, 'stretching': 2, 'nearing': 2, 'self-sufficiency': 1, 'concentrated': 2, 'launch': 1, 'government-to-government': 1, 'visible': 1, 'tunnel': 1, 'gradually': 1, 'peoples': 2, 'underdeveloped': 1, 'meantime': 1, 'sixties': 1, 'push': 1, 'self-sustaining': 1, 'barely': 1, 'threshold': 1, 'modernity': 1, 'launching': 1, 'slow': 2, 'developmental': 1, 'alter': 2, 'slow-acting': 1, 'laos': 2, 'dealing': 2, 'erupted': 1, 'call': 2, 'lengthy': 1, 'dams': 1, 'river': 1, 'schemes': 1, 'networks': 1, 'twofold': 1, 'threefold': 1, 'multi-year': 1, 'importantly': 2, 'tentatively': 1, 'sure': 2, 'interdependent': 1, 'se ...
# Sample padded sentence: [('<START>', '<START>'), ('the', 'AT'), ('office', 'NN-TL'), ('of', 'IN-TL'), ('business', 'NN-TL'), ('economics', 'NN-TL'), ('(', '('), ('<UNK>', 'NP'), (')', ')'), ('of', 'IN'), ('the', 'AT'), ('u.s.', 'NP-TL'), ('department', 'NN-TL'), ('of', 'IN-TL'), ('commerce', 'NN-TL'), ('provides', 'VBZ'), ('basic', 'JJ'), ('measures', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('national', 'JJ'), ('economy', 'NN'), ('and', 'CC'), ('current', 'JJ'), ('analysis', 'NN'), ('of', 'IN'), ('<UNK>', 'NN'), ('changes', 'NNS'), ('in', 'IN'), ('the', 'AT'), ('economic', 'JJ'), ('situation', 'NN'), ('and', 'CC'), ('business', 'NN'), ('outlook', 'NN'), ('.', '.'), ('<END>', '<END>')]
# Length of padded training data: 37

# %% [markdown]
# ## Cell 7 - Model Architecture & Parameter Estimation
# ### Cell 7 - Model Architecture & Parameter Estimation

# %%
# Loop through the training data set and extract the 
#   1. Tag -> Tag transition counts
#   2. Word -> Tag emission counts

unk_prob = 1e-6
transition_counts = Counter()
emission_counts = Counter()
for sent in train_data_padded:
    for i in range(1, len(sent)):
        prev_tag = sent[i-1][1]
        curr_tag = sent[i][1]
        transition_counts[(prev_tag, curr_tag)] += 1
        emission_counts[(sent[i][0].lower(), curr_tag)] += 1
#Update tag_counts to include the <START> and <END> tags
tag_counts["<START>"] = len(train_data_padded)
tag_counts["<END>"] = len(train_data_padded)

print("Tag Transition Counts:", transition_counts)
print("Word-Tag Emission Counts:", emission_counts)
# Out:
# Tag Transition Counts: Counter({('NN', 'IN'): 3150, ('IN', 'AT'): 2887, ('AT', 'NN'): 2560, ('.', '<END>'): 2531, ('JJ', 'NN'): 1883, ('NNS', 'IN'): 1430, ('IN', 'NN'): 1430, ('NN', 'NN'): 1055, ('AT', 'JJ'): 1010, ('NN', ','): 997, ('JJ', 'NNS'): 991, ('NN', '.'): 938, ('VBN', 'IN'): 896, ('TO', 'VB'): 783, ('IN', 'JJ'): 775, ('NN', 'NNS'): 683, ('NN', 'CC'): 624, (',', 'CC'): 575, ('NNS', ','): 568, ('<START>', 'AT'): 558, ('NNS', '.'): 548, ('AT', 'NN-TL'): 521, ('IN', 'NNS'): 484, ('CC', 'NN'): 437, ('MD', 'BE'): 403, ('AT', 'NNS'): 401, ('VB', 'AT'): 397, ('IN', 'CD'): 384, ('BE', 'VBN'): 376, ('MD', 'VB'): 365, ('<START>', 'IN'): 364, ('NNS', 'CC'): 362, ('IN', 'PP$'): 349, (',', 'IN'): 342, ('IN', 'VBG'): 334, (',', 'AT'): 331, ('IN', 'DT'): 328, ('DT', 'NN'): 325, ('CS', 'AT'): 318, ('NN-TL', 'IN-TL'): 301, ('PP$', 'NN'): 292, ('IN', 'NP'): 288, ('NN-TL', 'NN-TL'): 286, ('JJ', 'IN'): 283, ('RB', 'IN'): 282, ('NN-TL', ','): 275, ('CD', 'NNS'): 266, ('VB', 'IN'): 261, ('NN', 'MD'): 259, ('JJ-TL', 'NN-TL'): 258, ('NP', ','): 257, ('NN', 'BEZ'): 250, ('.', '.'): 247, ('NP', 'NP'): 246, ('CC', 'JJ'): 245, ('CD', ','): 239, ('JJ', 'JJ'): 238, ('CC', 'NNS'): 219, ('.-HL', '<END>'): 218, (',', 'NP'): 213, ('CC', 'AT'): 210, ('RB', 'VBN'): 206, ('VBG', 'NN'): 205, ('AP', 'NNS'): 203, ('RB', ','): 194, ('CC', 'IN'): 191, (',', 'NN'): 187, ('NN', 'TO'): 185, ('NN', 'CS'): 183, ('QL', 'JJ'): 182, ('BEZ', 'VBN'): 180, ('JJ', 'CC'): 178, ('NNS', 'BER'): 176, ('PP$', 'JJ'): 172, ('VBG', 'AT'): 164, ('VBN-TL', 'NNS-TL'): 164, ('NN-TL', '.'): 163, (',', 'CS'): 162, ('AT', 'JJ-TL'): 160, ('NP-TL', 'NN-TL'): 159, ('VBN', 'TO'): 157, ('IN', 'AP'): 155, (',', 'JJ'): 154, ('NN', 'VBN'): 154, ('<START>', 'PPS'): 151, ('NNS', 'VBN'): 150, ('PP$', 'NNS'): 148, ('AT', 'AP'): 148, ('VBN', 'NN'): 145, ('NP', 'CD'): 144, ('BER', 'VBN'): 144, ('CD', 'IN'): 144, ('NNS', 'MD'): 144, ('NN-TL', 'IN'): 143, ('<START>', 'NN'): 140, ('VB', 'JJ'): 136, ('CD', 'NN'): 136, ('<START>', 'CS'): 136, ('VBG', 'IN'): 135, (',', 'RB'): 135, ('CD', '.'): 135, ('JJ', ','): 134, ('VBG', 'NNS'): 131, ('<START>', 'RB'): 131, ('VB', 'NN'): 129, ('VBN', '.'): 128, ('AP', 'NN'): 127, ('DTS', 'NNS'): 127, ('NN', 'RB'): 127, (',', 'NNS'): 126, ('PPSS', 'MD'): 120, ('PPSS', 'VB'): 120, ('VBN', ','): 117, ('CS', 'PPSS'): 114, ('<START>', 'DT'): 113, ('BEZ', 'AT'): 111, ('NN', 'VBZ'): 110, ('IN', 'DTS'): 110, ('VBN', 'NNS'): 109, ('NNS', 'TO'): 109, (',', 'CD'): 109, ('IN', 'DTI'): 109, ('TO', 'BE'): 107, ('NN', 'CD'): 107, ('CD-HL', '.-HL'): 107, ('VBN', 'RB'): 106, ('<START>', 'CC'): 105, ('PPS', 'BEZ'): 105, ('RB', '.'): 104, ('BEDZ', 'VBN'): 104, ('CC', 'VBN'): 103, ('NP', '.'): 102, ('IN', 'NN-TL'): 102, ('AT', 'VBN-TL'): 101, ('NNS-TL', ','): 100, ('<START>', 'PPSS'): 100, ('DTI', 'NN'): 99, ('IN', 'WDT'): 98, (')-HL', '<END>'): 98, ('IN-TL', 'NN-TL'): 97, ('AT', 'VBG'): 95, ('VB', 'PP$'): 95, ('NNS', 'RB'): 94, ('IN', 'PPO'): 93, ('PPS', 'MD'): 93, ('CC', 'RB'): 90, ('<START>', 'NP'): 88, ('NNS', 'VB'): 88, ('VB', 'NNS'): 88, ('NN', 'BEDZ'): 88, ('<START>', 'JJ'): 87, ('BE', 'JJ'): 87, ('VBN', 'CC'): 87, ('VBZ', 'IN'): 87, ('IN-TL', 'NP-TL'): 87, ('NN', 'JJ'): 86, ('VBN', 'CS'): 86, ('NN-TL', 'CD-TL'): 85, ('VBD', 'AT'): 84, ('(', 'NP'): 83, ('<START>', '(-HL'): 83, ('NP', ')'): 82, ('VBZ', 'AT'): 82, ('JJ', 'TO'): 82, ('CC', 'VB'): 82, ('AT', 'VBN'): 82, (',', 'PPSS'): 82, ('JJ', 'CS'): 81, ('DT', 'NN-TL'): 81, ('NN', 'VBD'): 81, ('BEZ', 'JJ'): 80, ('NN-TL', 'NNS-TL'): 80, (',', 'VBG'): 80, ('CS', 'PPS'): 80, ('<START>', 'NN-HL'): 79, ('IN', 'ABN'): 79, ('<START>', 'NNS'): 79, ('RB', 'CS'): 77, ('NNS', 'CS'): 77, ('VBD', 'IN'): 77, ('RB', 'VB'): 76, ('AT', 'NP'): 76, ('IN-TL', 'AT-TL'): 76, ('CC', 'AP'): 75, ('VBN', 'JJ'): 75, ('BED', 'VBN'): 75, ('AP', 'IN'): 74, ('JJ', '.'): 74, ('VBG', 'JJ'): 74, ('IN', 'IN'): 73, ('CC', 'CD'): 73, ('CC', 'NP'): 72, ('AT', 'CD'): 72, ('QL', 'RB'): 72, ('NN-TL', 'CC'): 71, ('BER', 'JJ'): 70, ('NN', 'VBG'): 70, ('BEN', 'VBN'): 70, ('AT ...
# Word-Tag Emission Counts: Counter({('the', 'AT'): 4484, (',', ','): 3378, ('<end>', '<END>'): 3032, ('of', 'IN'): 2695, ('.', '.'): 2284, ('and', 'CC'): 1891, ('in', 'IN'): 1443, ('<unk>', 'NN'): 1285, ('to', 'TO'): 928, ('a', 'AT'): 919, ('to', 'IN'): 914, ('<unk>', 'NNS'): 830, ('for', 'IN'): 811, ('<unk>', 'JJ'): 765, ('is', 'BEZ'): 648, ('be', 'BE'): 596, (';', '.'): 444, ('this', 'DT'): 439, ('by', 'IN'): 428, ('are', 'BER'): 416, ('<unk>', 'VBN'): 416, ('as', 'CS'): 404, ('on', 'IN'): 399, ('or', 'CC'): 395, ('with', 'IN'): 376, ('that', 'CS'): 363, ('<unk>', 'VB'): 354, ('<unk>', 'VBG'): 333, ('of', 'IN-TL'): 320, ('<unk>', 'CD'): 273, ('<unk>', 'NP'): 266, ('which', 'WDT'): 264, ('at', 'IN'): 253, ('it', 'PPS'): 252, ('from', 'IN'): 244, (')', ')'): 240, ('will', 'MD'): 237, ('(', '('): 236, ('an', 'AT'): 224, ('have', 'HV'): 223, ('was', 'BEDZ'): 223, ('<unk>', 'RB'): 221, ('.', '.-HL'): 209, ('not', '*'): 207, ('other', 'AP'): 196, ('their', 'PP$'): 178, ('year', 'NN'): 177, ('such', 'JJ'): 175, ('<unk>', 'VBZ'): 173, ('he', 'PPS'): 168, ('all', 'ABN'): 166, ('states', 'NNS-TL'): 157, ('these', 'DTS'): 156, ('our', 'PP$'): 156, ('has', 'HVZ'): 153, ('may', 'MD'): 152, ('united', 'VBN-TL'): 150, ('his', 'PP$'): 149, ('its', 'PP$'): 148, ('any', 'DTI'): 148, ('we', 'PPSS'): 143, ('--', '--'): 139, ('been', 'BEN'): 130, ('were', 'BED'): 126, ('``', '``'): 125, ("''", "''"): 122, ('<unk>', 'NN-TL'): 120, ('they', 'PPSS'): 118, ('<unk>', 'VBD'): 118, ('would', 'MD'): 118, ('can', 'MD'): 115, ('one', 'CD'): 115, ('if', 'CS'): 112, ('but', 'CC'): 111, ('should', 'MD'): 111, ('development', 'NN'): 109, ('the', 'AT-TL'): 106, ('(', '(-HL'): 106, (')', ')-HL'): 105, ('years', 'NNS'): 104, ('made', 'VBN'): 103, ('new', 'JJ'): 102, ('time', 'NN'): 102, ('under', 'IN'): 101, (':', ':'): 101, ('must', 'MD'): 99, ('shall', 'MD'): 99, ('state', 'NN'): 99, ('there', 'EX'): 96, ('fiscal', 'JJ'): 95, ('i', 'PPSS'): 95, ('business', 'NN'): 94, ('state', 'NN-TL'): 89, ('also', 'RB'): 87, ('many', 'AP'): 85, ('during', 'IN'): 79, ('<unk>', 'NP-TL'): 79, ('program', 'NN'): 78, ('tax', 'NN'): 78, ('each', 'DT'): 77, ('who', 'WPS'): 77, ('government', 'NN-TL'): 76, ('department', 'NN-TL'): 73, ('you', 'PPSS'): 73, ('two', 'CD'): 71, ('rhode', 'NP-TL'): 71, ('than', 'CS'): 69, ('act', 'NN-TL'): 68, ('property', 'NN'): 67, ('1', 'CD'): 67, ('no', 'AT'): 67, ('that', 'DT'): 67, ('service', 'NN'): 66, ('it', 'PPO'): 66, ('1960', 'CD'): 66, ('when', 'WRB'): 65, ('use', 'NN'): 65, ('island', 'NN-TL'): 65, ('more', 'AP'): 64, ('some', 'DTI'): 63, ('them', 'PPO'): 63, ('into', 'IN'): 63, ('both', 'ABX'): 62, ('only', 'RB'): 62, ('as', 'QL'): 62, ('those', 'DTS'): 61, ('through', 'IN'): 59, ('that', 'WPS'): 59, ('local', 'JJ'): 57, ('mr.', 'NP'): 57, ('per', 'IN'): 56, ('more', 'QL'): 56, ('period', 'NN'): 56, ('out', 'RP'): 55, ('million', 'CD'): 55, ('secretary', 'NN-TL'): 55, ('now', 'RB'): 54, ('1961', 'CD'): 54, ('available', 'JJ'): 52, ('make', 'VB'): 52, ('your', 'PP$'): 52, ('small', 'JJ'): 51, ('provide', 'VB'): 51, ('do', 'DO'): 51, ('&', 'CC-TL'): 51, ('production', 'NN'): 50, ('what', 'WDT'): 50, ('same', 'AP'): 50, ('services', 'NNS'): 49, ('first', 'OD'): 49, ('shelter', 'NN'): 49, ('interest', 'NN'): 48, ('than', 'IN'): 48, ('great', 'JJ'): 47, ('within', 'IN'): 46, ('where', 'WRB'): 46, ('new', 'JJ-TL'): 46, ('necessary', 'JJ'): 46, ('had', 'HVD'): 46, ('between', 'IN'): 46, ('stations', 'NNS'): 46, ('important', 'JJ'): 45, ('national', 'JJ-TL'): 45, ('upon', 'IN'): 44, ('over', 'IN'): 44, ('military', 'JJ'): 44, ('world', 'NN'): 44, ('?', '.'): 44, ('general', 'NN-TL'): 44, ('du', 'NP'): 44, ('projects', 'NNS'): 43, ('about', 'RB'): 43, ('federal', 'JJ-TL'): 42, ('several', 'AP'): 42, ('policy', 'NN'): 42, ('research', 'NN'): 41, ('assistance', 'NN'): 41, ('of', 'IN-HL'): 41, ('amount', 'NN'): 41, ('own', 'JJ'): 41, ('being', 'BEG'): 41, ('income', 'NN'): 40, ('information', 'NN'): 40, ('part', 'NN'): 40, ('well', 'RB'): 40, ('americ ...

# %%
#Do a sanity check to check if the transition counts exceed the previous tag counts
# DEBUG CODE . PLEASE DO NOT USE THIS IF NOT REQUIRD
# for (prev_tag, curr_tag), count in transition_counts.items():
#     if count > tag_counts[prev_tag]:
#         print(f"Sanity Check Failed: Transition count from {prev_tag} to {curr_tag} exceeds total count of {prev_tag}")
#     else:
#         print(f"Sanity Check Passed: Transition count from {prev_tag} to {curr_tag} is within expected limits.")

# %%
# Convert the transition and emission counts to probabilities (MLE)
# OOV FIX: <UNK> is treated as a normal word and gets a proper per-tag MLE
# emission distribution, learned from the low-frequency words that were
# mapped to <UNK> during counting. This gives unknown words a meaningful
# tag distribution (e.g. unknowns are far more likely to be nouns) instead
# of a flat constant that carries no signal for the Viterbi decoder.
from collections import defaultdict

# Transition probabilities: P(curr | prev) = C(prev, curr) / C(prev)
trans_totals = defaultdict(int)
for (prev_tag, curr_tag), count in transition_counts.items():
    trans_totals[prev_tag] += count

transition_probs = {}
for (prev_tag, curr_tag), count in transition_counts.items():
    transition_probs[(prev_tag, curr_tag)] = count / trans_totals[prev_tag]

# Emission probabilities: P(word | tag) = C(word, tag) / C(tag)
# <UNK> is included here naturally because low-freq words were already
# replaced by <UNK> before counting.
emis_totals = defaultdict(int)
for (word, tag), count in emission_counts.items():
    emis_totals[tag] += count

emission_probs = {}
for (word, tag), count in emission_counts.items():
    emission_probs[(word, tag)] = count / emis_totals[tag]

print("Tag Transition Probabilities (sample):",
      dict(list(transition_probs.items())[:5]))
print("Word-Tag Emission Probabilities (sample):",
      dict(list(emission_probs.items())[:5]))
print("\n<UNK> emission distribution across tags (top 8):")
unk_dist = sorted(((t, p) for (w, t), p in emission_probs.items() if w == "<UNK>"),
                  key=lambda x: -x[1])[:8]
for t, p in unk_dist:
    print(f"  P(<UNK> | {t}) = {p:.4f}")
# Out:
# Tag Transition Probabilities (sample): {('<START>', 'AT'): 0.18403693931398418, ('AT', 'NN-TL'): 0.09114765570328902, ('NN-TL', 'IN-TL'): 0.15701617110067814, ('IN-TL', 'NN-TL'): 0.27019498607242337, ('NN-TL', 'NN-TL'): 0.14919144496609285}
# Word-Tag Emission Probabilities (sample): {('the', 'AT'): 0.7844646606018194, ('office', 'NN-TL'): 0.009389671361502348, ('of', 'IN-TL'): 0.8913649025069638, ('business', 'NN-TL'): 0.008868022952529996, ('economics', 'NN-TL'): 0.0010432968179447052}
#
# <UNK> emission distribution across tags (top 8):

# %%
transition_df = pd.DataFrame([(k[0], k[1], count) for k, count in transition_counts.items()],\
                             columns=["Prev Tag", "Curr Tag", "Count"])
top20_transitions = transition_df.nlargest(20, "Count")
emission_df = pd.DataFrame([(k[0], k[1], count) for k, count in emission_counts.items()],\
                             columns=["Word", "Tag", "Count"])
top20_emissions = emission_df.nlargest(20, "Count")

# %%
# Code to analyze the tags associated with the words "(" and ")" in the training data
# USE ONLY FOR DEBUGGING PURPOSES. DO NOT USE THIS CODE IN THE FINAL SUBMISSION AS IT IS 
# NOT PART OF THE ASSIGNMENT REQUIREMENTS.
# words_for_tag = set()

# for (word, tag), count in emission_counts.items():
#     if tag == "()":
#         words_for_tag.add(word)

# print(words_for_tag)
# all_tags = set(tag for (_, tag) in emission_counts.keys())

# # for tag in sorted(all_tags):
# #     if "(" in str(tag) or ")" in str(tag):
# #         print(repr(tag))
# for (word, tag), count in emission_counts.items():
#     if tag == "(":
#         print(repr(word), count)

# %%
#Plot the transition counts of the top 20 most common tag transitions as a heatmap
import seaborn as sns
import matplotlib.pyplot as plt
heatmap_df_transitions = top20_transitions.pivot(index="Prev Tag", columns="Curr Tag", values="Count").fillna(0)
plt.figure(figsize=(12,8))
sns.heatmap(heatmap_df_transitions, annot=True, cmap="copper")
plt.title("Top 20 Tag Transitions")
plt.xlabel("Next Tag")
plt.ylabel("Current Tag")
plt.show()

# %%
#Plot the emission counts of the top 20 most common tag transitions as a heatmap
import seaborn as sns
import matplotlib.pyplot as plt
heatmap_df_emissions = top20_emissions.pivot(index="Word", columns="Tag", values="Count").fillna(0)
plt.figure(figsize=(12,8))
sns.heatmap(heatmap_df_emissions, annot=True, cmap="copper")
plt.title("Top 20 Emissions")
plt.xlabel("Tag")
plt.ylabel("Word")
plt.show()

# %% [markdown]
# ## Cell 15 - Preprocess Test Data Set to run the Viterbi Algorithm

# %%
# PREPROCESS THE TEST DATA IN THE SAME WAY AS THE TRAINING DATA
# 1. Lowercase every word.
# 2. Map any word NOT in the training vocabulary to <UNK>.
#    (Note: we use the *training* vocabulary, not the train low_freq set,
#     because the model has only ever seen <UNK> emissions for words it did
#     not learn during training. Any genuinely unseen test word is OOV.)
# 3. Pad sentences with <START> and <END>.

# Build the set of words the model actually learned emissions for.
train_vocab = set(word for (word, tag) in emission_counts.keys())

def preprocess_word_for_inference(word):
    w = word.lower()
    return w if w in train_vocab else "<UNK>"

test_data_unk = []
for sent in test_data:
    new_sent = [(preprocess_word_for_inference(word), tag) for word, tag in sent]
    test_data_unk.append(new_sent)

test_data_padded = []
for sent in test_data_unk:
    new_sent = [("<START>", "<START>")] + sent + [("<END>", "<END>")]
    test_data_padded.append(new_sent)

print("Sample padded test sentence:", test_data_padded[0])
print("Number of test sentences:", len(test_data_padded))
# Out:
# Sample padded test sentence: [('<START>', '<START>'), ('it', 'PPS'), ('was', 'BEDZ'), ('among', 'IN'), ('these', 'DTS'), ('that', 'CS'), ('<UNK>', 'NP'), ('<UNK>', 'VBD'), ('a', 'AT'), ('<UNK>', 'NN'), ('of', 'IN'), ('<UNK>', 'NP'), ('<UNK>', '.'), ('<UNK>', '.'), ('<END>', '<END>')]
# Number of test sentences: 1053

# %% [markdown]
# ## Cell 17 - Apply the Viterbi Algorithm to predict the POS tags for the test data sentences

# %%
# ============================================================================
# VITERBI ALGORITHM (from scratch)
# ----------------------------------------------------------------------------
# Dynamic-programming decoder that returns the most likely sequence of POS
# tags for a sequence of words. We work in LOG space to avoid numerical
# underflow on long sentences (products of many small probabilities).
# ============================================================================
import math

# Hidden states = all real POS tags (exclude the structural <START>/<END>).
states = [t for t in tag_counts if t not in ("<START>", "<END>")]

#DEBUG PRINT CODE DELETE AFTER USE
#print ("States:", states[:10], "...")
#DEBUG END

LOG_ZERO = -1e18          # stand-in for log(0)
FLOOR    = 1e-12          # smoothing floor inside the log

def log(p):
    return math.log(p) if p > 0 else LOG_ZERO

def get_transition_prob(prev_tag, curr_tag):
    return transition_probs.get((prev_tag, curr_tag), FLOOR)

def get_emission_prob(word, tag):
    """OOV-aware emission lookup. Unknown words fall back to the learned
    <UNK> distribution rather than a flat constant."""
    w = word.lower()
    if (w, tag) in emission_probs:
        return emission_probs[(w, tag)]
    if ("<UNK>", tag) in emission_probs:
        return emission_probs[("<UNK>", tag)]
    return FLOOR

def viterbi_decode(words):
    """Input: list of raw words. Output: list of predicted POS tags."""
    # Map words into the model's vocabulary exactly as in training.
    obs = [w.lower() for w in words]
    obs = [w if w in train_vocab else "<UNK>" for w in obs]
    #DEBUG PRINT CODE DELETE AFTER USE
    print("Observations after preprocessing:", obs)
    #END DEBUG
    n = len(obs)
    if n == 0:
        return []

    viterbi    = [{} for _ in range(n)]
    backpointer = [{} for _ in range(n)]

    # Initialisation: transition from <START> into each tag * emission.
    for s in states:
        viterbi[0][s] = log(get_transition_prob("<START>", s)) + log(get_emission_prob(obs[0], s))
        backpointer[0][s] = None
        # #DEBUG PRINT CODE DELETE AFTER USE
        # print(f"Initial score for {s}: {viterbi[0][s]}")
        # #END DEBUG

    # Recursion.
    for i in range(1, n):
        for s in states:
            
            em = log(get_emission_prob(obs[i], s))
            # #DEBUG PRINT CODE DELETE AFTER USE
            # print(f"Emission score for {s} at position {i}: {em}")
            # #END DEBUG
            best_score, best_prev = LOG_ZERO, None
            for ps in states:       
                score = viterbi[i - 1][ps] + log(get_transition_prob(ps, s)) + em
                if score > best_score:
                    best_score, best_prev = score, ps
            viterbi[i][s] = best_score
            backpointer[i][s] = best_prev
            # #DEBUG PRINT CODE DELETE AFTER USE
            # print(f"Score for {s} at position {i}: {viterbi[i][s]}")
            # print(f"Backpointer best_prev for {s} at position {i}: {backpointer[i][s]}")
            # #END DEBUG

    # Termination: best final state, including transition into <END>.
    best_score, best_last = LOG_ZERO, None
    for s in states:
        score = viterbi[n - 1][s] + log(get_transition_prob(s, "<END>"))
        if score > best_score:
            best_score, best_last = score, s

    # Back-trace.
    best_path = [best_last]
   
    for i in range(n - 1, 0, -1):
        best_path.insert(0, backpointer[i][best_path[0]])
    # #DEBUG PRINT CODE DELETE AFTER USE
    # print(f"best_score: {best_score}")
    # print(f"best path: {best_path}")
    # #END DEBUG
    return best_path

# Quick smoke test on the first training sentence.
demo_words = [w for w, t in train_data[0]]
demo_pred  = viterbi_decode(demo_words)
print("Demo sentence:", demo_words[:10], "...")
print("Predicted tags:", demo_pred[:10], "...")
# Out:
# Observations after preprocessing: ['the', 'office', 'of', 'business', 'economics', '(', '<UNK>', ')', 'of', 'the', 'u.s.', 'department', 'of', 'commerce', 'provides', 'basic', 'measures', 'of', 'the', 'national', 'economy', 'and', 'current', 'analysis', 'of', '<UNK>', 'changes', 'in', 'the', 'economic', 'situation', 'and', 'business', 'outlook', '.']
# Demo sentence: ['The', 'Office', 'of', 'Business', 'Economics', '(', 'OBE', ')', 'of', 'the'] ...
# Predicted tags: ['AT', 'NN-TL', 'IN-TL', 'NN-TL', 'NN-TL', '(', 'NP', ')', 'IN', 'AT'] ...

# %% [markdown]
# ## Cell 19 - Inference and Evaluation
# ### Part 3 - Inference and Evaluation
#
# (a) Decode 4 test sentences (2 from the training category, 2 from the test category).
# (b) Identify 3 sentences with at least one misclassified tag and analyse why.
# (c) Overall token-level accuracy + confusion matrix for the top-5 POS tags.

# %%
# 3(a) Sequence Inference: decode 2 sentences from the training (government)
# category and 2 from the test (humor) category. We print word | gold | pred.

def show_prediction(sent, title):
    words = [w for w, t in sent]
    gold  = [t for w, t in sent]
    pred  = viterbi_decode(words)
    print("=" * 70)
    print(title)
    print("=" * 70)
    print(f"{'WORD':<18}{'GOLD':<10}{'PRED':<10}{'OK?'}")
    print("-" * 50)
    for w, g, p in zip(words, gold, pred):
        flag = "" if g == p else "  <-- MISMATCH"
        print(f"{w:<18}{g:<10}{p:<10}{flag}")
    acc = sum(g == p for g, p in zip(gold, pred)) / len(gold)
    print(f"Sentence accuracy: {acc:.2%}\n")

# 2 from training (government)
show_prediction(train_data[5],  "TRAIN SENTENCE #1 (government)")
show_prediction(train_data[12], "TRAIN SENTENCE #2 (government)")
# 2 from test (humor)
show_prediction(test_data[3],   "TEST SENTENCE #1 (humor)")
show_prediction(test_data[8],   "TEST SENTENCE #2 (humor)")
# Out:
# Observations after preprocessing: ['printed', 'material']
# ======================================================================
# TRAIN SENTENCE #1 (government)
# ======================================================================
# WORD              GOLD      PRED      OK?
# --------------------------------------------------
# Printed           VBN-HL    VBN-HL
# material          NN-HL     NN-HL
# Sentence accuracy: 100.00%
#
# Observations after preprocessing: ['these', 'publications', ',', 'written', 'especially', 'for', 'the', '<UNK>', 'or', 'owners', 'of', 'small', 'businesses', ',', 'indirectly', 'aid', 'in', 'community', 'development', 'programs', '.']
# ======================================================================
# TRAIN SENTENCE #2 (government)
# ======================================================================
# WORD              GOLD      PRED      OK?
# --------------------------------------------------
# These             DTS       DTS
# publications      NNS       NNS
# ,                 ,         ,
# written           VBN       VBN
# especially        RB        RB
# for               IN        IN
# the               AT        AT
# managers          NNS       NN          <-- MISMATCH
# or                CC        CC
# owners            NNS       NNS
# of                IN        IN
# small             JJ        JJ
# businesses        NNS       NNS
# ,                 ,         ,
# indirectly        RB        RB
# aid               VB        VB
# in                IN        IN
# community         NN        NN
# development       NN        NN
# programs          NNS       NNS
# .                 .         .
# Sentence accuracy: 95.24%
#
# Observations after preprocessing: ['mills', '<UNK>', '<UNK>', '<UNK>', 'from', 'the', '<UNK>', 'in', 'charge', ',', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'station', 'to', 'report', 'the', '<UNK>', ',', 'and', 'less', 'than', 'five', '<UNK>', 'later', ',', '<UNK>', 'with', 'his', '<UNK>', 'in', 'hand', 'were', 'on', 'the', 'trail', 'of', '<UNK>', '<UNK>', '.']
# ======================================================================
# TEST SENTENCE #1 (humor)
# ======================================================================
# WORD              GOLD      PRED      OK?
# --------------------------------------------------
# Mills             NP        NNS         <-- MISMATCH
# secured           VBD       VBG         <-- MISMATCH
# Barco's           NP$       JJ          <-- MISMATCH
# photograph        NN        NN
# from              IN        IN
# the               AT        AT
# gentleman         NN        NN
# in                IN        IN
# charge            NN        NN
# ,                 ,         ,
# rushed            VBD       NN          <-- MISMATCH
# to                IN        IN
# the               AT        AT
# Hollywood         NP        JJ          <-- MISMATCH
# police            NN        NN
# station           NN        NN
# to                TO        TO
# report            VB        VB
# the               AT        AT
# theft             NN        NN
# ,                 ,         ,
# and               CC        CC
# less              AP        AP
# than              IN        IN
# five              CD        CD
# minutes           NNS       NNS
# later             RBR       RBR
# ,                 ,         ,
# detectives        NNS       NN          <-- MISMATCH
# with              IN        IN
# his               PP$       PP$
# picture           NN        NN
# in                IN        IN
# hand              NN        NN
# were              BED       BED
# on                IN        IN
# the               AT        AT
# trail             NN        NN
# of                IN        IN
# Cal               NP        JJ          <-- MISMATCH
# Barco             NP        NN          <-- MISMATCH
# .                 .         .
# Sentence accuracy: 80.95%
#
# Observations after preprocessing: ['the', '<UNK>', ',', 'however', ',', 'was', '<UNK>', ',', 'for', 'by', 'that', 'time', '<UNK>', 'had', '<UNK>', 'of', 'it', 'at', 'a', '<UNK>', 'in', '<UNK>', '.']
# ======================================================================
# TEST SENTENCE #2 (humor)
# ======================================================================
# WORD              GOLD      PRED      OK?
# --------------------------------------------------
# The               AT        AT
# robe              NN        NN
# ,                 ,         ,
# however           WRB       RB          <-- MISMATCH
# ,                 ,         ,
# was               BEDZ      BEDZ
# missing           VBG       VBN         <-- MISMATCH
# ,                 ,         ,
# for               CS        IN          <-- MISMATCH
# by                IN        IN
# that              DT        DT
# time              NN        NN
# Barco             NP        NNS         <-- MISMATCH
# had               HVD       HVD
# disposed          VBN       VBN
# of                IN        IN
# it                PPO       PPO
# at                IN        IN
# a                 AT        AT
# pawnshop          NN        NN
# in                IN        IN
# Glendale          NP        NN          <-- MISMATCH
# .                 .         .
# Sentence accuracy: 78.26%

# %%
# 3(b) Find 3 distinct test (humor) sentences where Viterbi misclassified
# at least one tag, and print the specific errors for analysis.

found = 0
for idx, sent in enumerate(test_data):
    words = [w for w, t in sent]
    gold  = [t for w, t in sent]
    pred  = viterbi_decode(words)
    mism  = [(w, g, p) for w, g, p in zip(words, gold, pred) if g != p]
    # pick reasonably short sentences with a small number of clear errors
    if mism and 4 <= len(words) <= 14:
        print("=" * 70)
        print(f"Misclassified sentence #{found + 1} (test idx {idx})")
        print("Sentence:", " ".join(words))
        print("Errors (word | gold | predicted):")
        for w, g, p in mism:
            print(f"   {w:<15} {g:<8} -> {p}")
        print()
        found += 1
        if found == 3:
            break
# Out:
# Observations after preprocessing: ['it', 'was', 'among', 'these', 'that', '<UNK>', '<UNK>', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>']
# ======================================================================
# Misclassified sentence #1 (test idx 0)
# Sentence: It was among these that Hinkle identified a photograph of Barco ! !
# Errors (word | gold | predicted):
#    that            CS       -> WPS
#    Hinkle          NP       -> VBD
#    identified      VBD      -> VBG
#    Barco           NP       -> JJ
#    !               .        -> NN
#
# Observations after preprocessing: ['for', 'it', 'seems', 'that', '<UNK>', ',', '<UNK>', 'himself', 'a', '<UNK>', 'man', '(', 'and', 'why', 'not', ',', 'after', 'seven', '<UNK>', '?', '?']
# Observations after preprocessing: [')', ',', 'had', 'listed', 'himself', 'for', '<UNK>', '<UNK>', '<UNK>', 'at', 'the', '<UNK>', 'of', 'his', 'fourth', '<UNK>', '<UNK>', 'who', 'had', 'said', ':', '``', 'with', 'your', '<UNK>', ',', '<UNK>', ',', 'you', '<UNK>', 'to', 'be', 'in', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['mills', '<UNK>', '<UNK>', '<UNK>', 'from', 'the', '<UNK>', 'in', 'charge', ',', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'station', 'to', 'report', 'the', '<UNK>', ',', 'and', 'less', 'than', 'five', '<UNK>', 'later', ',', '<UNK>', 'with', 'his', '<UNK>', 'in', 'hand', 'were', 'on', 'the', 'trail', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['on', 'their', 'way', ',', 'they', '<UNK>', 'at', 'every', 'gas', 'station', 'along', 'the', 'main', '<UNK>', 'to', 'question', 'the', '<UNK>', '.']
# Observations after preprocessing: ['finally', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'station', 'on', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'that', 'their', 'man', ',', 'having', '<UNK>', 'to', 'get', '<UNK>', 'for', 'his', 'car', ',', 'had', 'asked', 'about', 'the', '<UNK>', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'in', 'that', 'direction', 'and', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'came', 'upon', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'old', '<UNK>', '<UNK>', '<UNK>', ',', '<UNK>', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['at', 'the', '<UNK>', ',', '<UNK>', 'back', 'was', 'to', 'the', 'road', 'so', 'he', '<UNK>', 'see', 'the', '<UNK>', 'close', 'in', 'on', 'his', '<UNK>', 'which', ',', 'in', 'their', '<UNK>', 'for', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'to', 'search', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'however', ',', 'was', '<UNK>', ',', 'for', 'by', 'that', 'time', '<UNK>', 'had', '<UNK>', 'of', 'it', 'at', 'a', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'placed', '<UNK>', 'under', '<UNK>', 'and', ',', 'without', '<UNK>', 'him', 'of', 'the', 'nature', 'of', 'the', 'charge', ',', 'took', 'him', 'back', 'to', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['thus', 'it', 'was', 'that', '<UNK>', ',', '<UNK>', 'for', '<UNK>', '<UNK>', ',', 'now', 'began', 'to', '<UNK>', 'that', 'one', 'or', 'another', 'of', 'his', '<UNK>', 'had', 'been', '<UNK>', '.']
# Observations after preprocessing: ['during', 'the', 'return', '<UNK>', ',', '<UNK>', 'kept', '<UNK>', 'to', 'himself', 'in', '<UNK>', '<UNK>', ',', 'such', 'as', ':', '``', '<UNK>', 'under', '<UNK>', '<UNK>', '<UNK>', 'better', 'off', ',', 'i', 'tell', 'you', 'i', '<UNK>', 'their', '<UNK>', "''", '.']
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'on', '<UNK>', '<UNK>', ',', 'felt', 'that', 'he', '<UNK>', '<UNK>', 'among', 'the', '<UNK>', 'citizens', 'of', 'our', 'community', 'who', 'are', '<UNK>', '<UNK>', '--', 'that', 'he', 'was', 'a', 'more', 'or', 'less', '<UNK>', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['however', 'while', 'in', 'his', '<UNK>', '<UNK>', 'trial', 'for', '<UNK>', ',', '<UNK>', ',', 'in', 'a', 'fit', 'of', '<UNK>', ',', 'made', 'an', 'attempt', 'to', 'take', 'his', 'own', 'life', '.']
# Observations after preprocessing: ['the', 'attempt', 'had', 'failed', 'because', ',', 'when', '<UNK>', 'to', 'cut', 'his', '<UNK>', ',', 'this', '<UNK>', 'of', 'seven', 'women', 'had', '<UNK>', 'at', 'the', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '--', '<UNK>', 'no', 'particular', 'significance', 'to', 'the', '<UNK>', '--', 'offered', '<UNK>', '<UNK>', 'to', '<UNK>', 'him', ';', ';']
# Observations after preprocessing: ['but', 'the', 'old', 'fellow', ',', 'a', '<UNK>', '<UNK>', ',', '<UNK>', 'it', ',', 'and', 'no', 'more', 'was', 'thought', 'of', 'the', 'matter', '.']
# Observations after preprocessing: ['then', 'it', 'was', 'that', 'district', 'attorney', '<UNK>', 'entered', 'the', 'case', '.']
# ======================================================================
# Misclassified sentence #2 (test idx 17)
# Sentence: Then it was that District Attorney Welch entered the case .
# Errors (word | gold | predicted):
#    that            CS       -> DT
#    Welch           NP       -> NN-TL
#
# Observations after preprocessing: ['a', 'man', 'of', '<UNK>', '<UNK>', ',', 'with', 'one', '<UNK>', 'on', 'the', '<UNK>', 'of', 'los', 'angeles', ',', 'nothing', 'ever', '<UNK>', 'him', 'which', 'might', '<UNK>', 'lead', 'to', 'personal', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'reported', 'to', '<UNK>', 'office', 'that', 'a', '<UNK>', 'in', 'the', 'city', '<UNK>', 'had', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'to', 'know', 'why', '.']
# ======================================================================
# Misclassified sentence #3 (test idx 20)
# Sentence: Welch wanted to know why .
# Errors (word | gold | predicted):
#    Welch           NP       -> RB
#    wanted          VBD      -> VBN
#    why             WRB      -> NN

# %% [markdown]
# ## Cell 22 Error Analysis
#
# The Viterbi decoder's mistakes fall into a few recurring categories:
#
# - **Out-of-vocabulary (OOV) words.** Humor vocabulary differs sharply from
#   government text. Any word unseen in training is mapped to `<UNK>`, so the
#   model relies purely on the `<UNK>` emission distribution plus transition
#   context. This biases unknown words toward frequent open-class tags (nouns)
#   and causes errors on rare proper nouns, adjectives, and domain-specific
#   vocabulary.
#
# - **Lexical ambiguity.** Words that can take multiple tags (e.g. *back* as
#   NN/RB/VB, *that* as a determiner vs. conjunction vs. pronoun) are resolved
#   only by bigram context. When the surrounding bigram is rare or was more
#   common with a different sense in the government corpus, the model picks the
#   training-dominant tag rather than the contextually correct one.
#
# - **Rare / unseen transitions.** A first-order (bigram) HMM only looks one tag
#   back. Tag pairs that are common in humor but rare in government receive a
#   near-floor transition probability, so the decoder avoids the correct path
#   even when the emission evidence supports it.
#
# - **Domain shift.** Because we train on *government* and test on *humor*, both
#   the emission and transition statistics are mismatched — the single largest
#   source of error and the main reason the HMM trails the pretrained baseline.

# %%
# 3(c) Run Viterbi across the ENTIRE test (humor) set and report
# overall token-level accuracy.

all_gold, all_pred = [], []
for sent in test_data:
    words = [w for w, t in sent]
    gold  = [t for w, t in sent]
    pred  = viterbi_decode(words)
    all_gold.extend(gold)
    all_pred.extend(pred)

correct = sum(g == p for g, p in zip(all_gold, all_pred))
total   = len(all_gold)
accuracy = correct / total
print(f"Overall token-level accuracy on humor test set: {accuracy:.4f} "
      f"({correct}/{total})")
# Out:
# Observations after preprocessing: ['it', 'was', 'among', 'these', 'that', '<UNK>', '<UNK>', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['for', 'it', 'seems', 'that', '<UNK>', ',', '<UNK>', 'himself', 'a', '<UNK>', 'man', '(', 'and', 'why', 'not', ',', 'after', 'seven', '<UNK>', '?', '?']
# Observations after preprocessing: [')', ',', 'had', 'listed', 'himself', 'for', '<UNK>', '<UNK>', '<UNK>', 'at', 'the', '<UNK>', 'of', 'his', 'fourth', '<UNK>', '<UNK>', 'who', 'had', 'said', ':', '``', 'with', 'your', '<UNK>', ',', '<UNK>', ',', 'you', '<UNK>', 'to', 'be', 'in', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['mills', '<UNK>', '<UNK>', '<UNK>', 'from', 'the', '<UNK>', 'in', 'charge', ',', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'station', 'to', 'report', 'the', '<UNK>', ',', 'and', 'less', 'than', 'five', '<UNK>', 'later', ',', '<UNK>', 'with', 'his', '<UNK>', 'in', 'hand', 'were', 'on', 'the', 'trail', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['on', 'their', 'way', ',', 'they', '<UNK>', 'at', 'every', 'gas', 'station', 'along', 'the', 'main', '<UNK>', 'to', 'question', 'the', '<UNK>', '.']
# Observations after preprocessing: ['finally', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'station', 'on', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'that', 'their', 'man', ',', 'having', '<UNK>', 'to', 'get', '<UNK>', 'for', 'his', 'car', ',', 'had', 'asked', 'about', 'the', '<UNK>', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'in', 'that', 'direction', 'and', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'came', 'upon', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'old', '<UNK>', '<UNK>', '<UNK>', ',', '<UNK>', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['at', 'the', '<UNK>', ',', '<UNK>', 'back', 'was', 'to', 'the', 'road', 'so', 'he', '<UNK>', 'see', 'the', '<UNK>', 'close', 'in', 'on', 'his', '<UNK>', 'which', ',', 'in', 'their', '<UNK>', 'for', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'to', 'search', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'however', ',', 'was', '<UNK>', ',', 'for', 'by', 'that', 'time', '<UNK>', 'had', '<UNK>', 'of', 'it', 'at', 'a', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'placed', '<UNK>', 'under', '<UNK>', 'and', ',', 'without', '<UNK>', 'him', 'of', 'the', 'nature', 'of', 'the', 'charge', ',', 'took', 'him', 'back', 'to', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['thus', 'it', 'was', 'that', '<UNK>', ',', '<UNK>', 'for', '<UNK>', '<UNK>', ',', 'now', 'began', 'to', '<UNK>', 'that', 'one', 'or', 'another', 'of', 'his', '<UNK>', 'had', 'been', '<UNK>', '.']
# Observations after preprocessing: ['during', 'the', 'return', '<UNK>', ',', '<UNK>', 'kept', '<UNK>', 'to', 'himself', 'in', '<UNK>', '<UNK>', ',', 'such', 'as', ':', '``', '<UNK>', 'under', '<UNK>', '<UNK>', '<UNK>', 'better', 'off', ',', 'i', 'tell', 'you', 'i', '<UNK>', 'their', '<UNK>', "''", '.']
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'on', '<UNK>', '<UNK>', ',', 'felt', 'that', 'he', '<UNK>', '<UNK>', 'among', 'the', '<UNK>', 'citizens', 'of', 'our', 'community', 'who', 'are', '<UNK>', '<UNK>', '--', 'that', 'he', 'was', 'a', 'more', 'or', 'less', '<UNK>', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['however', 'while', 'in', 'his', '<UNK>', '<UNK>', 'trial', 'for', '<UNK>', ',', '<UNK>', ',', 'in', 'a', 'fit', 'of', '<UNK>', ',', 'made', 'an', 'attempt', 'to', 'take', 'his', 'own', 'life', '.']
# Observations after preprocessing: ['the', 'attempt', 'had', 'failed', 'because', ',', 'when', '<UNK>', 'to', 'cut', 'his', '<UNK>', ',', 'this', '<UNK>', 'of', 'seven', 'women', 'had', '<UNK>', 'at', 'the', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '--', '<UNK>', 'no', 'particular', 'significance', 'to', 'the', '<UNK>', '--', 'offered', '<UNK>', '<UNK>', 'to', '<UNK>', 'him', ';', ';']
# Observations after preprocessing: ['but', 'the', 'old', 'fellow', ',', 'a', '<UNK>', '<UNK>', ',', '<UNK>', 'it', ',', 'and', 'no', 'more', 'was', 'thought', 'of', 'the', 'matter', '.']
# Observations after preprocessing: ['then', 'it', 'was', 'that', 'district', 'attorney', '<UNK>', 'entered', 'the', 'case', '.']
# Observations after preprocessing: ['a', 'man', 'of', '<UNK>', '<UNK>', ',', 'with', 'one', '<UNK>', 'on', 'the', '<UNK>', 'of', 'los', 'angeles', ',', 'nothing', 'ever', '<UNK>', 'him', 'which', 'might', '<UNK>', 'lead', 'to', 'personal', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'reported', 'to', '<UNK>', 'office', 'that', 'a', '<UNK>', 'in', 'the', 'city', '<UNK>', 'had', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'to', 'know', 'why', '.']
# Observations after preprocessing: ['no', 'one', '<UNK>', '.']
# Observations after preprocessing: ['now', '<UNK>', 'had', 'a', '<UNK>', '<UNK>', 'that', '<UNK>', 'is', 'guilty', 'of', '<UNK>', 'more', 'laws', 'than', 'he', 'ever', '<UNK>', '<UNK>', 'at', '.']
# Observations after preprocessing: ['the', '<UNK>', 'attempt', '<UNK>', 'to', 'him', 'like', 'an', 'opportunity', 'to', 'put', 'his', '<UNK>', 'to', 'the', 'test', '.']
# Observations after preprocessing: ['so', 'he', 'paid', 'a', '<UNK>', 'on', '<UNK>', 'in', 'his', '<UNK>', 'and', 'began', 'their', '<UNK>', 'by', '<UNK>', '<UNK>', ':']
# Observations after preprocessing: ['``', '<UNK>', ',', '<UNK>', '<UNK>', 'the', 'goods', 'on', 'you', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'be', 'a', '<UNK>', 'better', 'if', 'you', 'come', '<UNK>', "''", '.']
# Observations after preprocessing: ['at', 'first', '<UNK>', 'was', '<UNK>', 'and', '<UNK>', '.']
# Observations after preprocessing: ['but', 'with', '<UNK>', '<UNK>', '<UNK>', 'of', 'the', 'subject', ',', '<UNK>', 'finally', '``', '<UNK>', "''", 'and', 'started', '<UNK>', 'to', 'one', '<UNK>', 'after', 'another', '.']
# Observations after preprocessing: ['by', 'the', 'time', '<UNK>', 'reached', 'the', '<UNK>', 'of', 'three', ',', 'the', 'situation', '<UNK>', 'to', '<UNK>', 'almost', 'too', 'good', 'to', 'be', 'true', '.']
# Observations after preprocessing: ['but', 'if', 'true', ',', 'it', 'was', 'the', 'case', 'of', 'which', 'he', 'had', '<UNK>', ',', 'the', 'case', 'which', 'would', '<UNK>', 'him', 'into', '<UNK>', 'all', 'over', 'america', 'as', 'the', '<UNK>', 'of', 'a', 'great', '<UNK>', 'trial', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'officials', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['but', 'to', '<UNK>', '<UNK>', ',', 'the', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'in', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'clearly', 'a', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['it', 'required', 'strength', ',', '<UNK>', ',', '<UNK>', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['``', 'that', '<UNK>', 'a', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['then', ',', 'for', 'the', 'first', 'time', 'since', 'his', '<UNK>', ',', 'a', '<UNK>', 'of', 'spirit', '<UNK>', '<UNK>', 'eyes', '.']
# Observations after preprocessing: ['his', '<UNK>', 'had', 'been', '<UNK>', '.']
# Observations after preprocessing: ['he', '<UNK>', 'and', '<UNK>', 'to', 'his', 'feet', '.']
# Observations after preprocessing: ['<UNK>', 'show', 'them', '<UNK>', '<UNK>']
# Observations after preprocessing: ['``', 'is', 'that', 'so', "''", '?', '?']
# Observations after preprocessing: ['he', '<UNK>', '.']
# Observations after preprocessing: ['``', 'well', ',', 'for', 'ten', 'years', '<UNK>', 'been', '<UNK>', 'women', '.']
# Observations after preprocessing: ['i', 'can', 'lead', 'you', 'to', 'every', 'one', 'of', 'the', '<UNK>', ',', 'and', 'there', '<UNK>', 'four', ',', 'nor', 'five', ',', 'nor', 'six', 'of', '<UNK>', '--', '<UNK>', 'seven', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''"]
# Observations after preprocessing: ['the', 'next', 'day', 'the', '<UNK>', '<UNK>', ',', 'in', '<UNK>', ',', 'organized', 'what', 'he', '<UNK>', '``', '<UNK>', '<UNK>', '<UNK>', 'chase', "''", '.']
# Observations after preprocessing: ['for', 'indeed', 'it', '<UNK>', '<UNK>', 'that', '<UNK>', 'could', 'go', 'on', '<UNK>', '<UNK>', 'for', 'ten', 'years', 'and', 'not', 'get', '<UNK>', 'at', 'it', ',', 'even', 'in', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', 'consisted', 'of', 'the', '<UNK>', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', '<UNK>', 'with', '<UNK>', ',', 'newspaper', '<UNK>', ',', 'and', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'his', 'state', 'of', '<UNK>', '<UNK>', ',', 'never', 'to', 'return', ',', 'had', '<UNK>', 'a', '<UNK>', 'which', '<UNK>', 'his', 'principal', 'attitude', 'from', 'that', 'time', 'on', '.']
# Observations after preprocessing: ['he', 'directed', 'the', '<UNK>', 'of', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'near', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'the', 'cars', 'at', 'a', '<UNK>', 'in', 'the', 'road', ',', 'he', '<UNK>', 'out', ',', '<UNK>', 'off', 'a', 'certain', 'distance', 'to', 'a', '<UNK>', 'between', 'two', '<UNK>', '<UNK>', '<UNK>', ',', 'and', 'indicated', 'a', 'location', '.']
# Observations after preprocessing: ['orders', 'were', 'given', 'to', '<UNK>', '.']
# Observations after preprocessing: ['nothing', 'was', 'found', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', 'newspaper', '<UNK>', '<UNK>', '<UNK>', 'and', 'again', '<UNK>', 'pride', 'was', '<UNK>', '.']
# Observations after preprocessing: ['with', 'greater', 'precision', 'he', 'again', '<UNK>', 'off', 'a', 'location', ',', 'this', 'time', 'a', 'little', 'more', 'to', 'the', '<UNK>', '.']
# Observations after preprocessing: ['with', '<UNK>', 'and', '<UNK>', ',', 'the', '<UNK>', 'again', 'started', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'on', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'was', '<UNK>', 'that', 'it', 'was', 'a', '<UNK>', 'day', 'for', 'a', '<UNK>', 'when', 'finally', 'one', 'of', 'the', '<UNK>', '<UNK>', 'an', '<UNK>', '.']
# Observations after preprocessing: ['``', '<UNK>', 'something', 'here', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['said', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'around', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'about', 'with', 'his', '<UNK>', ',', 'now', 'raised', 'into', 'view', 'a', '<UNK>', '<UNK>', '<UNK>', 'in', 'one', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['although', 'it', 'was', 'a', '<UNK>', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', ',', 'it', 'was', 'enough', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', 'with', '<UNK>', '.']
# Observations after preprocessing: ['his', '<UNK>', 'grew', 'as', '<UNK>', 'seven', '<UNK>', 'brought', 'to', 'light', 'one', '<UNK>', 'after', 'another', '.']
# Observations after preprocessing: ['now', 'did', '<UNK>', 'truly', 'become', 'the', 'man', 'of', 'the', 'hour', ',', 'and', '<UNK>', 'that', 'followed', 'in', 'the', 'procedure', 'of', 'justice', 'was', 'a', 'new', '<UNK>', 'for', 'him', '.']
# Observations after preprocessing: ['it', '<UNK>', 'to', 'his', 'head', ',', 'and', 'his', '<UNK>', 'increased', '.']
# Observations after preprocessing: ['it', 'was', '<UNK>', 'that', '<UNK>', 'was', 'in', '<UNK>', 'with', '<UNK>', 'and', 'would', 'use', 'his', 'power', 'as', '<UNK>', 'to', '<UNK>', 'every', 'possible', '<UNK>', 'into', 'the', 'case', '.']
# Observations after preprocessing: ['every', 'new', '<UNK>', 'which', 'would', 'provide', 'more', '``', 'copy', "''", 'for', '<UNK>', '<UNK>', 'would', 'thus', 'mean', 'more', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'that', 'both', 'these', '<UNK>', 'were', '<UNK>', 'with', '<UNK>', 'for', 'the', 'dramatic', '<UNK>', 'when', '<UNK>', 'was', 'called', 'to', 'the', '<UNK>', '.']
# Observations after preprocessing: ['once', 'there', ',', 'the', '<UNK>', 'with', '<UNK>', '<UNK>', 'would', 'provide', '<UNK>', 'with', '<UNK>', ':', '``', '<UNK>', 'multiple', '<UNK>', "''", '``', '<UNK>', '<UNK>', 'an', '<UNK>', "''", '``', '<UNK>', 'of', 'another', '<UNK>', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['it', 'would', 'be', '<UNK>', '<UNK>', 'for', 'the', 'man', 'who', 'was', '<UNK>', 'to', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'over', 'the', '<UNK>', '<UNK>', 'of', 'a', '<UNK>', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['i', '<UNK>', '<UNK>', 'closely', 'as', 'the', 'trial', '<UNK>', 'for', 'any', '<UNK>', 'which', 'might', 'give', 'me', 'a', 'lead', 'as', 'to', 'how', 'he', 'might', 'be', '<UNK>', '.']
# Observations after preprocessing: ['it', '<UNK>', 'long', 'before', 'i', '<UNK>', 'that', 'there', 'was', 'something', '<UNK>', 'than', '<UNK>', '<UNK>', 'back', 'of', 'his', 'desire', 'for', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['he', 'was', '<UNK>', 'and', '<UNK>', 'toward', 'her', ',', 'personally', '<UNK>', '.']
# Observations after preprocessing: ['a', '<UNK>', '<UNK>', 'entered', 'my', '<UNK>', 'that', 'perhaps', 'he', 'had', '<UNK>', '<UNK>', 'toward', '<UNK>', '<UNK>', '--', 'or', ',', 'even', 'more', 'serious', 'perhaps', ',', 'that', 'he', 'had', '<UNK>', 'a', 'share', 'of', 'them', 'and', 'had', 'then', 'been', '<UNK>', 'by', 'some', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'did', 'not', 'rest', 'until', 'i', 'had', '<UNK>', 'the', '<UNK>', 'down', '.']
# Observations after preprocessing: ['well', ',', 'here', 'it', 'is', '.']
# Observations after preprocessing: ['one', 'day', 'over', 'a', 'year', 'before', ',', 'there', 'had', 'been', 'a', '<UNK>', '<UNK>', 'in', 'an', 'apartment', 'of', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'had', 'been', '<UNK>', 'to', '<UNK>', ',', 'by', '<UNK>', ',', 'and', 'not', '<UNK>', 'the', 'host', 'or', 'the', 'character', 'of', 'the', '<UNK>', ',', '<UNK>', 'had', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'late', 'and', 'as', '<UNK>', 'entered', 'the', '<UNK>', ',', 'noted', 'that', '<UNK>', '<UNK>', 'to', 'be', 'in', 'the', 'majority', ';', ';']
# Observations after preprocessing: ['the', 'air', 'was', 'thick', 'with', '<UNK>', ',', '<UNK>', '<UNK>', 'were', 'in', 'evidence', ',', 'and', 'several', 'of', 'the', '<UNK>', 'were', 'somewhat', 'the', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', '<UNK>', 'had', 'no', 'wish', 'to', 'remain', ',', 'but', '<UNK>', 'felt', '<UNK>', '<UNK>', 'leave', 'so', 'soon', 'after', 'her', '<UNK>', ',', 'in', 'all', '<UNK>', 'to', 'her', 'host', '.']
# Observations after preprocessing: ['and', 'it', 'so', '<UNK>', 'that', '<UNK>', 'to', 'a', '<UNK>', 'on', 'which', '<UNK>', 'had', 'taken', '<UNK>', 'was', 'a', 'small', 'table', 'on', 'which', '<UNK>', 'noted', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['while', '<UNK>', 'from', '<UNK>', 'the', '<UNK>', 'were', 'a', '<UNK>', 'of', 'feet', 'which', ',', 'as', '<UNK>', 'would', 'have', 'it', ',', '<UNK>', 'to', 'district', 'attorney', '<UNK>', '.']
# Observations after preprocessing: ['as', '<UNK>', '<UNK>', 'there', ',', 'a', '<UNK>', '<UNK>', '<UNK>', 'her', 'to', '<UNK>', 'the', '<UNK>', 'and', '<UNK>', 'from', 'the', '<UNK>', 'feet', 'and', ',', 'as', 'a', '<UNK>', ',', '<UNK>', '<UNK>', 'between', 'the', '<UNK>', '.']
# Observations after preprocessing: ['a', 'little', 'later', 'the', 'district', 'attorney', '<UNK>', 'up', ',', '<UNK>', 'from', 'under', 'the', '<UNK>', ',', '<UNK>', 'at', 'his', '<UNK>', ',', 'and', 'realized', 'he', 'had', 'an', '<UNK>', 'that', 'very', 'hour', 'to', '<UNK>', 'a', 'meeting', 'of', 'the', '<UNK>', '<UNK>', 'on', '``', 'the', 'civic', 'spirit', 'of', 'the', '<UNK>', "''", ',', 'in', 'the', '<UNK>', 'room', 'of', 'the', '<UNK>', 'where', 'his', 'wife', ',', 'as', 'president', 'of', 'the', '<UNK>', ',', 'was', 'to', '<UNK>', '.']
# Observations after preprocessing: ['he', 'made', 'his', 'way', 'to', 'his', '<UNK>', '<UNK>', 'where', 'he', 'carefully', '<UNK>', 'himself', 'off', ',', '<UNK>', '<UNK>', 'his', '<UNK>', ',', 'and', '<UNK>', 'selected', 'his', '<UNK>', 'from', 'the', 'many', 'on', 'the', '<UNK>', '.']
# Observations after preprocessing: ['then', ',', '<UNK>', 'neither', 'the', 'absence', 'of', 'his', '<UNK>', 'nor', 'the', '<UNK>', 'of', 'the', '<UNK>', ',', 'he', 'made', 'his', 'way', 'to', 'the', '<UNK>', 'room', 'and', ',', 'with', 'his', 'usual', 'dignity', ',', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['the', 'effect', 'on', 'the', '<UNK>', 'among', 'his', '<UNK>', 'may', 'well', 'be', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'aside', 'from', 'reflecting', 'on', '<UNK>', 'political', 'career', ',', 'had', 'all', 'but', '<UNK>', 'his', 'home', 'life', '.']
# Observations after preprocessing: ['he', 'never', '<UNK>', 'until', 'he', 'discovered', 'who', 'the', '<UNK>', 'was', ',', 'and', 'when', 'he', 'did', ',', 'he', '<UNK>', '<UNK>', 'on', '<UNK>', '<UNK>', 'if', 'ever', 'the', '<UNK>', 'came', 'his', 'way', '.']
# Observations after preprocessing: ['and', 'here', 'it', 'was', '<UNK>', '<UNK>']
# Observations after preprocessing: ['by', 'such', '<UNK>', 'actions', 'are', 'human', '<UNK>', 'sometimes', 'set', 'in', '<UNK>', '.']
# Observations after preprocessing: ['during', 'these', 'first', 'days', 'of', 'the', 'trial', 'i', '<UNK>', 'have', 'as', 'much', 'time', 'to', '<UNK>', 'with', '<UNK>', 'as', 'i', 'should', 'have', '<UNK>', '.']
# Observations after preprocessing: ['in', 'the', 'first', 'place', ',', 'it', 'was', 'difficult', 'for', 'us', 'to', 'meet', '.']
# Observations after preprocessing: ['we', '<UNK>', 'be', 'seen', 'together', ',', 'for', 'the', '<UNK>', 'of', '<UNK>', 'was', 'ever', 'ready', 'to', '<UNK>', 'our', '<UNK>', ',', 'and', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', 'but', 'one', 'thing', 'to', 'say', 'of', 'the', 'association', 'of', 'a', 'man', 'with', 'a', '<UNK>', ',', 'no', 'matter', 'how', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', '<UNK>', '<UNK>', 'to', 'our', 'house', ',', 'for', '<UNK>', '<UNK>', '<UNK>', 'to', 'receive', 'her', '.']
# Observations after preprocessing: ['now', 'the', '<UNK>', 'had', 'not', '<UNK>', 'my', 'own', 'sense', 'of', 'social', 'values', ',', 'but', '<UNK>', 'had', '<UNK>', 'a', 'reflected', '<UNK>', 'through', 'it', ',', 'which', 'had', '<UNK>', 'the', '<UNK>', 'of', 'los', '<UNK>', 'society', 'to', 'her', '.']
# Observations after preprocessing: ['there', ',', '<UNK>', 'was', 'received', 'by', 'the', '<UNK>', 'of', '<UNK>', 'lines', 'which', 'are', '<UNK>', 'by', 'the', '<UNK>', '(', 'of', '<UNK>', '<UNK>', ')', ',', 'the', '<UNK>', '(', 'of', '<UNK>', 'origin', ')', ',', 'and', 'the', '<UNK>', '(', 'whose', '<UNK>', '<UNK>', 'a', '<UNK>', 'famous', 'trade', 'in', '<UNK>', ')', '.']
# Observations after preprocessing: ['i', '<UNK>', 'being', '<UNK>', 'into', 'the', '<UNK>', 'of', 'these', '<UNK>', '.']
# Observations after preprocessing: ['but', '<UNK>', '<UNK>', ',', 'for', 'it', 'is', '<UNK>', 'indeed', 'that', '<UNK>', '<UNK>', 'connected', 'with', 'the', '<UNK>', 'is', 'ever', 'received', 'in', 'their', 'exclusive', '<UNK>', '.']
# Observations after preprocessing: ['in', 'fact', ',', 'it', 'was', 'not', 'until', 'the', '<UNK>', 'of', '<UNK>', 'had', '<UNK>', 'at', '<UNK>', 'that', '<UNK>', 'and', '<UNK>', 'were', '<UNK>', 'to', 'cross', 'the', '<UNK>', '<UNK>', 'which', 'separate', 'los', 'angeles', 'and', '<UNK>', 'from', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'even', '<UNK>', 'so', 'far', 'as', 'to', '<UNK>', 'up', 'for', 'me', '<UNK>', 'opportunities', 'with', '<UNK>', '<UNK>', 'who', 'had', 'been', '<UNK>', 'abroad', ',', 'and', 'with', 'those', 'of', 'the', 'more', '<UNK>', 'los', 'angeles', 'area', 'where', 'a', '<UNK>', 'was', 'a', '<UNK>', 'who', 'had', 'been', 'to', 'high', 'school', '.']
# Observations after preprocessing: ['but', 'at', 'long', 'last', 'came', 'a', 'time', 'when', 'i', '<UNK>', 'away', 'from', '<UNK>', 'and', 'her', 'society', '``', '<UNK>', "''", 'in', 'order', 'to', '<UNK>', 'a', '<UNK>', '<UNK>', 'with', '<UNK>', 'and', 'her', '<UNK>', 'at', 'her', 'home', '.']
# Observations after preprocessing: ['however', ',', 'such', 'a', '<UNK>', 'of', '<UNK>', 'had', '<UNK>', 'up', 'during', 'the', 'trial', ',', 'that', 'every', '<UNK>', 'had', 'to', 'be', 'taken', 'to', 'keep', 'my', '<UNK>', 'from', 'being', '<UNK>', 'to', 'the', 'world', ',', 'society', ',', 'and', 'even', ',', '<UNK>', ',', 'to', 'my', 'own', '<UNK>', '.']
# Observations after preprocessing: ['when', 'i', '<UNK>', 'at', '<UNK>', 'i', 'was', 'shown', ',', 'to', 'my', '<UNK>', ',', 'into', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'me', ',', 'in', '<UNK>', '<UNK>', ',', '<UNK>', 'in', 'hand', ',', 'and', 'explained', 'it', 'was', 'the', '<UNK>', 'night', 'out', 'and', 'that', '<UNK>', '<UNK>', 'was', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'and', '<UNK>', 'proceedings', '.']
# Observations after preprocessing: ['there', 'was', 'to', 'be', '<UNK>', '<UNK>', 'with', '<UNK>', ',', '<UNK>', '<UNK>', ',', '<UNK>', ',', 'new', '<UNK>', 'with', 'a', '<UNK>', 'of', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', '<UNK>', '--', 'all', 'chosen', ',', 'prepared', ',', 'and', '<UNK>', 'by', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'realized', 'that', '<UNK>', 'was', '<UNK>', 'with', 'an', 'entirely', 'different', 'problem', ',', 'but', 'his', '<UNK>', 'could', 'have', 'been', 'no', 'greater', '.']
# Observations after preprocessing: ['the', 'most', 'that', 'was', 'accomplished', 'was', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', ',', 'and', 'by', 'means', 'of', '<UNK>', '<UNK>', ',', 'on', 'an', '<UNK>', 'scale', ',', '<UNK>', 'that', 'the', '<UNK>', '<UNK>', 'themselves', ',', 'after', 'a', 'fashion', '.']
# Observations after preprocessing: ['i', 'was', '<UNK>', 'from', 'making', 'the', 'decision', 'as', 'the', '<UNK>', '<UNK>', ',', 'and', 'the', '<UNK>', 'were', 'upon', 'me', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'a', '<UNK>', '<UNK>', ':', 'if', 'you', '<UNK>', 'find', 'your', '<UNK>', ',', 'and', 'get', '<UNK>', 'of', 'calling', 'them', ',', '<UNK>', 'up', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', 'matter', 'if', 'your', '<UNK>', 'are', 'at', 'the', '<UNK>', ',', 'in', 'school', ',', '<UNK>', 'their', '<UNK>', ',', 'or', 'on', 'a', 'field', '<UNK>', 'in', 'some', '<UNK>', 'city', ',', 'they', 'will', 'be', 'upon', 'you', '<UNK>', 'within', '<UNK>', 'after', 'you', '<UNK>', 'up', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', '<UNK>', 'themselves', 'around', 'me', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'a', '<UNK>', 'and', '<UNK>', 'the', 'hand', 'with', 'which', 'i', 'was', '<UNK>', 'to', 'hold', 'the', '<UNK>', ',', '<UNK>', 'my', 'immediate', 'attention', 'on', '<UNK>', 'of', '<UNK>', 'emergency', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'to', 'get', 'out', 'a', '<UNK>', ',', '<UNK>', ',', '``', '<UNK>', 'you', 'hold', 'on', 'a', 'second', ',', '<UNK>', "''", ',', 'i', 'covered', 'up', 'the', '<UNK>', ',', 'and', 'with', 'more', '<UNK>', 'and', 'less', '<UNK>', ',', '<UNK>', 'a', '<UNK>', '<UNK>', 'on', '<UNK>', 'and', '<UNK>', ',', 'mostly', 'the', 'latter', ',', 'including', '<UNK>', 'island', 'and', 'the', '<UNK>', 'reaches', 'of', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'to', '<UNK>', 'the', '<UNK>', ',', 'if', 'they', 'so', 'much', 'as', '<UNK>', '<UNK>', 'after', 'the', '<UNK>', 'was', 'completed', '.']
# Observations after preprocessing: ['<UNK>', 'into', 'the', '<UNK>', 'again', 'and', '<UNK>', 'the', '<UNK>', ',', 'i', '<UNK>', 'my', '<UNK>', 'voice', '.']
# Observations after preprocessing: ['soon', 'we', 'were', 'deep', 'in', 'a', '<UNK>', 'that', 'was', '<UNK>', 'many', 'times', 'by', 'little', 'things', 'like', '<UNK>', '<UNK>', 'her', '<UNK>', 'and', '<UNK>', 'to', '<UNK>', 'out', ',', '<UNK>', '<UNK>', 'the', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', 'on', 'the', 'table', ',', 'and', 'various', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', '.']
# Observations after preprocessing: ['under', 'the', 'circumstances', ',', 'i', 'had', '<UNK>', 'keeping', 'up', 'with', 'the', '<UNK>', 'on', 'the', '<UNK>', ',', 'but', 'when', 'i', '<UNK>', 'up', 'i', 'was', 'reasonably', 'certain', 'that', '<UNK>', 'had', '<UNK>', 'to', '<UNK>', 'me', 'of', 'our', 'town', 'meeting', 'the', 'next', '<UNK>', ',', 'and', 'how', 'important', 'it', 'was', 'that', '<UNK>', 'and', 'i', 'be', 'there', '.']
# Observations after preprocessing: ['i', 'discovered', 'that', 'the', '<UNK>', 'had', '<UNK>', '<UNK>', 'the', '<UNK>', ',', 'and', 'were', '<UNK>', '<UNK>', 'in', 'the', 'living', 'room', '.']
# Observations after preprocessing: ['it', '<UNK>', 'that', 'i', 'would', 'be', 'the', '<UNK>', 'if', 'i', 'accepted', 'the', 'peace', 'and', '<UNK>', ',', 'instead', 'of', 'carrying', 'out', 'my', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'to', 'get', 'something', 'done', ',', 'i', 'started', 'in', 'on', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', '.']
# Observations after preprocessing: ['<UNK>', 'not', 'saying', 'it', 'right', '.']
# Observations after preprocessing: ['what', 'i', '<UNK>', 'to', 'say', 'was', 'that', 'i', 'started', 'to', 'start', 'in', 'on', 'the', '<UNK>', 'by', '<UNK>', 'them', 'all', 'together', 'in', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'so', '<UNK>', ',', 'however', ',', 'so', '<UNK>', ',', 'that', 'i', 'found', '<UNK>', '<UNK>', 'at', 'them', 'in', '<UNK>', 'and', '<UNK>', 'to', '<UNK>', 'again', ',', 'this', 'time', 'about', '<UNK>', 'and', 'her', '<UNK>', '.']
# Observations after preprocessing: ['how', 'about', 'them', ',', 'i', 'thought', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'were', 'among', 'the', 'few', 'people', 'we', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['we', '<UNK>', 'even', 'know', 'them', '<UNK>', 'about', 'a', 'month', 'after', 'we', 'moved', '--', 'at', 'that', 'time', ',', 'they', 'had', 'called', 'on', 'us', ',', 'after', 'i', 'met', '<UNK>', 'at', 'a', '<UNK>', 'meeting', ',', 'and', 'had', 'taken', 'us', 'in', 'hand', '<UNK>', '.']
# Observations after preprocessing: ['they', 'had', 'been', 'kind', 'to', 'us', 'and', 'we', 'were', '<UNK>', 'to', 'them', 'for', 'one', 'or', 'two', '<UNK>', '<UNK>', ',', 'and', 'for', 'information', 'as', 'to', 'where', 'to', 'shop', ',', 'which', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', 'to', '<UNK>', '(', 'not', 'that', 'there', 'was', 'much', 'of', 'a', 'choice', ',', 'since', '<UNK>', 'was', 'just', 'a', '<UNK>', ';', ';']
# Observations after preprocessing: ['the', '<UNK>', 'pages', 'of', 'the', '<UNK>', '<UNK>', 'were', '<UNK>', '<UNK>', ')', '.']
# Observations after preprocessing: ['they', 'were', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', ',', 'an', 'expert', 'on', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', ',', 'was', '<UNK>', 'fashion', 'editor', 'of', '<UNK>', ',', 'the', 'weekly', 'magazine', 'with', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', 'he', 'had', 'met', 'about', 'two', 'years', 'after', '<UNK>', 'had', '<UNK>', 'in', '<UNK>', 'from', '<UNK>', ',', 'or', 'was', 'it', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', 'was', 'the', '<UNK>', 'and', '<UNK>', '<UNK>', 'of', 'either', 'a', '<UNK>', '<UNK>', 'or', 'an', '<UNK>', '<UNK>', 'and', ',', 'having', '<UNK>', 'in', 'new', 'york', 'with', 'a', 'big', 'bank', '<UNK>', ',', 'became', 'a', '<UNK>', 'in', 'various', 'fields', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'for', '<UNK>', ',', 'then', 'put', 'some', 'money', 'into', 'a', '<UNK>', 'show', 'which', 'was', 'successful', '(', '<UNK>', ',', 'but', 'successful', ')', '.']
# Observations after preprocessing: ['it', 'was', 'during', 'her', '``', 'writing', "''", 'period', 'that', '<UNK>', 'and', '<UNK>', 'met', 'and', 'decided', 'that', 'they', 'were', 'in', '<UNK>', '.']
# Observations after preprocessing: ['they', 'were', '<UNK>', 'at', 'a', '<UNK>', '<UNK>', 'which', 'was', 'duly', '<UNK>', 'in', '<UNK>', 'and', 'all', 'other', '<UNK>', 'and', '<UNK>', ',', 'and', 'then', 'they', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['no', ',', 'not', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'not', 'in', '<UNK>', 'that', 'year', '.']
# Observations after preprocessing: ['they', 'had', '<UNK>', 'in', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'was', 'very', 'high', 'on', '<UNK>', 'that', 'year', '.']
# Observations after preprocessing: ['they', 'had', '<UNK>', 'their', 'house', 'in', '<UNK>', 'after', '<UNK>', 'all', 'the', 'regions', 'of', '<UNK>', '<UNK>', 'new', 'york', ';', ';']
# Observations after preprocessing: ['they', 'had', 'chosen', '<UNK>', 'because', 'of', 'its', '<UNK>', 'for', 'excellent', 'schools', ',', '<UNK>', ',', 'and', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['``', 'you', 'are', '<UNK>', 'to', 'get', 'involved', 'with', 'people', 'when', 'you', 'have', '<UNK>', "''", ',', '<UNK>', 'had', '<UNK>', 'me', 'at', 'our', 'first', 'meeting', ',', '``', 'so', 'it', 'is', 'good', 'to', 'know', 'that', 'those', 'with', 'whom', 'you', 'get', 'involved', 'are', 'not', 'just', '<UNK>', 'little', '<UNK>', 'and', '<UNK>', '<UNK>', ',', 'but', 'people', 'who', 'do', 'things', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', 'their', 'easy', 'way', 'of', 'doing', 'things', 'but', 'i', '<UNK>', '<UNK>', 'an', '<UNK>', 'at', 'their', 'way', 'of', 'always', 'doing', 'the', 'right', 'things', '.']
# Observations after preprocessing: ['their', 'house', 'was', 'a', '<UNK>', '<UNK>', 'which', 'they', 'had', 'had', '<UNK>', '(', '<UNK>', 'by', 'an', '<UNK>', '<UNK>', ')', 'and', '<UNK>', ',', 'and', 'added', 'on', 'to', '.']
# Observations after preprocessing: ['it', 'had', 'a', '<UNK>', 'corner', '(', 'instead', 'of', 'a', '<UNK>', ')', ',', 'a', 'breakfast', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', 'room', 'for', 'standing', 'up', ',', 'a', '<UNK>', 'room', ',', '<UNK>', '<UNK>', 'for', '<UNK>', ',', 'even', 'a', 'room', 'for', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'all', 'set', 'up', 'so', 'there', 'would', 'be', 'no', '<UNK>', '<UNK>', 'and', 'so', 'that', 'their', '<UNK>', 'would', '<UNK>', 'in', 'the', '<UNK>', 'room', ',', '<UNK>', 'in', 'the', '<UNK>', 'room', ',', 'play', 'with', 'blocks', 'in', 'the', 'block', 'house', ',', 'and', 'do', 'all', 'the', 'other', 'things', 'in', 'the', 'proper', '<UNK>', 'at', '<UNK>', 'the', 'right', 'time', '.']
# Observations after preprocessing: ['their', 'two', '<UNK>', 'were', '``', 'well', 'adjusted', "''", 'and', ',', 'like', 'their', '<UNK>', ',', 'always', 'did', 'the', 'right', 'thing', 'at', 'the', 'right', 'time', 'and', '<UNK>', 'the', 'consequences', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'considered', 'themselves', '<UNK>', '<UNK>', 'and', 'showed', 'the', 'world', 'they', 'were', 'by', '<UNK>', 'their', '<UNK>', 'house', 'with', '<UNK>', '<UNK>', 'and', '<UNK>', 'and', 'other', 'art', '<UNK>', '(', 'expensive', ',', 'but', 'not', 'necessarily', 'valuable', ',', '<UNK>', 'things', ')', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'her', 'independence', 'by', '<UNK>', 'against', 'the', '<UNK>', 'uniform', 'of', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'by', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'in', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'and', '<UNK>', 'and', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['sometimes', '<UNK>', 'even', '<UNK>', 'the', 'uniform', 'in', 'solid', ',', '<UNK>', '<UNK>', ',', 'and', 'with', 'her', '<UNK>', '<UNK>', 'cut', 'so', 'closely', ',', '<UNK>', 'this', 'uniform', ',', '<UNK>', 'strongly', '<UNK>', 'a', 'member', 'of', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', 'one', 'could', '<UNK>', 'them', ',', 'i', 'thought', '.']
# Observations after preprocessing: ['sometimes', ',', 'though', ',', 'they', 'did', 'not', 'seem', 'quite', 'human', '.']
# Observations after preprocessing: ['it', '<UNK>', ',', 'indeed', ',', 'that', 'their', 'house', 'was', 'not', 'so', 'much', 'a', 'home', ',', 'but', 'rather', 'a', '<UNK>', 'stage', 'set', ',', 'and', 'that', 'they', 'were', '<UNK>', 'who', 'had', 'been', '<UNK>', '<UNK>', '<UNK>', 'in', 'a', 'successful', 'play', ',', 'and', 'had', '<UNK>', 'enough', 'to', '<UNK>', 'the', '<UNK>', '<UNK>', ',', 'with', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['practically', 'the', 'only', '<UNK>', 'they', 'showed', 'was', 'when', 'they', 'were', '<UNK>', '``', '<UNK>', "''", ';', ';']
# Observations after preprocessing: ['even', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['you', 'should', '<UNK>', 'the', '<UNK>', 'in', '<UNK>', 'voice', 'when', '<UNK>', 'said', '``', '<UNK>', "''", 'or', '``', '<UNK>', "''", 'or', '``', '<UNK>', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'always', 'let', 'it', 'be', 'known', 'that', 'there', 'was', '<UNK>', 'in', 'the', '<UNK>', '<UNK>', 'or', 'that', 'the', '<UNK>', 'had', 'been', '<UNK>', 'in', '<UNK>', ',', 'and', 'that', '<UNK>', 'second', '<UNK>', 'was', 'an', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'have', '<UNK>', 'time', '<UNK>', 'over', 'this', '<UNK>', 'were', 'it', 'not', 'for', 'my', '<UNK>', 'that', 'all', 'the', 'other', '<UNK>', 'of', '<UNK>', 'were', 'equally', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'feel', 'at', 'home', 'among', 'them', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', ',', 'there', 'was', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', 'and', '<UNK>', ',', 'but', '<UNK>', 'was', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', '<UNK>', 'was', 'very', ',', 'very', '<UNK>', '--', 'being', 'in', 'her', 'company', 'was', 'like', 'being', '<UNK>', 'in', 'warm', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'had', 'once', 'been', 'a', '<UNK>', 'when', '<UNK>', 'had', '<UNK>', 'and', 'said', 'with', 'only', 'minimum', '<UNK>', ',', '``', 'oh', ',', 'my', '<UNK>', 'has', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'knows', 'how', 'a', 'real', ',', '<UNK>', '<UNK>', 'would', '<UNK>', 'to', 'such', 'a', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['if', '<UNK>', 'had', 'been', '<UNK>', ',', '<UNK>', 'would', 'have', '<UNK>', ',', '<UNK>', 'at', 'least', 'a', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'a', 'few', 'little', ',', '<UNK>', 'things', '.']
# Observations after preprocessing: ['but', '<UNK>', 'me', ',', 'no', ';', ';']
# Observations after preprocessing: ['not', '<UNK>', '.']
# Observations after preprocessing: ['after', 'five', '<UNK>', 'with', '<UNK>', ',', 'one', 'might', 'welcome', 'the', '<UNK>', 'of', '<UNK>', ',', 'who', 'was', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', 'to', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'were', '<UNK>', 'committee', 'chairmen', 'and', 'they', 'usually', '<UNK>', 'to', 'be', '<UNK>', '<UNK>', ',', 'equal', '<UNK>', ',', 'of', '<UNK>', '<UNK>', 'or', 'civic', 'project', 'was', 'being', 'launched', '.']
# Observations after preprocessing: ['they', 'were', '<UNK>', ',', 'not', 'because', 'they', 'were', '<UNK>', 'of', 'each', 'other', ',', 'but', 'because', 'they', '<UNK>', 'to', 'keep', 'an', '<UNK>', 'on', 'each', 'other', ',', 'as', 'they', 'were', '<UNK>', '<UNK>', 'for', 'social', 'leadership', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'mean', ':', '<UNK>', 'mean', ',', 'and', '<UNK>', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'it', 'was', 'who', 'had', '<UNK>', 'to', 'see', 'if', 'i', 'was', '<UNK>', '<UNK>', 'upon', '<UNK>', 'that', 'i', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'had', 'a', 'small', ',', '<UNK>', 'head', 'and', 'her', '<UNK>', 'and', '<UNK>', 'were', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'in', 'an', '<UNK>', 'house', 'whose', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', 'even', '<UNK>', 'were', 'chosen', 'to', '<UNK>', 'her', '<UNK>', ';', ';']
# Observations after preprocessing: ['the', '<UNK>', 'were', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['her', 'uniform', 'was', 'of', '<UNK>', ',', 'raw', '<UNK>', ',', 'in', 'a', '<UNK>', 'which', '<UNK>', 'her', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', ',', 'and', 'since', '<UNK>', 'was', 'so', '<UNK>', 'as', 'to', 'be', 'almost', '<UNK>', ',', '<UNK>', 'rather', '<UNK>', 'a', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'of', 'these', 'women', 'and', 'others', 'i', 'had', 'met', 'in', '<UNK>', 'were', 'distinguished', 'only', 'in', 'that', 'they', 'were', ',', 'to', 'me', 'at', 'least', ',', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'tell', 'one', 'from', 'the', 'other', '.']
# Observations after preprocessing: ['like', '<UNK>', ',', 'they', 'were', 'all', 'in', 'communications', ':', 'radio', ',', '<UNK>', ',', '<UNK>', ',', 'and', 'advertising', '.']
# Observations after preprocessing: ['one', 'or', 'two', 'were', '<UNK>', 'of', 'books', ';', ';']
# Observations after preprocessing: ['all', 'were', 'fellows', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['each', 'had', 'developed', 'a', '<UNK>', '<UNK>', 'and', 'the', '<UNK>', 'of', 'saying', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['in', '<UNK>', 'to', '<UNK>', '.']
# Observations after preprocessing: ['i', 'never', 'thought', '<UNK>', 'live', 'to', '<UNK>', 'people', '<UNK>', 'and', 'say', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['in', 'real', 'life', '.']
# Observations after preprocessing: ['i', '<UNK>', 'have', '<UNK>', 'it', 'for', 'anything', '.']
# Observations after preprocessing: ['they', 'were', '``', '<UNK>', "''", '--', 'men', 'of', 'the', '<UNK>', '<UNK>', 'and', 'the', 'urgent', '<UNK>', '.']
# Observations after preprocessing: ['these', '<UNK>', '<UNK>', 'an', 'introduction', 'to', '<UNK>', 'by', '<UNK>', '<UNK>', 'one', 'of', 'his', '<UNK>', 'in', 'both', 'of', '<UNK>', ',', 'while', 'they', '<UNK>', ',', '<UNK>', 'with', 'care', ',', 'into', 'the', 'eyes', 'of', 'the', 'person', 'they', 'were', 'meeting', '.']
# Observations after preprocessing: ['could', 'such', '<UNK>', '<UNK>', ',', 'for', 'a', 'total', '<UNK>', ',', 'be', '<UNK>', '?', '?']
# Observations after preprocessing: ['they', 'were', 'always', '<UNK>', 'to', 'light', '<UNK>', ',', 'open', 'car', '<UNK>', ',', '<UNK>', '<UNK>', 'or', '<UNK>', ',', 'and', 'i', '<UNK>', 'the', 'whole', '<UNK>', 'of', 'them', 'to', 'the', 'same', 'degree', 'that', 'i', '<UNK>', '<UNK>', 'shops', 'that', 'called', 'themselves', '``', '<UNK>', '<UNK>', 'shops', "''", '.']
# Observations after preprocessing: ['``', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''", 'i', 'thought', ',', 'and', '<UNK>', 'what', 'kind', 'of', '<UNK>', 'such', '<UNK>', '<UNK>', 'would', 'establish', 'in', 'this', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'who', '<UNK>', 'like', '<UNK>', '<UNK>', 'even', 'at', '<UNK>', 'conferences', 'and', 'who', 'never', 'called', 'the', 'school', 'principal', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', ',', 'thinking', 'that', 'among', 'other', 'things', ',', 'people', 'here', '<UNK>', 'to', 'be', 'those', 'who', 'would', 'have', 'to', 'cut', 'down', 'if', 'they', '<UNK>', 'less', 'than', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['people', 'who', 'would', 'give', 'their', '<UNK>', 'for', 'a', '<UNK>', 'to', 'get', 'on', '``', 'person', 'to', 'person', "''", ';', ';']
# Observations after preprocessing: ['people', 'who', 'thought', 'it', 'was', '<UNK>', 'to', 'be', 'important', ',', 'but', 'not', 'important', 'to', 'be', '<UNK>', ';', ';']
# Observations after preprocessing: ['who', 'were', 'more', '<UNK>', 'than', '<UNK>', ',', 'more', '<UNK>', 'than', 'persons', '.']
# Observations after preprocessing: ['in', 'my', '<UNK>', ',', 'they', 'were', 'people', 'who', 'read', '<UNK>', 'du', '<UNK>', ',', 'and', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['well', ',', 'not', '<UNK>', 'him', '<UNK>', ',', 'but', 'said', ',', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'and', 'raised', 'their', 'eyes', ',', 'as', 'if', 'they', 'were', 'at', 'a', 'loss', 'to', '<UNK>', 'how', 'they', 'felt', 'about', '<UNK>', ',', 'which', 'they', 'were', ',', 'because', 'they', 'had', 'no', 'opinions', 'about', '<UNK>', ',', 'not', 'having', 'read', '<UNK>', '.']
# Observations after preprocessing: ['they', 'were', ',', 'i', 'felt', ',', 'people', '<UNK>', '<UNK>', 'to', '<UNK>', 'not', 'who', ',', 'but', 'what', 'they', 'were', ',', 'and', '<UNK>', 'to', 'determine', 'what', ',', 'not', 'who', ',', 'others', 'were', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'that', 'it', 'was', 'nearly', '<UNK>', ',', 'i', 'brought', '<UNK>', 'back', 'to', 'the', 'tasks', 'at', 'hand', '.']
# Observations after preprocessing: ['i', 'made', 'plans', 'for', 'the', '<UNK>', '--', 'doing', 'the', 'breakfast', 'and', '<UNK>', '<UNK>', 'all', 'at', 'once', ',', 'making', 'the', '<UNK>', ',', 'and', 'then', '<UNK>', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['then', ',', 'i', '<UNK>', 'that', 'the', '<UNK>', 'had', 'had', 'a', '<UNK>', 'for', '<UNK>', 'every', 'day', 'for', 'the', 'last', 'week', '.']
# Observations after preprocessing: ['``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'had', '<UNK>', 'each', 'time', '.']
# Observations after preprocessing: ['``', '<UNK>', 'not', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'not', 'even', 'food', '.']
# Observations after preprocessing: ['<UNK>', 'just', 'something', '<UNK>', '<UNK>', 'to', 'put', 'on', '<UNK>', 'for', 'breakfast', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', 'around', 'and', 'found', 'a', '<UNK>', ',', 'and', 'was', 'able', 'to', '<UNK>', 'them', 'with', 'a', '<UNK>', '<UNK>', 'with', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['(', 'sometimes', 'i', 'think', 'you', 'need', 'only', 'one', 'rule', 'for', '<UNK>', ':', 'if', 'you', '<UNK>', 'put', '<UNK>', 'in', 'it', ',', 'put', '<UNK>', 'in', 'it', '.']
# Observations after preprocessing: [')']
# Observations after preprocessing: ['the', '<UNK>', 'was', 'received', 'in', 'a', '<UNK>', '<UNK>', 'that', 'was', 'evidence', 'in', 'itself', 'of', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'had', 'been', 'providing', '.']
# Observations after preprocessing: ['then', '<UNK>', '<UNK>', 'her', 'eyes', ',', '<UNK>', 'forth', 'her', 'arms', ',', 'and', 'said', ':', '``', 'take', 'my', 'hand', ',', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'a', '<UNK>', 'in', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'to', 'say', ',', 'i', 'was', '<UNK>', 'at', 'this', '<UNK>', '<UNK>', 'upon', 'free', 'enterprise', '.']
# Observations after preprocessing: ['how', '<UNK>', 'they', 'demand', 'to', '``', '<UNK>', "''", 'in', 'private', 'financial', 'records', ',', '<UNK>', ',', '<UNK>', 'contracts', 'and', '<UNK>', '?', '?']
# Observations after preprocessing: ['``', 'it', 'is', 'as', 'though', "''", ',', 'i', 'said', 'on', 'the', '<UNK>', '<UNK>', ',', '<UNK>', 'radio', 'broadcast', 'which', 'i', '<UNK>', '(', 'following', 'father', '<UNK>', 'and', '<UNK>', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', 'and', 'major', '<UNK>', 'shows', ')', '``', 'that', 'man', 'in', 'the', '<UNK>', 'house', ',', 'like', 'some', '<UNK>', 'of', '<UNK>', ',', '<UNK>', 'on', 'reading', 'my', '<UNK>', ',', '<UNK>', 'my', '<UNK>', 'and', '<UNK>', 'my', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''", 'my', '<UNK>', '<UNK>', 'for', 'civil', 'rights', '<UNK>', 'a', '<UNK>', 'of', '<UNK>', 'and', 'one', '<UNK>', 'even', 'asked', 'me', 'to', 'consider', '<UNK>', 'the', '<UNK>', '<UNK>', '<UNK>', 'hour', 'on', 'a', 'permanent', 'basis', '.']
# Observations after preprocessing: ['but', 'what', '<UNK>', 'could', 'a', 'poor', '<UNK>', '<UNK>', 'expect', 'from', 'a', '<UNK>', 'who', 'would', 'even', 'make', 'so', '<UNK>', 'as', 'to', 'close', 'all', 'of', 'the', 'banks', 'in', 'our', 'great', 'nation', '?', '?']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '<UNK>', 'of', '<UNK>', 'russian', 'communism', '<UNK>', 'on', 'the', '<UNK>', 'that', 'was', '<UNK>', '<UNK>', ',', '<UNK>', 'and', '<UNK>', 'with', 'their', '<UNK>', '<UNK>', '<UNK>', 'of', '``', '<UNK>', 'the', '<UNK>', "'", '<UNK>', '<UNK>']
# Observations after preprocessing: ['after', 'an', '<UNK>', '<UNK>', ',', '<UNK>', 'the', 'better', 'part', 'of', 'two', 'months', ',', 'it', 'was', 'announced', 'that', 'the', '<UNK>', '``', '<UNK>', "''", 'the', 'government', 'a', 'tax', '<UNK>', 'in', 'excess', 'of', 'eight', 'million', 'dollars', 'while', 'i', ',', 'who', 'had', 'always', '<UNK>', '<UNK>', 'from', 'such', '<UNK>', 'practices', 'as', '<UNK>', 'taxes', 'on', 'the', 'salary', 'i', 'had', '<UNK>', 'and', 'the', 'little', 'i', '<UNK>', '<UNK>', 'as', '<UNK>', '<UNK>', '<UNK>', ',', 'was', '``', '<UNK>', "''", 'with', 'a', 'personal', '<UNK>', 'of', 'such', '<UNK>', 'proportions', 'as', 'to', '``', '<UNK>', 'out', "''", 'all', 'but', 'a', '<UNK>', 'of', 'my', 'poor', ',', '<UNK>', 'savings', '.']
# Observations after preprocessing: ['i', 'was', 'also', '<UNK>', '<UNK>', ',', '<UNK>', 'through', 'the', '<UNK>', 'by', 'the', 'radical', '<UNK>', 'and', 'made', 'a', 'figure', 'of', '<UNK>', 'by', 'such', '<UNK>', 'publications', 'as', 'the', 'new', 'republic', ',', 'the', 'new', '<UNK>', ',', 'time', 'and', 'the', '<UNK>', 'science', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'then', 'that', 'i', '<UNK>', '<UNK>', 'of', 'the', 'rights', 'of', 'a', '<UNK>', 'and', 'declared', 'the', 'income', 'tax', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'was', '<UNK>', 'and', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'like', 'a', '<UNK>', 'but', 'by', 'the', 'time', 'i', '<UNK>', 'my', 'case', 'to', 'the', '<UNK>', 'court', '(', '<UNK>', ')', ',', 'mr.', '<UNK>', 'and', 'his', '``', '<UNK>', "''", 'had', 'done', 'their', '``', '<UNK>', 'work', "''", 'all', 'too', 'well', ',', 'even', 'going', 'so', 'far', 'as', 'to', 'attempt', 'to', '``', '<UNK>', "''", 'the', 'highest', '<UNK>', 'in', 'the', 'land', 'in', 'order', 'to', '<UNK>', 'little', 'me', '.']
# ...
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'by', 'several', '<UNK>', '<UNK>', '<UNK>', 'to', 'keep', 'you', 'on', 'your', '<UNK>', ',', 'will', 'pursue', 'you', 'with', 'a', '<UNK>', '<UNK>', 'of', '<UNK>', '<UNK>', ',', 'but', 'before', 'they', 'close', 'in', ',', '<UNK>', '<UNK>', ',', 'i', '<UNK>', ',', 'for', 'a', '<UNK>', '<UNK>', 'more', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'of', 'the', '<UNK>', 'you', 'took', '<UNK>', 'properties', 'of', 'a', 'most', '<UNK>', 'and', '<UNK>', 'nature', ',', 'as', 'you', 'will', '<UNK>', 'when', 'your', '<UNK>', 'begin', 'to', '<UNK>', 'and', 'your', '<UNK>', 'falls', 'out', 'in', '<UNK>', '.']
# Observations after preprocessing: ['in', 'time', ',', 'these', 'minor', '<UNK>', 'will', 'multiply', 'and', '<UNK>', ',', '<UNK>', 'you', 'with', '<UNK>', ',', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', '<UNK>', ',', 'until', 'your', 'very', 'existence', '<UNK>', 'a', 'burden', 'and', 'you', '<UNK>', 'out', 'for', '<UNK>', '.']
# Observations after preprocessing: ['all', 'this', ',', 'though', ',', 'is', 'simply', 'a', '<UNK>', ',', 'a', '<UNK>', ',', 'for', 'what', '<UNK>', ',', 'and', 'i', 'doubt', 'whether', 'any', '<UNK>', 'could', 'accurately', '<UNK>', 'it', '.']
# Observations after preprocessing: ['if', ',', 'however', ',', 'it', 'would', 'help', 'to', '<UNK>', 'your', '<UNK>', ',', 'i', 'can', '<UNK>', 'the', '<UNK>', 'of', 'a', 'few', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', 'the', '<UNK>', 'they', '<UNK>', 'out', 'in', 'one', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['hold', 'on', '<UNK>', '.']
# Observations after preprocessing: ['first', 'of', 'all', ',', 'the', 'six', 'figures', 'of', 'the', '<UNK>', 'you', '<UNK>', '--', 'four', '<UNK>', '<UNK>', ',', 'a', '<UNK>', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'position', ',', 'and', 'a', 'large', '<UNK>', 'figure', 'of', 'the', '<UNK>', '<UNK>', 'on', 'a', '<UNK>', 'base', '.']
# Observations after preprocessing: ['now', ',', 'you', 'probably', 'share', 'the', 'widespread', 'western', 'belief', 'that', 'the', 'lord', '<UNK>', 'is', 'the', 'most', '<UNK>', 'of', 'the', '<UNK>', ',', 'much', 'more', 'so', 'than', '<UNK>', 'and', '<UNK>', 'and', 'the', 'rest', '.']
# Observations after preprocessing: ['<UNK>', 'up', '--', '<UNK>', 'you', '?', '?']
# Observations after preprocessing: ['well', ',', '<UNK>', 'he', 'is', ',', 'except', '(', 'as', 'the', '<UNK>', 'of', 'the', 'law', '<UNK>', ')', 'toward', '<UNK>', '<UNK>', 'who', '<UNK>', ',', '<UNK>', ',', 'or', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['very', '<UNK>', '<UNK>', 'indeed', 'seems', 'to', '<UNK>', 'such', '<UNK>', '.']
# Observations after preprocessing: ['eight', 'or', 'ten', 'years', 'ago', ',', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'a', '<UNK>', '<UNK>', 'head', 'from', 'the', '<UNK>', '<UNK>', ',', 'in', '<UNK>', ',', 'and', 'a', 'week', 'later', '<UNK>', 'into', 'the', '<UNK>', 'with', '<UNK>', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'own', 'amount', 'of', '<UNK>', '<UNK>', 'did', 'nothing', 'to', '<UNK>', 'their', '<UNK>', ';', ';']
# Observations after preprocessing: ['they', '<UNK>', '<UNK>', '<UNK>', '<UNK>', ',', '<UNK>', 'the', '<UNK>', 'one', 'to', '<UNK>', 'their', '<UNK>', '.']
# Observations after preprocessing: ['any', '<UNK>', '<UNK>', '<UNK>', 'can', 'supply', 'you', 'with', 'a', '<UNK>', 'similar', 'instances', ',', 'and', '<UNK>', 'presently', '<UNK>', 'a', 'case', 'out', 'of', 'my', 'own', 'personal', 'experience', ',', 'but', ',', 'for', 'the', '<UNK>', ',', '<UNK>', 'resume', 'our', '<UNK>', '.']
# Observations after preprocessing: ['whether', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'you', '<UNK>', '<UNK>', '<UNK>', 'the', '<UNK>', 'to', 'turn', 'your', '<UNK>', 'to', 'lead', ',', 'as', 'a', '<UNK>', 'in', '<UNK>', '<UNK>', 'me', ',', 'i', 'am', 'not', 'competent', 'to', 'say', '.']
# Observations after preprocessing: ['likewise', 'the', '<UNK>', '<UNK>', '<UNK>', 'figure', 'known', 'as', 'a', '``', '<UNK>', '<UNK>', "''", '(', '<UNK>', '<UNK>', ')', ';', ';']
# Observations after preprocessing: ['a', '<UNK>', 'of', '<UNK>', '<UNK>', 'her', 'from', 'the', '<UNK>', '<UNK>', 'for', 'inspection', 'was', '<UNK>', 'as', 'if', 'by', 'a', '<UNK>', ',', 'but', 'he', 'had', 'previously', '<UNK>', 'a', 'quantity', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', 'three', '<UNK>', '<UNK>', '<UNK>', ',', 'though', '--', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', '--', 'are', 'an', '<UNK>', 'different', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'from', '<UNK>', ',', 'a', 'state', 'in', 'the', '<UNK>', 'where', '<UNK>', ',', 'the', '<UNK>', 'of', '<UNK>', ',', 'is', '<UNK>', '.']
# Observations after preprocessing: ['have', 'you', 'ever', '<UNK>', 'of', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['but', 'it', 'is', 'the', '<UNK>', '<UNK>', 'from', '<UNK>', ',', 'the', 'one', 'representing', 'two', 'men', 'with', 'their', '<UNK>', '<UNK>', '<UNK>', 'and', 'their', '<UNK>', '<UNK>', 'by', 'a', '<UNK>', ',', 'that', 'i', 'particularly', '<UNK>', 'to', 'your', 'attention', '.']
# Observations after preprocessing: ['<UNK>', 'enough', ',', 'this', 'is', 'an', '<UNK>', 'against', '<UNK>', ',', 'presented', 'to', 'the', '<UNK>', 'and', 'me', 'by', 'a', 'local', '<UNK>', 'in', '1949', '.']
# Observations after preprocessing: ['<UNK>', 'around', 'its', 'base', 'is', 'a', '<UNK>', 'in', '<UNK>', ',', 'a', '<UNK>', 'i', 'take', 'it', 'you', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['neither', 'do', 'i', ',', 'but', 'the', '<UNK>', '<UNK>', 'was', 'good', 'enough', 'to', '<UNK>', ',', 'and', '<UNK>', 'do', 'as', 'much', 'for', 'you', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'our', '<UNK>', ',', 'the', '<UNK>', 'states', ',', 'can', 'expect', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'will', '<UNK>', 'from', 'his', '<UNK>', 'like', '<UNK>', ',', 'his', 'wife', 'will', 'make', 'him', '<UNK>', 'with', '<UNK>', ',', 'and', 'a', '<UNK>', 'car', 'will', 'grow', 'in', 'his', '<UNK>', '.']
# Observations after preprocessing: ['furthermore', '--', 'and', 'this', ',', 'to', 'me', ',', '<UNK>', 'an', 'especially', '<UNK>', 'note', '--', 'it', 'shall', '<UNK>', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'away', 'or', '<UNK>', 'of', 'their', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'of', '<UNK>', '<UNK>', 'the', '<UNK>', 'they', '<UNK>', 'any', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'them', '<UNK>', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'of', '<UNK>', ',', '<UNK>', 'it', '?', '?']
# Observations after preprocessing: ['still', ',', 'there', 'it', 'is', '.']
# Observations after preprocessing: ['now', ',', 'you', 'no', 'doubt', 'regard', 'the', 'preceding', 'as', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'around', 'full', 'of', '<UNK>', 'in', 'your', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', 'on', '<UNK>', 'and', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'and', 'generally', '<UNK>', 'like', '<UNK>', '.']
# Observations after preprocessing: ['in', 'that', 'case', ',', '<UNK>', 'to', 'what', '<UNK>', 'another', '<UNK>', 'who', '<UNK>', 'with', 'our', '<UNK>', '.']
# Observations after preprocessing: ['a', '<UNK>', 'of', 'years', 'back', ',', 'i', '<UNK>', 'a', '<UNK>', 'apartment', 'whose', '<UNK>', '<UNK>', 'contained', 'the', 'type', 'of', '<UNK>', 'called', 'a', '``', '<UNK>', 'turn', "''", '.']
# Observations after preprocessing: ['in', 'it', 'was', 'a', '<UNK>', '<UNK>', '<UNK>', 'i', 'had', '<UNK>', 'up', 'in', '<UNK>', ',', 'and', '<UNK>', ',', 'to', 'make', 'merit', ',', 'my', 'wife', 'and', 'i', '<UNK>', 'it', 'with', '<UNK>', 'or', '<UNK>', 'a', 'few', '<UNK>', 'in', 'its', '<UNK>', '.']
# Observations after preprocessing: ['after', 'a', 'while', ',', 'we', 'became', '<UNK>', 'that', 'the', 'money', 'was', '<UNK>', 'as', '<UNK>', 'as', 'we', '<UNK>', 'it', '.']
# Observations after preprocessing: ['our', '<UNK>', 'eventually', '<UNK>', ',', 'by', 'the', 'process', 'of', 'elimination', ',', 'on', 'a', '<UNK>', '<UNK>', ',', 'a', 'thoroughly', '<UNK>', '<UNK>', ',', 'who', 'delivered', '<UNK>', 'to', 'the', 'people', '<UNK>', '.']
# Observations after preprocessing: ['the', 'more', 'i', '<UNK>', 'into', 'this', 'young', '<UNK>', 'activities', 'and', 'character', ',', 'the', 'less', '<UNK>', 'i', 'found', 'him', '.']
# Observations after preprocessing: ['i', '<UNK>', ',', 'for', 'example', ',', 'that', 'he', 'made', 'a', 'practice', 'of', '<UNK>', 'at', '<UNK>', 'he', '<UNK>', 'and', ',', 'in', '<UNK>', ',', 'of', '<UNK>', '<UNK>', 'on', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'their', 'feet', '.']
# Observations after preprocessing: ['his', 'energy', 'was', '<UNK>', ';', ';']
# Observations after preprocessing: ['sometimes', 'he', 'would', 'be', 'up', 'before', '<UNK>', ',', '<UNK>', 'as', 'a', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'into', '<UNK>', 'to', '<UNK>', 'us', ',', 'and', 'thereafter', 'would', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'at', 'the', '<UNK>', 'and', '<UNK>', '<UNK>', '<UNK>', 'against', 'their', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'he', 'was', 'frequently', 'to', 'be', 'seen', 'at', '<UNK>', 'like', '<UNK>', '&', '<UNK>', 'or', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', '``', '<UNK>', '<UNK>', '<UNK>', "''", '.']
# Observations after preprocessing: ['in', 'short', ',', 'and', 'to', '<UNK>', 'an', '<UNK>', '<UNK>', ',', '<UNK>', 'timber', '.']
# Observations after preprocessing: ['well', ',', 'the', '<UNK>', 'little', '<UNK>', '<UNK>', 'along', '<UNK>', 'animals', 'and', '<UNK>', 'who', '<UNK>', '<UNK>', ',', 'and', 'in', 'due', 'course', ',', 'as', 'was', '<UNK>', ',', '<UNK>', 'himself', '.']
# Observations after preprocessing: ['one', '<UNK>', ',', 'we', 'discovered', 'not', 'only', 'that', 'the', '<UNK>', 'were', '<UNK>', 'from', 'the', '<UNK>', 'but', 'that', 'a', '<UNK>', 'had', 'been', '<UNK>', 'out', 'in', 'its', '<UNK>', '.']
# Observations after preprocessing: ['``', 'now', '<UNK>', '<UNK>', 'it', "''", ',', 'said', 'my', 'wife', '<UNK>', '.']
# Observations after preprocessing: ['``', 'no', '<UNK>', 'will', 'hold', 'still', 'for', 'that', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'for', 'it', "''", '.']
# Observations after preprocessing: ['and', 'how', 'right', '<UNK>', 'was', '.']
# Observations after preprocessing: ['the', 'next', 'time', 'we', '<UNK>', 'him', ',', 'he', 'was', 'a', 'changed', 'person', ';', ';']
# Observations after preprocessing: ['he', 'had', '<UNK>', '<UNK>', 'years', ',', 'and', 'his', 'face', ',', 'the', '<UNK>', 'of', '<UNK>', ',', 'was', '<UNK>', 'with', '<UNK>', ',', 'as', 'though', 'it', 'had', 'been', '<UNK>', 'in', '<UNK>', 'wire', '.']
# Observations after preprocessing: ['some', '<UNK>', 'of', '<UNK>', 'was', '<UNK>', 'his', '<UNK>', ',', 'he', '<UNK>', 'us', 'in', 'a', '<UNK>', 'voice', '--', 'either', 'an', '<UNK>', '<UNK>', 'or', '<UNK>', '<UNK>', ',', 'a', '<UNK>', ',', 'we', '<UNK>', 'determine', 'which', '.']
# Observations after preprocessing: ['his', 'eyes', 'had', 'the', 'same', '<UNK>', '<UNK>', '<UNK>', 'as', 'dr.', '<UNK>', '<UNK>', 'when', 'he', 'was', 'found', 'before', 'his', 'open', '<UNK>', '<UNK>', 'the', '<UNK>', 'band', '.']
# Observations after preprocessing: ['the', '<UNK>', 'the', '<UNK>', 'worked', 'for', 'soon', '<UNK>', 'of', 'his', '<UNK>', 'effect', 'on', '<UNK>', ',', 'most', 'of', 'whom', 'were', 'sufficiently', '<UNK>', 'without', 'the', 'threat', 'of', '<UNK>', ',', 'and', 'let', 'him', 'go', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'the', '<UNK>', 'part', 'of', 'his', '<UNK>', ',', 'however', ',', 'was', 'the', '<UNK>', 'way', 'the', '<UNK>', '<UNK>', 'him', 'off', '.']
# Observations after preprocessing: ['reduced', 'to', '<UNK>', ',', 'he', 'at', 'last', '<UNK>', 'a', 'job', 'as', 'office', '<UNK>', 'to', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['his', '<UNK>', ',', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'carried', 'him', '<UNK>', 'to', 'the', 'top', '.']
# Observations after preprocessing: ['he', '<UNK>', 'programs', 'that', '<UNK>', 'new', '<UNK>', 'of', '<UNK>', 'and', '<UNK>', 'whole', '<UNK>', ',', 'and', 'quickly', '<UNK>', 'his', '<UNK>', '.']
# Observations after preprocessing: ['not', 'long', 'ago', ',', 'i', '<UNK>', 'down', 'with', 'him', 'in', 'an', '<UNK>', 'in', 'radio', 'city', ';', ';']
# Observations after preprocessing: ['he', 'was', '<UNK>', 'to', 'himself', '<UNK>', 'to', 'the', '<UNK>', 'and', '<UNK>', 'two', '<UNK>', 'at', 'once', ',', 'clearly', 'a', 'man', 'in', '<UNK>', '.']
# Observations after preprocessing: ['``', 'see', 'that', '<UNK>', "''", '?', '?']
# Observations after preprocessing: ['the', '<UNK>', 'asked', '<UNK>', '.']
# Observations after preprocessing: ['``', 'i', '<UNK>', 'be', 'in', 'his', '<UNK>', 'for', 'all', 'the', 'rice', 'in', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'some', 'kind', 'of', 'a', '<UNK>', '<UNK>', 'his', '<UNK>', "''", '.']
# Observations after preprocessing: ['however', 'one', 'looks', 'at', 'it', ',', 'therefore', ',', '<UNK>', 'say', 'that', 'your', '<UNK>', 'for', 'this', '<UNK>', 'is', 'the', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', 'inventory', 'you', 'acquired', 'from', 'me', '<UNK>', 'going', 'to', 'be', 'easy', 'to', 'move', ';', ';']
# Observations after preprocessing: ['you', '<UNK>', 'very', 'well', '<UNK>', 'up', 'to', 'people', 'on', 'the', 'street', 'and', 'ask', 'if', 'they', 'want', 'to', 'buy', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'since', '<UNK>', 'going', 'to', 'be', '<UNK>', 'de', '<UNK>', '<UNK>', 'soon', 'with', '<UNK>', ',', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', '<UNK>', ',', 'and', 'a', 'host', 'of', 'other', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'you', '<UNK>', 'expect', 'to', 'be', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['my', 'advice', ',', 'if', 'you', 'live', 'long', 'enough', 'to', 'continue', 'your', '<UNK>', ',', 'is', 'that', 'the', 'next', 'time', '<UNK>', '<UNK>', 'by', 'the', '<UNK>', ',', 'pass', 'it', 'up', '--', '<UNK>', 'nothing', 'but', 'a', '<UNK>', '.']
# Observations after preprocessing: ['as', 'you', 'can', '<UNK>', 'on', 'me', 'to', 'do', 'the', 'same', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', ',']
# Observations after preprocessing: ['s.', 'j.', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'in', 'the', '<UNK>']
# Observations after preprocessing: ['the', '<UNK>', 'of', 'the', 'd', '<UNK>', '<UNK>', '<UNK>', ',', 'and', 'as', 'i', '<UNK>', 'into', 'a', '<UNK>', 'and', ',', '<UNK>', ',', '<UNK>', 'up', 'across', 'the', '<UNK>', ',', 'the', 'whole', '<UNK>', 'in', 'my', 'head', '<UNK>', 'into', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'a', 'living', '<UNK>', 'and', 'no', '<UNK>', '--', 'the', '<UNK>', '<UNK>', ',', 'the', 'wide', '<UNK>', ',', '<UNK>', ',', 'that', '<UNK>', 'the', '<UNK>', '<UNK>', 'in', 'her', '<UNK>', '<UNK>', ',', 'and', 'the', '<UNK>', 'whose', 'only', '<UNK>', ',', 'in', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'was', 'that', 'the', 'lower', '<UNK>', 'was', 'a', '<UNK>', 'too', '<UNK>', '.']
# Observations after preprocessing: ['from', 'what', 'i', 'was', 'able', 'to', '<UNK>', 'in', 'a', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'the', 'figure', 'inside', 'the', '<UNK>', '<UNK>', '<UNK>', 'was', '<UNK>', '.']
# Overall token-level accuracy on humor test set: 0.7860 (17052/21695)

# %%
# 3(c) Confusion matrix for the TOP-5 most common POS tags (gold).
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

top5 = [t for t, _ in Counter(all_gold).most_common(5)]
print("Top-5 gold tags:", top5)

idx = {t: i for i, t in enumerate(top5)}
cm = np.zeros((5, 5), dtype=int)
for g, p in zip(all_gold, all_pred):
    if g in idx and p in idx:
        cm[idx[g]][idx[p]] += 1

cm_df = pd.DataFrame(cm, index=top5, columns=top5)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="copper")
plt.title("Confusion Matrix (Top-5 POS Tags) - HMM Viterbi")
plt.xlabel("Predicted Tag")
plt.ylabel("Gold Tag")
plt.show()
cm_df
# Out:
# Top-5 gold tags: ['NN', 'IN', 'AT', ',', '.']
#       NN    IN    AT     ,     .
# NN  2029     1     0     1     0
# IN     3  1815     0     0     0
# AT     3     0  1644     0     0
# ,      0     0     0  1331     0
# .     23     0     0     0  1154

# %% [markdown]
# ## Cell 25 - Baseline Comparison
# ### Part 4 - Baseline Comparison
#
# Compare the from-scratch HMM against NLTK's pretrained averaged
# **PerceptronTagger**.
#
# **Tagset note:** Brown uses its own tagset while the Perceptron tagger emits
# Penn Treebank tags. A raw string comparison would therefore be unfairly low.
# For a fair comparison we map *both* the gold Brown tags and the predicted Penn
# tags onto the **universal tagset**, and we recompute the HMM accuracy under the
# same universal mapping so the two numbers are directly comparable.

# %%
# 4. Pretrained baseline: NLTK averaged PerceptronTagger.
import nltk
nltk.download("averaged_perceptron_tagger", quiet=True)
nltk.download("averaged_perceptron_tagger_eng", quiet=True)
nltk.download("universal_tagset", quiet=True)
from nltk.tag import PerceptronTagger
from nltk.tag.mapping import map_tag

perceptron = PerceptronTagger()

def to_universal(tag, source):
    try:
        return map_tag(source, "universal", tag)
    except Exception:
        return tag

# --- Baseline accuracy (universal-mapped) ---
base_correct = base_total = 0
for sent in test_data:
    words = [w for w, t in sent]
    gold  = [t for w, t in sent]
    tagged = perceptron.tag(words)
    for (w, pred_penn), g in zip(tagged, gold):
        u_pred = to_universal(pred_penn, "en-ptb")
        u_gold = to_universal(g, "brown")
        base_total += 1
        base_correct += (u_pred == u_gold)
baseline_acc = base_correct / base_total

# --- HMM accuracy under the SAME universal mapping (apples-to-apples) ---
hmm_correct = hmm_total = 0
for sent in test_data:
    words = [w for w, t in sent]
    gold  = [t for w, t in sent]
    pred  = viterbi_decode(words)
    for g, p in zip(gold, pred):
        u_gold = to_universal(g, "brown")
        u_pred = to_universal(p, "brown")
        hmm_total += 1
        hmm_correct += (u_gold == u_pred)
hmm_universal_acc = hmm_correct / hmm_total

print(f"HMM (Viterbi) accuracy, universal-mapped : {hmm_universal_acc:.4f}")
print(f"Pretrained Perceptron, universal-mapped  : {baseline_acc:.4f}")
print(f"Gap                                      : {baseline_acc - hmm_universal_acc:+.4f}")
# Out:
# Observations after preprocessing: ['it', 'was', 'among', 'these', 'that', '<UNK>', '<UNK>', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['for', 'it', 'seems', 'that', '<UNK>', ',', '<UNK>', 'himself', 'a', '<UNK>', 'man', '(', 'and', 'why', 'not', ',', 'after', 'seven', '<UNK>', '?', '?']
# Observations after preprocessing: [')', ',', 'had', 'listed', 'himself', 'for', '<UNK>', '<UNK>', '<UNK>', 'at', 'the', '<UNK>', 'of', 'his', 'fourth', '<UNK>', '<UNK>', 'who', 'had', 'said', ':', '``', 'with', 'your', '<UNK>', ',', '<UNK>', ',', 'you', '<UNK>', 'to', 'be', 'in', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['mills', '<UNK>', '<UNK>', '<UNK>', 'from', 'the', '<UNK>', 'in', 'charge', ',', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'station', 'to', 'report', 'the', '<UNK>', ',', 'and', 'less', 'than', 'five', '<UNK>', 'later', ',', '<UNK>', 'with', 'his', '<UNK>', 'in', 'hand', 'were', 'on', 'the', 'trail', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['on', 'their', 'way', ',', 'they', '<UNK>', 'at', 'every', 'gas', 'station', 'along', 'the', 'main', '<UNK>', 'to', 'question', 'the', '<UNK>', '.']
# Observations after preprocessing: ['finally', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'station', 'on', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'that', 'their', 'man', ',', 'having', '<UNK>', 'to', 'get', '<UNK>', 'for', 'his', 'car', ',', 'had', 'asked', 'about', 'the', '<UNK>', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'in', 'that', 'direction', 'and', ',', 'at', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'came', 'upon', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'old', '<UNK>', '<UNK>', '<UNK>', ',', '<UNK>', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['at', 'the', '<UNK>', ',', '<UNK>', 'back', 'was', 'to', 'the', 'road', 'so', 'he', '<UNK>', 'see', 'the', '<UNK>', 'close', 'in', 'on', 'his', '<UNK>', 'which', ',', 'in', 'their', '<UNK>', 'for', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'they', '<UNK>', 'to', 'search', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'however', ',', 'was', '<UNK>', ',', 'for', 'by', 'that', 'time', '<UNK>', 'had', '<UNK>', 'of', 'it', 'at', 'a', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'placed', '<UNK>', 'under', '<UNK>', 'and', ',', 'without', '<UNK>', 'him', 'of', 'the', 'nature', 'of', 'the', 'charge', ',', 'took', 'him', 'back', 'to', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['thus', 'it', 'was', 'that', '<UNK>', ',', '<UNK>', 'for', '<UNK>', '<UNK>', ',', 'now', 'began', 'to', '<UNK>', 'that', 'one', 'or', 'another', 'of', 'his', '<UNK>', 'had', 'been', '<UNK>', '.']
# Observations after preprocessing: ['during', 'the', 'return', '<UNK>', ',', '<UNK>', 'kept', '<UNK>', 'to', 'himself', 'in', '<UNK>', '<UNK>', ',', 'such', 'as', ':', '``', '<UNK>', 'under', '<UNK>', '<UNK>', '<UNK>', 'better', 'off', ',', 'i', 'tell', 'you', 'i', '<UNK>', 'their', '<UNK>', "''", '.']
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'on', '<UNK>', '<UNK>', ',', 'felt', 'that', 'he', '<UNK>', '<UNK>', 'among', 'the', '<UNK>', 'citizens', 'of', 'our', 'community', 'who', 'are', '<UNK>', '<UNK>', '--', 'that', 'he', 'was', 'a', 'more', 'or', 'less', '<UNK>', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['however', 'while', 'in', 'his', '<UNK>', '<UNK>', 'trial', 'for', '<UNK>', ',', '<UNK>', ',', 'in', 'a', 'fit', 'of', '<UNK>', ',', 'made', 'an', 'attempt', 'to', 'take', 'his', 'own', 'life', '.']
# Observations after preprocessing: ['the', 'attempt', 'had', 'failed', 'because', ',', 'when', '<UNK>', 'to', 'cut', 'his', '<UNK>', ',', 'this', '<UNK>', 'of', 'seven', 'women', 'had', '<UNK>', 'at', 'the', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '--', '<UNK>', 'no', 'particular', 'significance', 'to', 'the', '<UNK>', '--', 'offered', '<UNK>', '<UNK>', 'to', '<UNK>', 'him', ';', ';']
# Observations after preprocessing: ['but', 'the', 'old', 'fellow', ',', 'a', '<UNK>', '<UNK>', ',', '<UNK>', 'it', ',', 'and', 'no', 'more', 'was', 'thought', 'of', 'the', 'matter', '.']
# Observations after preprocessing: ['then', 'it', 'was', 'that', 'district', 'attorney', '<UNK>', 'entered', 'the', 'case', '.']
# Observations after preprocessing: ['a', 'man', 'of', '<UNK>', '<UNK>', ',', 'with', 'one', '<UNK>', 'on', 'the', '<UNK>', 'of', 'los', 'angeles', ',', 'nothing', 'ever', '<UNK>', 'him', 'which', 'might', '<UNK>', 'lead', 'to', 'personal', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'reported', 'to', '<UNK>', 'office', 'that', 'a', '<UNK>', 'in', 'the', 'city', '<UNK>', 'had', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'to', 'know', 'why', '.']
# Observations after preprocessing: ['no', 'one', '<UNK>', '.']
# Observations after preprocessing: ['now', '<UNK>', 'had', 'a', '<UNK>', '<UNK>', 'that', '<UNK>', 'is', 'guilty', 'of', '<UNK>', 'more', 'laws', 'than', 'he', 'ever', '<UNK>', '<UNK>', 'at', '.']
# Observations after preprocessing: ['the', '<UNK>', 'attempt', '<UNK>', 'to', 'him', 'like', 'an', 'opportunity', 'to', 'put', 'his', '<UNK>', 'to', 'the', 'test', '.']
# Observations after preprocessing: ['so', 'he', 'paid', 'a', '<UNK>', 'on', '<UNK>', 'in', 'his', '<UNK>', 'and', 'began', 'their', '<UNK>', 'by', '<UNK>', '<UNK>', ':']
# Observations after preprocessing: ['``', '<UNK>', ',', '<UNK>', '<UNK>', 'the', 'goods', 'on', 'you', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'be', 'a', '<UNK>', 'better', 'if', 'you', 'come', '<UNK>', "''", '.']
# Observations after preprocessing: ['at', 'first', '<UNK>', 'was', '<UNK>', 'and', '<UNK>', '.']
# Observations after preprocessing: ['but', 'with', '<UNK>', '<UNK>', '<UNK>', 'of', 'the', 'subject', ',', '<UNK>', 'finally', '``', '<UNK>', "''", 'and', 'started', '<UNK>', 'to', 'one', '<UNK>', 'after', 'another', '.']
# Observations after preprocessing: ['by', 'the', 'time', '<UNK>', 'reached', 'the', '<UNK>', 'of', 'three', ',', 'the', 'situation', '<UNK>', 'to', '<UNK>', 'almost', 'too', 'good', 'to', 'be', 'true', '.']
# Observations after preprocessing: ['but', 'if', 'true', ',', 'it', 'was', 'the', 'case', 'of', 'which', 'he', 'had', '<UNK>', ',', 'the', 'case', 'which', 'would', '<UNK>', 'him', 'into', '<UNK>', 'all', 'over', 'america', 'as', 'the', '<UNK>', 'of', 'a', 'great', '<UNK>', 'trial', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'officials', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['but', 'to', '<UNK>', '<UNK>', ',', 'the', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'in', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'clearly', 'a', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['it', 'required', 'strength', ',', '<UNK>', ',', '<UNK>', 'to', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['``', 'that', '<UNK>', 'a', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['then', ',', 'for', 'the', 'first', 'time', 'since', 'his', '<UNK>', ',', 'a', '<UNK>', 'of', 'spirit', '<UNK>', '<UNK>', 'eyes', '.']
# Observations after preprocessing: ['his', '<UNK>', 'had', 'been', '<UNK>', '.']
# Observations after preprocessing: ['he', '<UNK>', 'and', '<UNK>', 'to', 'his', 'feet', '.']
# Observations after preprocessing: ['<UNK>', 'show', 'them', '<UNK>', '<UNK>']
# Observations after preprocessing: ['``', 'is', 'that', 'so', "''", '?', '?']
# Observations after preprocessing: ['he', '<UNK>', '.']
# Observations after preprocessing: ['``', 'well', ',', 'for', 'ten', 'years', '<UNK>', 'been', '<UNK>', 'women', '.']
# Observations after preprocessing: ['i', 'can', 'lead', 'you', 'to', 'every', 'one', 'of', 'the', '<UNK>', ',', 'and', 'there', '<UNK>', 'four', ',', 'nor', 'five', ',', 'nor', 'six', 'of', '<UNK>', '--', '<UNK>', 'seven', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''"]
# Observations after preprocessing: ['the', 'next', 'day', 'the', '<UNK>', '<UNK>', ',', 'in', '<UNK>', ',', 'organized', 'what', 'he', '<UNK>', '``', '<UNK>', '<UNK>', '<UNK>', 'chase', "''", '.']
# Observations after preprocessing: ['for', 'indeed', 'it', '<UNK>', '<UNK>', 'that', '<UNK>', 'could', 'go', 'on', '<UNK>', '<UNK>', 'for', 'ten', 'years', 'and', 'not', 'get', '<UNK>', 'at', 'it', ',', 'even', 'in', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', 'consisted', 'of', 'the', '<UNK>', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', '<UNK>', 'with', '<UNK>', ',', 'newspaper', '<UNK>', ',', 'and', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'his', 'state', 'of', '<UNK>', '<UNK>', ',', 'never', 'to', 'return', ',', 'had', '<UNK>', 'a', '<UNK>', 'which', '<UNK>', 'his', 'principal', 'attitude', 'from', 'that', 'time', 'on', '.']
# Observations after preprocessing: ['he', 'directed', 'the', '<UNK>', 'of', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'near', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'the', 'cars', 'at', 'a', '<UNK>', 'in', 'the', 'road', ',', 'he', '<UNK>', 'out', ',', '<UNK>', 'off', 'a', 'certain', 'distance', 'to', 'a', '<UNK>', 'between', 'two', '<UNK>', '<UNK>', '<UNK>', ',', 'and', 'indicated', 'a', 'location', '.']
# Observations after preprocessing: ['orders', 'were', 'given', 'to', '<UNK>', '.']
# Observations after preprocessing: ['nothing', 'was', 'found', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', 'newspaper', '<UNK>', '<UNK>', '<UNK>', 'and', 'again', '<UNK>', 'pride', 'was', '<UNK>', '.']
# Observations after preprocessing: ['with', 'greater', 'precision', 'he', 'again', '<UNK>', 'off', 'a', 'location', ',', 'this', 'time', 'a', 'little', 'more', 'to', 'the', '<UNK>', '.']
# Observations after preprocessing: ['with', '<UNK>', 'and', '<UNK>', ',', 'the', '<UNK>', 'again', 'started', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'on', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'was', '<UNK>', 'that', 'it', 'was', 'a', '<UNK>', 'day', 'for', 'a', '<UNK>', 'when', 'finally', 'one', 'of', 'the', '<UNK>', '<UNK>', 'an', '<UNK>', '.']
# Observations after preprocessing: ['``', '<UNK>', 'something', 'here', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['said', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'around', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'about', 'with', 'his', '<UNK>', ',', 'now', 'raised', 'into', 'view', 'a', '<UNK>', '<UNK>', '<UNK>', 'in', 'one', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['although', 'it', 'was', 'a', '<UNK>', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', ',', 'it', 'was', 'enough', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', 'with', '<UNK>', '.']
# Observations after preprocessing: ['his', '<UNK>', 'grew', 'as', '<UNK>', 'seven', '<UNK>', 'brought', 'to', 'light', 'one', '<UNK>', 'after', 'another', '.']
# Observations after preprocessing: ['now', 'did', '<UNK>', 'truly', 'become', 'the', 'man', 'of', 'the', 'hour', ',', 'and', '<UNK>', 'that', 'followed', 'in', 'the', 'procedure', 'of', 'justice', 'was', 'a', 'new', '<UNK>', 'for', 'him', '.']
# Observations after preprocessing: ['it', '<UNK>', 'to', 'his', 'head', ',', 'and', 'his', '<UNK>', 'increased', '.']
# Observations after preprocessing: ['it', 'was', '<UNK>', 'that', '<UNK>', 'was', 'in', '<UNK>', 'with', '<UNK>', 'and', 'would', 'use', 'his', 'power', 'as', '<UNK>', 'to', '<UNK>', 'every', 'possible', '<UNK>', 'into', 'the', 'case', '.']
# Observations after preprocessing: ['every', 'new', '<UNK>', 'which', 'would', 'provide', 'more', '``', 'copy', "''", 'for', '<UNK>', '<UNK>', 'would', 'thus', 'mean', 'more', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'that', 'both', 'these', '<UNK>', 'were', '<UNK>', 'with', '<UNK>', 'for', 'the', 'dramatic', '<UNK>', 'when', '<UNK>', 'was', 'called', 'to', 'the', '<UNK>', '.']
# Observations after preprocessing: ['once', 'there', ',', 'the', '<UNK>', 'with', '<UNK>', '<UNK>', 'would', 'provide', '<UNK>', 'with', '<UNK>', ':', '``', '<UNK>', 'multiple', '<UNK>', "''", '``', '<UNK>', '<UNK>', 'an', '<UNK>', "''", '``', '<UNK>', 'of', 'another', '<UNK>', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['it', 'would', 'be', '<UNK>', '<UNK>', 'for', 'the', 'man', 'who', 'was', '<UNK>', 'to', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'over', 'the', '<UNK>', '<UNK>', 'of', 'a', '<UNK>', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['i', '<UNK>', '<UNK>', 'closely', 'as', 'the', 'trial', '<UNK>', 'for', 'any', '<UNK>', 'which', 'might', 'give', 'me', 'a', 'lead', 'as', 'to', 'how', 'he', 'might', 'be', '<UNK>', '.']
# Observations after preprocessing: ['it', '<UNK>', 'long', 'before', 'i', '<UNK>', 'that', 'there', 'was', 'something', '<UNK>', 'than', '<UNK>', '<UNK>', 'back', 'of', 'his', 'desire', 'for', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['he', 'was', '<UNK>', 'and', '<UNK>', 'toward', 'her', ',', 'personally', '<UNK>', '.']
# Observations after preprocessing: ['a', '<UNK>', '<UNK>', 'entered', 'my', '<UNK>', 'that', 'perhaps', 'he', 'had', '<UNK>', '<UNK>', 'toward', '<UNK>', '<UNK>', '--', 'or', ',', 'even', 'more', 'serious', 'perhaps', ',', 'that', 'he', 'had', '<UNK>', 'a', 'share', 'of', 'them', 'and', 'had', 'then', 'been', '<UNK>', 'by', 'some', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'did', 'not', 'rest', 'until', 'i', 'had', '<UNK>', 'the', '<UNK>', 'down', '.']
# Observations after preprocessing: ['well', ',', 'here', 'it', 'is', '.']
# Observations after preprocessing: ['one', 'day', 'over', 'a', 'year', 'before', ',', 'there', 'had', 'been', 'a', '<UNK>', '<UNK>', 'in', 'an', 'apartment', 'of', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'had', 'been', '<UNK>', 'to', '<UNK>', ',', 'by', '<UNK>', ',', 'and', 'not', '<UNK>', 'the', 'host', 'or', 'the', 'character', 'of', 'the', '<UNK>', ',', '<UNK>', 'had', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'late', 'and', 'as', '<UNK>', 'entered', 'the', '<UNK>', ',', 'noted', 'that', '<UNK>', '<UNK>', 'to', 'be', 'in', 'the', 'majority', ';', ';']
# Observations after preprocessing: ['the', 'air', 'was', 'thick', 'with', '<UNK>', ',', '<UNK>', '<UNK>', 'were', 'in', 'evidence', ',', 'and', 'several', 'of', 'the', '<UNK>', 'were', 'somewhat', 'the', '<UNK>', 'for', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', '<UNK>', 'had', 'no', 'wish', 'to', 'remain', ',', 'but', '<UNK>', 'felt', '<UNK>', '<UNK>', 'leave', 'so', 'soon', 'after', 'her', '<UNK>', ',', 'in', 'all', '<UNK>', 'to', 'her', 'host', '.']
# Observations after preprocessing: ['and', 'it', 'so', '<UNK>', 'that', '<UNK>', 'to', 'a', '<UNK>', 'on', 'which', '<UNK>', 'had', 'taken', '<UNK>', 'was', 'a', 'small', 'table', 'on', 'which', '<UNK>', 'noted', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['while', '<UNK>', 'from', '<UNK>', 'the', '<UNK>', 'were', 'a', '<UNK>', 'of', 'feet', 'which', ',', 'as', '<UNK>', 'would', 'have', 'it', ',', '<UNK>', 'to', 'district', 'attorney', '<UNK>', '.']
# Observations after preprocessing: ['as', '<UNK>', '<UNK>', 'there', ',', 'a', '<UNK>', '<UNK>', '<UNK>', 'her', 'to', '<UNK>', 'the', '<UNK>', 'and', '<UNK>', 'from', 'the', '<UNK>', 'feet', 'and', ',', 'as', 'a', '<UNK>', ',', '<UNK>', '<UNK>', 'between', 'the', '<UNK>', '.']
# Observations after preprocessing: ['a', 'little', 'later', 'the', 'district', 'attorney', '<UNK>', 'up', ',', '<UNK>', 'from', 'under', 'the', '<UNK>', ',', '<UNK>', 'at', 'his', '<UNK>', ',', 'and', 'realized', 'he', 'had', 'an', '<UNK>', 'that', 'very', 'hour', 'to', '<UNK>', 'a', 'meeting', 'of', 'the', '<UNK>', '<UNK>', 'on', '``', 'the', 'civic', 'spirit', 'of', 'the', '<UNK>', "''", ',', 'in', 'the', '<UNK>', 'room', 'of', 'the', '<UNK>', 'where', 'his', 'wife', ',', 'as', 'president', 'of', 'the', '<UNK>', ',', 'was', 'to', '<UNK>', '.']
# Observations after preprocessing: ['he', 'made', 'his', 'way', 'to', 'his', '<UNK>', '<UNK>', 'where', 'he', 'carefully', '<UNK>', 'himself', 'off', ',', '<UNK>', '<UNK>', 'his', '<UNK>', ',', 'and', '<UNK>', 'selected', 'his', '<UNK>', 'from', 'the', 'many', 'on', 'the', '<UNK>', '.']
# Observations after preprocessing: ['then', ',', '<UNK>', 'neither', 'the', 'absence', 'of', 'his', '<UNK>', 'nor', 'the', '<UNK>', 'of', 'the', '<UNK>', ',', 'he', 'made', 'his', 'way', 'to', 'the', '<UNK>', 'room', 'and', ',', 'with', 'his', 'usual', 'dignity', ',', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['the', 'effect', 'on', 'the', '<UNK>', 'among', 'his', '<UNK>', 'may', 'well', 'be', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'aside', 'from', 'reflecting', 'on', '<UNK>', 'political', 'career', ',', 'had', 'all', 'but', '<UNK>', 'his', 'home', 'life', '.']
# Observations after preprocessing: ['he', 'never', '<UNK>', 'until', 'he', 'discovered', 'who', 'the', '<UNK>', 'was', ',', 'and', 'when', 'he', 'did', ',', 'he', '<UNK>', '<UNK>', 'on', '<UNK>', '<UNK>', 'if', 'ever', 'the', '<UNK>', 'came', 'his', 'way', '.']
# Observations after preprocessing: ['and', 'here', 'it', 'was', '<UNK>', '<UNK>']
# Observations after preprocessing: ['by', 'such', '<UNK>', 'actions', 'are', 'human', '<UNK>', 'sometimes', 'set', 'in', '<UNK>', '.']
# Observations after preprocessing: ['during', 'these', 'first', 'days', 'of', 'the', 'trial', 'i', '<UNK>', 'have', 'as', 'much', 'time', 'to', '<UNK>', 'with', '<UNK>', 'as', 'i', 'should', 'have', '<UNK>', '.']
# Observations after preprocessing: ['in', 'the', 'first', 'place', ',', 'it', 'was', 'difficult', 'for', 'us', 'to', 'meet', '.']
# Observations after preprocessing: ['we', '<UNK>', 'be', 'seen', 'together', ',', 'for', 'the', '<UNK>', 'of', '<UNK>', 'was', 'ever', 'ready', 'to', '<UNK>', 'our', '<UNK>', ',', 'and', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', 'but', 'one', 'thing', 'to', 'say', 'of', 'the', 'association', 'of', 'a', 'man', 'with', 'a', '<UNK>', ',', 'no', 'matter', 'how', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', '<UNK>', '<UNK>', 'to', 'our', 'house', ',', 'for', '<UNK>', '<UNK>', '<UNK>', 'to', 'receive', 'her', '.']
# Observations after preprocessing: ['now', 'the', '<UNK>', 'had', 'not', '<UNK>', 'my', 'own', 'sense', 'of', 'social', 'values', ',', 'but', '<UNK>', 'had', '<UNK>', 'a', 'reflected', '<UNK>', 'through', 'it', ',', 'which', 'had', '<UNK>', 'the', '<UNK>', 'of', 'los', '<UNK>', 'society', 'to', 'her', '.']
# Observations after preprocessing: ['there', ',', '<UNK>', 'was', 'received', 'by', 'the', '<UNK>', 'of', '<UNK>', 'lines', 'which', 'are', '<UNK>', 'by', 'the', '<UNK>', '(', 'of', '<UNK>', '<UNK>', ')', ',', 'the', '<UNK>', '(', 'of', '<UNK>', 'origin', ')', ',', 'and', 'the', '<UNK>', '(', 'whose', '<UNK>', '<UNK>', 'a', '<UNK>', 'famous', 'trade', 'in', '<UNK>', ')', '.']
# Observations after preprocessing: ['i', '<UNK>', 'being', '<UNK>', 'into', 'the', '<UNK>', 'of', 'these', '<UNK>', '.']
# Observations after preprocessing: ['but', '<UNK>', '<UNK>', ',', 'for', 'it', 'is', '<UNK>', 'indeed', 'that', '<UNK>', '<UNK>', 'connected', 'with', 'the', '<UNK>', 'is', 'ever', 'received', 'in', 'their', 'exclusive', '<UNK>', '.']
# Observations after preprocessing: ['in', 'fact', ',', 'it', 'was', 'not', 'until', 'the', '<UNK>', 'of', '<UNK>', 'had', '<UNK>', 'at', '<UNK>', 'that', '<UNK>', 'and', '<UNK>', 'were', '<UNK>', 'to', 'cross', 'the', '<UNK>', '<UNK>', 'which', 'separate', 'los', 'angeles', 'and', '<UNK>', 'from', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'even', '<UNK>', 'so', 'far', 'as', 'to', '<UNK>', 'up', 'for', 'me', '<UNK>', 'opportunities', 'with', '<UNK>', '<UNK>', 'who', 'had', 'been', '<UNK>', 'abroad', ',', 'and', 'with', 'those', 'of', 'the', 'more', '<UNK>', 'los', 'angeles', 'area', 'where', 'a', '<UNK>', 'was', 'a', '<UNK>', 'who', 'had', 'been', 'to', 'high', 'school', '.']
# Observations after preprocessing: ['but', 'at', 'long', 'last', 'came', 'a', 'time', 'when', 'i', '<UNK>', 'away', 'from', '<UNK>', 'and', 'her', 'society', '``', '<UNK>', "''", 'in', 'order', 'to', '<UNK>', 'a', '<UNK>', '<UNK>', 'with', '<UNK>', 'and', 'her', '<UNK>', 'at', 'her', 'home', '.']
# Observations after preprocessing: ['however', ',', 'such', 'a', '<UNK>', 'of', '<UNK>', 'had', '<UNK>', 'up', 'during', 'the', 'trial', ',', 'that', 'every', '<UNK>', 'had', 'to', 'be', 'taken', 'to', 'keep', 'my', '<UNK>', 'from', 'being', '<UNK>', 'to', 'the', 'world', ',', 'society', ',', 'and', 'even', ',', '<UNK>', ',', 'to', 'my', 'own', '<UNK>', '.']
# Observations after preprocessing: ['when', 'i', '<UNK>', 'at', '<UNK>', 'i', 'was', 'shown', ',', 'to', 'my', '<UNK>', ',', 'into', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'me', ',', 'in', '<UNK>', '<UNK>', ',', '<UNK>', 'in', 'hand', ',', 'and', 'explained', 'it', 'was', 'the', '<UNK>', 'night', 'out', 'and', 'that', '<UNK>', '<UNK>', 'was', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'and', '<UNK>', 'proceedings', '.']
# Observations after preprocessing: ['there', 'was', 'to', 'be', '<UNK>', '<UNK>', 'with', '<UNK>', ',', '<UNK>', '<UNK>', ',', '<UNK>', ',', 'new', '<UNK>', 'with', 'a', '<UNK>', 'of', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', '<UNK>', '--', 'all', 'chosen', ',', 'prepared', ',', 'and', '<UNK>', 'by', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'realized', 'that', '<UNK>', 'was', '<UNK>', 'with', 'an', 'entirely', 'different', 'problem', ',', 'but', 'his', '<UNK>', 'could', 'have', 'been', 'no', 'greater', '.']
# Observations after preprocessing: ['the', 'most', 'that', 'was', 'accomplished', 'was', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', ',', 'and', 'by', 'means', 'of', '<UNK>', '<UNK>', ',', 'on', 'an', '<UNK>', 'scale', ',', '<UNK>', 'that', 'the', '<UNK>', '<UNK>', 'themselves', ',', 'after', 'a', 'fashion', '.']
# Observations after preprocessing: ['i', 'was', '<UNK>', 'from', 'making', 'the', 'decision', 'as', 'the', '<UNK>', '<UNK>', ',', 'and', 'the', '<UNK>', 'were', 'upon', 'me', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'a', '<UNK>', '<UNK>', ':', 'if', 'you', '<UNK>', 'find', 'your', '<UNK>', ',', 'and', 'get', '<UNK>', 'of', 'calling', 'them', ',', '<UNK>', 'up', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', 'matter', 'if', 'your', '<UNK>', 'are', 'at', 'the', '<UNK>', ',', 'in', 'school', ',', '<UNK>', 'their', '<UNK>', ',', 'or', 'on', 'a', 'field', '<UNK>', 'in', 'some', '<UNK>', 'city', ',', 'they', 'will', 'be', 'upon', 'you', '<UNK>', 'within', '<UNK>', 'after', 'you', '<UNK>', 'up', 'the', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', '<UNK>', 'themselves', 'around', 'me', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'a', '<UNK>', 'and', '<UNK>', 'the', 'hand', 'with', 'which', 'i', 'was', '<UNK>', 'to', 'hold', 'the', '<UNK>', ',', '<UNK>', 'my', 'immediate', 'attention', 'on', '<UNK>', 'of', '<UNK>', 'emergency', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'to', 'get', 'out', 'a', '<UNK>', ',', '<UNK>', ',', '``', '<UNK>', 'you', 'hold', 'on', 'a', 'second', ',', '<UNK>', "''", ',', 'i', 'covered', 'up', 'the', '<UNK>', ',', 'and', 'with', 'more', '<UNK>', 'and', 'less', '<UNK>', ',', '<UNK>', 'a', '<UNK>', '<UNK>', 'on', '<UNK>', 'and', '<UNK>', ',', 'mostly', 'the', 'latter', ',', 'including', '<UNK>', 'island', 'and', 'the', '<UNK>', 'reaches', 'of', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'to', '<UNK>', 'the', '<UNK>', ',', 'if', 'they', 'so', 'much', 'as', '<UNK>', '<UNK>', 'after', 'the', '<UNK>', 'was', 'completed', '.']
# Observations after preprocessing: ['<UNK>', 'into', 'the', '<UNK>', 'again', 'and', '<UNK>', 'the', '<UNK>', ',', 'i', '<UNK>', 'my', '<UNK>', 'voice', '.']
# Observations after preprocessing: ['soon', 'we', 'were', 'deep', 'in', 'a', '<UNK>', 'that', 'was', '<UNK>', 'many', 'times', 'by', 'little', 'things', 'like', '<UNK>', '<UNK>', 'her', '<UNK>', 'and', '<UNK>', 'to', '<UNK>', 'out', ',', '<UNK>', '<UNK>', 'the', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', 'on', 'the', 'table', ',', 'and', 'various', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', '.']
# Observations after preprocessing: ['under', 'the', 'circumstances', ',', 'i', 'had', '<UNK>', 'keeping', 'up', 'with', 'the', '<UNK>', 'on', 'the', '<UNK>', ',', 'but', 'when', 'i', '<UNK>', 'up', 'i', 'was', 'reasonably', 'certain', 'that', '<UNK>', 'had', '<UNK>', 'to', '<UNK>', 'me', 'of', 'our', 'town', 'meeting', 'the', 'next', '<UNK>', ',', 'and', 'how', 'important', 'it', 'was', 'that', '<UNK>', 'and', 'i', 'be', 'there', '.']
# Observations after preprocessing: ['i', 'discovered', 'that', 'the', '<UNK>', 'had', '<UNK>', '<UNK>', 'the', '<UNK>', ',', 'and', 'were', '<UNK>', '<UNK>', 'in', 'the', 'living', 'room', '.']
# Observations after preprocessing: ['it', '<UNK>', 'that', 'i', 'would', 'be', 'the', '<UNK>', 'if', 'i', 'accepted', 'the', 'peace', 'and', '<UNK>', ',', 'instead', 'of', 'carrying', 'out', 'my', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'to', 'get', 'something', 'done', ',', 'i', 'started', 'in', 'on', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', '.']
# Observations after preprocessing: ['<UNK>', 'not', 'saying', 'it', 'right', '.']
# Observations after preprocessing: ['what', 'i', '<UNK>', 'to', 'say', 'was', 'that', 'i', 'started', 'to', 'start', 'in', 'on', 'the', '<UNK>', 'by', '<UNK>', 'them', 'all', 'together', 'in', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'so', '<UNK>', ',', 'however', ',', 'so', '<UNK>', ',', 'that', 'i', 'found', '<UNK>', '<UNK>', 'at', 'them', 'in', '<UNK>', 'and', '<UNK>', 'to', '<UNK>', 'again', ',', 'this', 'time', 'about', '<UNK>', 'and', 'her', '<UNK>', '.']
# Observations after preprocessing: ['how', 'about', 'them', ',', 'i', 'thought', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'were', 'among', 'the', 'few', 'people', 'we', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['we', '<UNK>', 'even', 'know', 'them', '<UNK>', 'about', 'a', 'month', 'after', 'we', 'moved', '--', 'at', 'that', 'time', ',', 'they', 'had', 'called', 'on', 'us', ',', 'after', 'i', 'met', '<UNK>', 'at', 'a', '<UNK>', 'meeting', ',', 'and', 'had', 'taken', 'us', 'in', 'hand', '<UNK>', '.']
# Observations after preprocessing: ['they', 'had', 'been', 'kind', 'to', 'us', 'and', 'we', 'were', '<UNK>', 'to', 'them', 'for', 'one', 'or', 'two', '<UNK>', '<UNK>', ',', 'and', 'for', 'information', 'as', 'to', 'where', 'to', 'shop', ',', 'which', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', 'to', '<UNK>', '(', 'not', 'that', 'there', 'was', 'much', 'of', 'a', 'choice', ',', 'since', '<UNK>', 'was', 'just', 'a', '<UNK>', ';', ';']
# Observations after preprocessing: ['the', '<UNK>', 'pages', 'of', 'the', '<UNK>', '<UNK>', 'were', '<UNK>', '<UNK>', ')', '.']
# Observations after preprocessing: ['they', 'were', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', ',', 'an', 'expert', 'on', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', ',', 'was', '<UNK>', 'fashion', 'editor', 'of', '<UNK>', ',', 'the', 'weekly', 'magazine', 'with', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', 'he', 'had', 'met', 'about', 'two', 'years', 'after', '<UNK>', 'had', '<UNK>', 'in', '<UNK>', 'from', '<UNK>', ',', 'or', 'was', 'it', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', 'was', 'the', '<UNK>', 'and', '<UNK>', '<UNK>', 'of', 'either', 'a', '<UNK>', '<UNK>', 'or', 'an', '<UNK>', '<UNK>', 'and', ',', 'having', '<UNK>', 'in', 'new', 'york', 'with', 'a', 'big', 'bank', '<UNK>', ',', 'became', 'a', '<UNK>', 'in', 'various', 'fields', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'for', '<UNK>', ',', 'then', 'put', 'some', 'money', 'into', 'a', '<UNK>', 'show', 'which', 'was', 'successful', '(', '<UNK>', ',', 'but', 'successful', ')', '.']
# Observations after preprocessing: ['it', 'was', 'during', 'her', '``', 'writing', "''", 'period', 'that', '<UNK>', 'and', '<UNK>', 'met', 'and', 'decided', 'that', 'they', 'were', 'in', '<UNK>', '.']
# Observations after preprocessing: ['they', 'were', '<UNK>', 'at', 'a', '<UNK>', '<UNK>', 'which', 'was', 'duly', '<UNK>', 'in', '<UNK>', 'and', 'all', 'other', '<UNK>', 'and', '<UNK>', ',', 'and', 'then', 'they', '<UNK>', 'in', '<UNK>', '.']
# Observations after preprocessing: ['no', ',', 'not', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'not', 'in', '<UNK>', 'that', 'year', '.']
# Observations after preprocessing: ['they', 'had', '<UNK>', 'in', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'was', 'very', 'high', 'on', '<UNK>', 'that', 'year', '.']
# Observations after preprocessing: ['they', 'had', '<UNK>', 'their', 'house', 'in', '<UNK>', 'after', '<UNK>', 'all', 'the', 'regions', 'of', '<UNK>', '<UNK>', 'new', 'york', ';', ';']
# Observations after preprocessing: ['they', 'had', 'chosen', '<UNK>', 'because', 'of', 'its', '<UNK>', 'for', 'excellent', 'schools', ',', '<UNK>', ',', 'and', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['``', 'you', 'are', '<UNK>', 'to', 'get', 'involved', 'with', 'people', 'when', 'you', 'have', '<UNK>', "''", ',', '<UNK>', 'had', '<UNK>', 'me', 'at', 'our', 'first', 'meeting', ',', '``', 'so', 'it', 'is', 'good', 'to', 'know', 'that', 'those', 'with', 'whom', 'you', 'get', 'involved', 'are', 'not', 'just', '<UNK>', 'little', '<UNK>', 'and', '<UNK>', '<UNK>', ',', 'but', 'people', 'who', 'do', 'things', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', 'their', 'easy', 'way', 'of', 'doing', 'things', 'but', 'i', '<UNK>', '<UNK>', 'an', '<UNK>', 'at', 'their', 'way', 'of', 'always', 'doing', 'the', 'right', 'things', '.']
# Observations after preprocessing: ['their', 'house', 'was', 'a', '<UNK>', '<UNK>', 'which', 'they', 'had', 'had', '<UNK>', '(', '<UNK>', 'by', 'an', '<UNK>', '<UNK>', ')', 'and', '<UNK>', ',', 'and', 'added', 'on', 'to', '.']
# Observations after preprocessing: ['it', 'had', 'a', '<UNK>', 'corner', '(', 'instead', 'of', 'a', '<UNK>', ')', ',', 'a', 'breakfast', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', '<UNK>', 'room', ',', 'a', 'room', 'for', 'standing', 'up', ',', 'a', '<UNK>', 'room', ',', '<UNK>', '<UNK>', 'for', '<UNK>', ',', 'even', 'a', 'room', 'for', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'all', 'set', 'up', 'so', 'there', 'would', 'be', 'no', '<UNK>', '<UNK>', 'and', 'so', 'that', 'their', '<UNK>', 'would', '<UNK>', 'in', 'the', '<UNK>', 'room', ',', '<UNK>', 'in', 'the', '<UNK>', 'room', ',', 'play', 'with', 'blocks', 'in', 'the', 'block', 'house', ',', 'and', 'do', 'all', 'the', 'other', 'things', 'in', 'the', 'proper', '<UNK>', 'at', '<UNK>', 'the', 'right', 'time', '.']
# Observations after preprocessing: ['their', 'two', '<UNK>', 'were', '``', 'well', 'adjusted', "''", 'and', ',', 'like', 'their', '<UNK>', ',', 'always', 'did', 'the', 'right', 'thing', 'at', 'the', 'right', 'time', 'and', '<UNK>', 'the', 'consequences', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'considered', 'themselves', '<UNK>', '<UNK>', 'and', 'showed', 'the', 'world', 'they', 'were', 'by', '<UNK>', 'their', '<UNK>', 'house', 'with', '<UNK>', '<UNK>', 'and', '<UNK>', 'and', 'other', 'art', '<UNK>', '(', 'expensive', ',', 'but', 'not', 'necessarily', 'valuable', ',', '<UNK>', 'things', ')', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'her', 'independence', 'by', '<UNK>', 'against', 'the', '<UNK>', 'uniform', 'of', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'by', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'in', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'and', '<UNK>', 'and', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['sometimes', '<UNK>', 'even', '<UNK>', 'the', 'uniform', 'in', 'solid', ',', '<UNK>', '<UNK>', ',', 'and', 'with', 'her', '<UNK>', '<UNK>', 'cut', 'so', 'closely', ',', '<UNK>', 'this', 'uniform', ',', '<UNK>', 'strongly', '<UNK>', 'a', 'member', 'of', 'the', '<UNK>', '.']
# Observations after preprocessing: ['no', 'one', 'could', '<UNK>', 'them', ',', 'i', 'thought', '.']
# Observations after preprocessing: ['sometimes', ',', 'though', ',', 'they', 'did', 'not', 'seem', 'quite', 'human', '.']
# Observations after preprocessing: ['it', '<UNK>', ',', 'indeed', ',', 'that', 'their', 'house', 'was', 'not', 'so', 'much', 'a', 'home', ',', 'but', 'rather', 'a', '<UNK>', 'stage', 'set', ',', 'and', 'that', 'they', 'were', '<UNK>', 'who', 'had', 'been', '<UNK>', '<UNK>', '<UNK>', 'in', 'a', 'successful', 'play', ',', 'and', 'had', '<UNK>', 'enough', 'to', '<UNK>', 'the', '<UNK>', '<UNK>', ',', 'with', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['practically', 'the', 'only', '<UNK>', 'they', 'showed', 'was', 'when', 'they', 'were', '<UNK>', '``', '<UNK>', "''", ';', ';']
# Observations after preprocessing: ['even', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['you', 'should', '<UNK>', 'the', '<UNK>', 'in', '<UNK>', 'voice', 'when', '<UNK>', 'said', '``', '<UNK>', "''", 'or', '``', '<UNK>', "''", 'or', '``', '<UNK>', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'always', 'let', 'it', 'be', 'known', 'that', 'there', 'was', '<UNK>', 'in', 'the', '<UNK>', '<UNK>', 'or', 'that', 'the', '<UNK>', 'had', 'been', '<UNK>', 'in', '<UNK>', ',', 'and', 'that', '<UNK>', 'second', '<UNK>', 'was', 'an', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'have', '<UNK>', 'time', '<UNK>', 'over', 'this', '<UNK>', 'were', 'it', 'not', 'for', 'my', '<UNK>', 'that', 'all', 'the', 'other', '<UNK>', 'of', '<UNK>', 'were', 'equally', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'feel', 'at', 'home', 'among', 'them', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', ',', 'there', 'was', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', '<UNK>', 'and', '<UNK>', ',', 'but', '<UNK>', 'was', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', '<UNK>', 'was', 'very', ',', 'very', '<UNK>', '--', 'being', 'in', 'her', 'company', 'was', 'like', 'being', '<UNK>', 'in', 'warm', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', 'had', 'once', 'been', 'a', '<UNK>', 'when', '<UNK>', 'had', '<UNK>', 'and', 'said', 'with', 'only', 'minimum', '<UNK>', ',', '``', 'oh', ',', 'my', '<UNK>', 'has', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'knows', 'how', 'a', 'real', ',', '<UNK>', '<UNK>', 'would', '<UNK>', 'to', 'such', 'a', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['if', '<UNK>', 'had', 'been', '<UNK>', ',', '<UNK>', 'would', 'have', '<UNK>', ',', '<UNK>', 'at', 'least', 'a', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'a', 'few', 'little', ',', '<UNK>', 'things', '.']
# Observations after preprocessing: ['but', '<UNK>', 'me', ',', 'no', ';', ';']
# Observations after preprocessing: ['not', '<UNK>', '.']
# Observations after preprocessing: ['after', 'five', '<UNK>', 'with', '<UNK>', ',', 'one', 'might', 'welcome', 'the', '<UNK>', 'of', '<UNK>', ',', 'who', 'was', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', 'to', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'and', '<UNK>', 'were', '<UNK>', 'committee', 'chairmen', 'and', 'they', 'usually', '<UNK>', 'to', 'be', '<UNK>', '<UNK>', ',', 'equal', '<UNK>', ',', 'of', '<UNK>', '<UNK>', 'or', 'civic', 'project', 'was', 'being', 'launched', '.']
# Observations after preprocessing: ['they', 'were', '<UNK>', ',', 'not', 'because', 'they', 'were', '<UNK>', 'of', 'each', 'other', ',', 'but', 'because', 'they', '<UNK>', 'to', 'keep', 'an', '<UNK>', 'on', 'each', 'other', ',', 'as', 'they', 'were', '<UNK>', '<UNK>', 'for', 'social', 'leadership', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'mean', ':', '<UNK>', 'mean', ',', 'and', '<UNK>', ',', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'it', 'was', 'who', 'had', '<UNK>', 'to', 'see', 'if', 'i', 'was', '<UNK>', '<UNK>', 'upon', '<UNK>', 'that', 'i', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'had', 'a', 'small', ',', '<UNK>', 'head', 'and', 'her', '<UNK>', 'and', '<UNK>', 'were', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'in', 'an', '<UNK>', 'house', 'whose', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', 'even', '<UNK>', 'were', 'chosen', 'to', '<UNK>', 'her', '<UNK>', ';', ';']
# Observations after preprocessing: ['the', '<UNK>', 'were', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['her', 'uniform', 'was', 'of', '<UNK>', ',', 'raw', '<UNK>', ',', 'in', 'a', '<UNK>', 'which', '<UNK>', 'her', '<UNK>', ',', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', ',', 'and', 'since', '<UNK>', 'was', 'so', '<UNK>', 'as', 'to', 'be', 'almost', '<UNK>', ',', '<UNK>', 'rather', '<UNK>', 'a', '<UNK>', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'of', 'these', 'women', 'and', 'others', 'i', 'had', 'met', 'in', '<UNK>', 'were', 'distinguished', 'only', 'in', 'that', 'they', 'were', ',', 'to', 'me', 'at', 'least', ',', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'tell', 'one', 'from', 'the', 'other', '.']
# Observations after preprocessing: ['like', '<UNK>', ',', 'they', 'were', 'all', 'in', 'communications', ':', 'radio', ',', '<UNK>', ',', '<UNK>', ',', 'and', 'advertising', '.']
# Observations after preprocessing: ['one', 'or', 'two', 'were', '<UNK>', 'of', 'books', ';', ';']
# Observations after preprocessing: ['all', 'were', 'fellows', 'of', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['each', 'had', 'developed', 'a', '<UNK>', '<UNK>', 'and', 'the', '<UNK>', 'of', 'saying', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['in', '<UNK>', 'to', '<UNK>', '.']
# Observations after preprocessing: ['i', 'never', 'thought', '<UNK>', 'live', 'to', '<UNK>', 'people', '<UNK>', 'and', 'say', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['in', 'real', 'life', '.']
# Observations after preprocessing: ['i', '<UNK>', 'have', '<UNK>', 'it', 'for', 'anything', '.']
# Observations after preprocessing: ['they', 'were', '``', '<UNK>', "''", '--', 'men', 'of', 'the', '<UNK>', '<UNK>', 'and', 'the', 'urgent', '<UNK>', '.']
# Observations after preprocessing: ['these', '<UNK>', '<UNK>', 'an', 'introduction', 'to', '<UNK>', 'by', '<UNK>', '<UNK>', 'one', 'of', 'his', '<UNK>', 'in', 'both', 'of', '<UNK>', ',', 'while', 'they', '<UNK>', ',', '<UNK>', 'with', 'care', ',', 'into', 'the', 'eyes', 'of', 'the', 'person', 'they', 'were', 'meeting', '.']
# Observations after preprocessing: ['could', 'such', '<UNK>', '<UNK>', ',', 'for', 'a', 'total', '<UNK>', ',', 'be', '<UNK>', '?', '?']
# Observations after preprocessing: ['they', 'were', 'always', '<UNK>', 'to', 'light', '<UNK>', ',', 'open', 'car', '<UNK>', ',', '<UNK>', '<UNK>', 'or', '<UNK>', ',', 'and', 'i', '<UNK>', 'the', 'whole', '<UNK>', 'of', 'them', 'to', 'the', 'same', 'degree', 'that', 'i', '<UNK>', '<UNK>', 'shops', 'that', 'called', 'themselves', '``', '<UNK>', '<UNK>', 'shops', "''", '.']
# Observations after preprocessing: ['``', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''", 'i', 'thought', ',', 'and', '<UNK>', 'what', 'kind', 'of', '<UNK>', 'such', '<UNK>', '<UNK>', 'would', 'establish', 'in', 'this', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'who', '<UNK>', 'like', '<UNK>', '<UNK>', 'even', 'at', '<UNK>', 'conferences', 'and', 'who', 'never', 'called', 'the', 'school', 'principal', '``', '<UNK>', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', ',', 'thinking', 'that', 'among', 'other', 'things', ',', 'people', 'here', '<UNK>', 'to', 'be', 'those', 'who', 'would', 'have', 'to', 'cut', 'down', 'if', 'they', '<UNK>', 'less', 'than', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['people', 'who', 'would', 'give', 'their', '<UNK>', 'for', 'a', '<UNK>', 'to', 'get', 'on', '``', 'person', 'to', 'person', "''", ';', ';']
# Observations after preprocessing: ['people', 'who', 'thought', 'it', 'was', '<UNK>', 'to', 'be', 'important', ',', 'but', 'not', 'important', 'to', 'be', '<UNK>', ';', ';']
# Observations after preprocessing: ['who', 'were', 'more', '<UNK>', 'than', '<UNK>', ',', 'more', '<UNK>', 'than', 'persons', '.']
# Observations after preprocessing: ['in', 'my', '<UNK>', ',', 'they', 'were', 'people', 'who', 'read', '<UNK>', 'du', '<UNK>', ',', 'and', '<UNK>', '<UNK>', ';', ';']
# Observations after preprocessing: ['well', ',', 'not', '<UNK>', 'him', '<UNK>', ',', 'but', 'said', ',', '``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'and', 'raised', 'their', 'eyes', ',', 'as', 'if', 'they', 'were', 'at', 'a', 'loss', 'to', '<UNK>', 'how', 'they', 'felt', 'about', '<UNK>', ',', 'which', 'they', 'were', ',', 'because', 'they', 'had', 'no', 'opinions', 'about', '<UNK>', ',', 'not', 'having', 'read', '<UNK>', '.']
# Observations after preprocessing: ['they', 'were', ',', 'i', 'felt', ',', 'people', '<UNK>', '<UNK>', 'to', '<UNK>', 'not', 'who', ',', 'but', 'what', 'they', 'were', ',', 'and', '<UNK>', 'to', 'determine', 'what', ',', 'not', 'who', ',', 'others', 'were', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'that', 'it', 'was', 'nearly', '<UNK>', ',', 'i', 'brought', '<UNK>', 'back', 'to', 'the', 'tasks', 'at', 'hand', '.']
# Observations after preprocessing: ['i', 'made', 'plans', 'for', 'the', '<UNK>', '--', 'doing', 'the', 'breakfast', 'and', '<UNK>', '<UNK>', 'all', 'at', 'once', ',', 'making', 'the', '<UNK>', ',', 'and', 'then', '<UNK>', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['then', ',', 'i', '<UNK>', 'that', 'the', '<UNK>', 'had', 'had', 'a', '<UNK>', 'for', '<UNK>', 'every', 'day', 'for', 'the', 'last', 'week', '.']
# Observations after preprocessing: ['``', '<UNK>', "''", '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'had', '<UNK>', 'each', 'time', '.']
# Observations after preprocessing: ['``', '<UNK>', 'not', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'not', 'even', 'food', '.']
# Observations after preprocessing: ['<UNK>', 'just', 'something', '<UNK>', '<UNK>', 'to', 'put', 'on', '<UNK>', 'for', 'breakfast', "''", '.']
# Observations after preprocessing: ['i', '<UNK>', 'around', 'and', 'found', 'a', '<UNK>', ',', 'and', 'was', 'able', 'to', '<UNK>', 'them', 'with', 'a', '<UNK>', '<UNK>', 'with', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['(', 'sometimes', 'i', 'think', 'you', 'need', 'only', 'one', 'rule', 'for', '<UNK>', ':', 'if', 'you', '<UNK>', 'put', '<UNK>', 'in', 'it', ',', 'put', '<UNK>', 'in', 'it', '.']
# Observations after preprocessing: [')']
# Observations after preprocessing: ['the', '<UNK>', 'was', 'received', 'in', 'a', '<UNK>', '<UNK>', 'that', 'was', 'evidence', 'in', 'itself', 'of', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'had', 'been', 'providing', '.']
# Observations after preprocessing: ['then', '<UNK>', '<UNK>', 'her', 'eyes', ',', '<UNK>', 'forth', 'her', 'arms', ',', 'and', 'said', ':', '``', 'take', 'my', 'hand', ',', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', 'a', '<UNK>', 'in', '<UNK>', "''", '.']
# Observations after preprocessing: ['<UNK>', 'to', 'say', ',', 'i', 'was', '<UNK>', 'at', 'this', '<UNK>', '<UNK>', 'upon', 'free', 'enterprise', '.']
# Observations after preprocessing: ['how', '<UNK>', 'they', 'demand', 'to', '``', '<UNK>', "''", 'in', 'private', 'financial', 'records', ',', '<UNK>', ',', '<UNK>', 'contracts', 'and', '<UNK>', '?', '?']
# Observations after preprocessing: ['``', 'it', 'is', 'as', 'though', "''", ',', 'i', 'said', 'on', 'the', '<UNK>', '<UNK>', ',', '<UNK>', 'radio', 'broadcast', 'which', 'i', '<UNK>', '(', 'following', 'father', '<UNK>', 'and', '<UNK>', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', 'and', 'major', '<UNK>', 'shows', ')', '``', 'that', 'man', 'in', 'the', '<UNK>', 'house', ',', 'like', 'some', '<UNK>', 'of', '<UNK>', ',', '<UNK>', 'on', 'reading', 'my', '<UNK>', ',', '<UNK>', 'my', '<UNK>', 'and', '<UNK>', 'my', '<UNK>', '<UNK>', '<UNK>']
# Observations after preprocessing: ["''", 'my', '<UNK>', '<UNK>', 'for', 'civil', 'rights', '<UNK>', 'a', '<UNK>', 'of', '<UNK>', 'and', 'one', '<UNK>', 'even', 'asked', 'me', 'to', 'consider', '<UNK>', 'the', '<UNK>', '<UNK>', '<UNK>', 'hour', 'on', 'a', 'permanent', 'basis', '.']
# Observations after preprocessing: ['but', 'what', '<UNK>', 'could', 'a', 'poor', '<UNK>', '<UNK>', 'expect', 'from', 'a', '<UNK>', 'who', 'would', 'even', 'make', 'so', '<UNK>', 'as', 'to', 'close', 'all', 'of', 'the', 'banks', 'in', 'our', 'great', 'nation', '?', '?']
# Observations after preprocessing: ['the', '<UNK>', '<UNK>', '<UNK>', 'of', '<UNK>', 'russian', 'communism', '<UNK>', 'on', 'the', '<UNK>', 'that', 'was', '<UNK>', '<UNK>', ',', '<UNK>', 'and', '<UNK>', 'with', 'their', '<UNK>', '<UNK>', '<UNK>', 'of', '``', '<UNK>', 'the', '<UNK>', "'", '<UNK>', '<UNK>']
# Observations after preprocessing: ['after', 'an', '<UNK>', '<UNK>', ',', '<UNK>', 'the', 'better', 'part', 'of', 'two', 'months', ',', 'it', 'was', 'announced', 'that', 'the', '<UNK>', '``', '<UNK>', "''", 'the', 'government', 'a', 'tax', '<UNK>', 'in', 'excess', 'of', 'eight', 'million', 'dollars', 'while', 'i', ',', 'who', 'had', 'always', '<UNK>', '<UNK>', 'from', 'such', '<UNK>', 'practices', 'as', '<UNK>', 'taxes', 'on', 'the', 'salary', 'i', 'had', '<UNK>', 'and', 'the', 'little', 'i', '<UNK>', '<UNK>', 'as', '<UNK>', '<UNK>', '<UNK>', ',', 'was', '``', '<UNK>', "''", 'with', 'a', 'personal', '<UNK>', 'of', 'such', '<UNK>', 'proportions', 'as', 'to', '``', '<UNK>', 'out', "''", 'all', 'but', 'a', '<UNK>', 'of', 'my', 'poor', ',', '<UNK>', 'savings', '.']
# Observations after preprocessing: ['i', 'was', 'also', '<UNK>', '<UNK>', ',', '<UNK>', 'through', 'the', '<UNK>', 'by', 'the', 'radical', '<UNK>', 'and', 'made', 'a', 'figure', 'of', '<UNK>', 'by', 'such', '<UNK>', 'publications', 'as', 'the', 'new', 'republic', ',', 'the', 'new', '<UNK>', ',', 'time', 'and', 'the', '<UNK>', 'science', '<UNK>', '.']
# Observations after preprocessing: ['it', 'was', 'then', 'that', 'i', '<UNK>', '<UNK>', 'of', 'the', 'rights', 'of', 'a', '<UNK>', 'and', 'declared', 'the', 'income', 'tax', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'was', '<UNK>', 'and', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['i', '<UNK>', 'like', 'a', '<UNK>', 'but', 'by', 'the', 'time', 'i', '<UNK>', 'my', 'case', 'to', 'the', '<UNK>', 'court', '(', '<UNK>', ')', ',', 'mr.', '<UNK>', 'and', 'his', '``', '<UNK>', "''", 'had', 'done', 'their', '``', '<UNK>', 'work', "''", 'all', 'too', 'well', ',', 'even', 'going', 'so', 'far', 'as', 'to', 'attempt', 'to', '``', '<UNK>', "''", 'the', 'highest', '<UNK>', 'in', 'the', 'land', 'in', 'order', 'to', '<UNK>', 'little', 'me', '.']
# ...
# Observations after preprocessing: ['the', '<UNK>', ',', '<UNK>', 'by', 'several', '<UNK>', '<UNK>', '<UNK>', 'to', 'keep', 'you', 'on', 'your', '<UNK>', ',', 'will', 'pursue', 'you', 'with', 'a', '<UNK>', '<UNK>', 'of', '<UNK>', '<UNK>', ',', 'but', 'before', 'they', 'close', 'in', ',', '<UNK>', '<UNK>', ',', 'i', '<UNK>', ',', 'for', 'a', '<UNK>', '<UNK>', 'more', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'of', 'the', '<UNK>', 'you', 'took', '<UNK>', 'properties', 'of', 'a', 'most', '<UNK>', 'and', '<UNK>', 'nature', ',', 'as', 'you', 'will', '<UNK>', 'when', 'your', '<UNK>', 'begin', 'to', '<UNK>', 'and', 'your', '<UNK>', 'falls', 'out', 'in', '<UNK>', '.']
# Observations after preprocessing: ['in', 'time', ',', 'these', 'minor', '<UNK>', 'will', 'multiply', 'and', '<UNK>', ',', '<UNK>', 'you', 'with', '<UNK>', ',', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'and', '<UNK>', '<UNK>', ',', 'until', 'your', 'very', 'existence', '<UNK>', 'a', 'burden', 'and', 'you', '<UNK>', 'out', 'for', '<UNK>', '.']
# Observations after preprocessing: ['all', 'this', ',', 'though', ',', 'is', 'simply', 'a', '<UNK>', ',', 'a', '<UNK>', ',', 'for', 'what', '<UNK>', ',', 'and', 'i', 'doubt', 'whether', 'any', '<UNK>', 'could', 'accurately', '<UNK>', 'it', '.']
# Observations after preprocessing: ['if', ',', 'however', ',', 'it', 'would', 'help', 'to', '<UNK>', 'your', '<UNK>', ',', 'i', 'can', '<UNK>', 'the', '<UNK>', 'of', 'a', 'few', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', 'the', '<UNK>', 'they', '<UNK>', 'out', 'in', 'one', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['hold', 'on', '<UNK>', '.']
# Observations after preprocessing: ['first', 'of', 'all', ',', 'the', 'six', 'figures', 'of', 'the', '<UNK>', 'you', '<UNK>', '--', 'four', '<UNK>', '<UNK>', ',', 'a', '<UNK>', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'position', ',', 'and', 'a', 'large', '<UNK>', 'figure', 'of', 'the', '<UNK>', '<UNK>', 'on', 'a', '<UNK>', 'base', '.']
# Observations after preprocessing: ['now', ',', 'you', 'probably', 'share', 'the', 'widespread', 'western', 'belief', 'that', 'the', 'lord', '<UNK>', 'is', 'the', 'most', '<UNK>', 'of', 'the', '<UNK>', ',', 'much', 'more', 'so', 'than', '<UNK>', 'and', '<UNK>', 'and', 'the', 'rest', '.']
# Observations after preprocessing: ['<UNK>', 'up', '--', '<UNK>', 'you', '?', '?']
# Observations after preprocessing: ['well', ',', '<UNK>', 'he', 'is', ',', 'except', '(', 'as', 'the', '<UNK>', 'of', 'the', 'law', '<UNK>', ')', 'toward', '<UNK>', '<UNK>', 'who', '<UNK>', ',', '<UNK>', ',', 'or', '<UNK>', 'the', '<UNK>', '.']
# Observations after preprocessing: ['very', '<UNK>', '<UNK>', 'indeed', 'seems', 'to', '<UNK>', 'such', '<UNK>', '.']
# Observations after preprocessing: ['eight', 'or', 'ten', 'years', 'ago', ',', 'a', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'a', '<UNK>', '<UNK>', 'head', 'from', 'the', '<UNK>', '<UNK>', ',', 'in', '<UNK>', ',', 'and', 'a', 'week', 'later', '<UNK>', 'into', 'the', '<UNK>', 'with', '<UNK>', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'own', 'amount', 'of', '<UNK>', '<UNK>', 'did', 'nothing', 'to', '<UNK>', 'their', '<UNK>', ';', ';']
# Observations after preprocessing: ['they', '<UNK>', '<UNK>', '<UNK>', '<UNK>', ',', '<UNK>', 'the', '<UNK>', 'one', 'to', '<UNK>', 'their', '<UNK>', '.']
# Observations after preprocessing: ['any', '<UNK>', '<UNK>', '<UNK>', 'can', 'supply', 'you', 'with', 'a', '<UNK>', 'similar', 'instances', ',', 'and', '<UNK>', 'presently', '<UNK>', 'a', 'case', 'out', 'of', 'my', 'own', 'personal', 'experience', ',', 'but', ',', 'for', 'the', '<UNK>', ',', '<UNK>', 'resume', 'our', '<UNK>', '.']
# Observations after preprocessing: ['whether', 'the', '<UNK>', 'of', '<UNK>', '<UNK>', '<UNK>', 'you', '<UNK>', '<UNK>', '<UNK>', 'the', '<UNK>', 'to', 'turn', 'your', '<UNK>', 'to', 'lead', ',', 'as', 'a', '<UNK>', 'in', '<UNK>', '<UNK>', 'me', ',', 'i', 'am', 'not', 'competent', 'to', 'say', '.']
# Observations after preprocessing: ['likewise', 'the', '<UNK>', '<UNK>', '<UNK>', 'figure', 'known', 'as', 'a', '``', '<UNK>', '<UNK>', "''", '(', '<UNK>', '<UNK>', ')', ';', ';']
# Observations after preprocessing: ['a', '<UNK>', 'of', '<UNK>', '<UNK>', 'her', 'from', 'the', '<UNK>', '<UNK>', 'for', 'inspection', 'was', '<UNK>', 'as', 'if', 'by', 'a', '<UNK>', ',', 'but', 'he', 'had', 'previously', '<UNK>', 'a', 'quantity', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', 'three', '<UNK>', '<UNK>', '<UNK>', ',', 'though', '--', '<UNK>', ',', '<UNK>', ',', 'and', '<UNK>', '--', 'are', 'an', '<UNK>', 'different', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['they', '<UNK>', 'from', '<UNK>', ',', 'a', 'state', 'in', 'the', '<UNK>', 'where', '<UNK>', ',', 'the', '<UNK>', 'of', '<UNK>', ',', 'is', '<UNK>', '.']
# Observations after preprocessing: ['have', 'you', 'ever', '<UNK>', 'of', '<UNK>', '?', '?']
# Observations after preprocessing: ['<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['but', 'it', 'is', 'the', '<UNK>', '<UNK>', 'from', '<UNK>', ',', 'the', 'one', 'representing', 'two', 'men', 'with', 'their', '<UNK>', '<UNK>', '<UNK>', 'and', 'their', '<UNK>', '<UNK>', 'by', 'a', '<UNK>', ',', 'that', 'i', 'particularly', '<UNK>', 'to', 'your', 'attention', '.']
# Observations after preprocessing: ['<UNK>', 'enough', ',', 'this', 'is', 'an', '<UNK>', 'against', '<UNK>', ',', 'presented', 'to', 'the', '<UNK>', 'and', 'me', 'by', 'a', 'local', '<UNK>', 'in', '1949', '.']
# Observations after preprocessing: ['<UNK>', 'around', 'its', 'base', 'is', 'a', '<UNK>', 'in', '<UNK>', ',', 'a', '<UNK>', 'i', 'take', 'it', 'you', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['neither', 'do', 'i', ',', 'but', 'the', '<UNK>', '<UNK>', 'was', 'good', 'enough', 'to', '<UNK>', ',', 'and', '<UNK>', 'do', 'as', 'much', 'for', 'you', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'our', '<UNK>', ',', 'the', '<UNK>', 'states', ',', 'can', 'expect', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'will', '<UNK>', 'from', 'his', '<UNK>', 'like', '<UNK>', ',', 'his', 'wife', 'will', 'make', 'him', '<UNK>', 'with', '<UNK>', ',', 'and', 'a', '<UNK>', 'car', 'will', 'grow', 'in', 'his', '<UNK>', '.']
# Observations after preprocessing: ['furthermore', '--', 'and', 'this', ',', 'to', 'me', ',', '<UNK>', 'an', 'especially', '<UNK>', 'note', '--', 'it', 'shall', '<UNK>', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'away', 'or', '<UNK>', 'of', 'their', '<UNK>', '.']
# Observations after preprocessing: ['the', '<UNK>', 'of', '<UNK>', '<UNK>', 'the', '<UNK>', 'they', '<UNK>', 'any', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'them', '<UNK>', 'the', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'of', '<UNK>', ',', '<UNK>', 'it', '?', '?']
# Observations after preprocessing: ['still', ',', 'there', 'it', 'is', '.']
# Observations after preprocessing: ['now', ',', 'you', 'no', 'doubt', 'regard', 'the', 'preceding', 'as', '<UNK>', ';', ';']
# Observations after preprocessing: ['<UNK>', '<UNK>', 'around', 'full', 'of', '<UNK>', 'in', 'your', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', 'on', '<UNK>', 'and', '<UNK>', '<UNK>', 'in', 'the', '<UNK>', 'and', 'generally', '<UNK>', 'like', '<UNK>', '.']
# Observations after preprocessing: ['in', 'that', 'case', ',', '<UNK>', 'to', 'what', '<UNK>', 'another', '<UNK>', 'who', '<UNK>', 'with', 'our', '<UNK>', '.']
# Observations after preprocessing: ['a', '<UNK>', 'of', 'years', 'back', ',', 'i', '<UNK>', 'a', '<UNK>', 'apartment', 'whose', '<UNK>', '<UNK>', 'contained', 'the', 'type', 'of', '<UNK>', 'called', 'a', '``', '<UNK>', 'turn', "''", '.']
# Observations after preprocessing: ['in', 'it', 'was', 'a', '<UNK>', '<UNK>', '<UNK>', 'i', 'had', '<UNK>', 'up', 'in', '<UNK>', ',', 'and', '<UNK>', ',', 'to', 'make', 'merit', ',', 'my', 'wife', 'and', 'i', '<UNK>', 'it', 'with', '<UNK>', 'or', '<UNK>', 'a', 'few', '<UNK>', 'in', 'its', '<UNK>', '.']
# Observations after preprocessing: ['after', 'a', 'while', ',', 'we', 'became', '<UNK>', 'that', 'the', 'money', 'was', '<UNK>', 'as', '<UNK>', 'as', 'we', '<UNK>', 'it', '.']
# Observations after preprocessing: ['our', '<UNK>', 'eventually', '<UNK>', ',', 'by', 'the', 'process', 'of', 'elimination', ',', 'on', 'a', '<UNK>', '<UNK>', ',', 'a', 'thoroughly', '<UNK>', '<UNK>', ',', 'who', 'delivered', '<UNK>', 'to', 'the', 'people', '<UNK>', '.']
# Observations after preprocessing: ['the', 'more', 'i', '<UNK>', 'into', 'this', 'young', '<UNK>', 'activities', 'and', 'character', ',', 'the', 'less', '<UNK>', 'i', 'found', 'him', '.']
# Observations after preprocessing: ['i', '<UNK>', ',', 'for', 'example', ',', 'that', 'he', 'made', 'a', 'practice', 'of', '<UNK>', 'at', '<UNK>', 'he', '<UNK>', 'and', ',', 'in', '<UNK>', ',', 'of', '<UNK>', '<UNK>', 'on', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'their', 'feet', '.']
# Observations after preprocessing: ['his', 'energy', 'was', '<UNK>', ';', ';']
# Observations after preprocessing: ['sometimes', 'he', 'would', 'be', 'up', 'before', '<UNK>', ',', '<UNK>', 'as', 'a', '<UNK>', '<UNK>', 'and', '<UNK>', '<UNK>', 'into', '<UNK>', 'to', '<UNK>', 'us', ',', 'and', 'thereafter', 'would', '<UNK>', 'to', 'the', '<UNK>', '<UNK>', 'to', '<UNK>', 'at', 'the', '<UNK>', 'and', '<UNK>', '<UNK>', '<UNK>', 'against', 'their', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'he', 'was', 'frequently', 'to', 'be', 'seen', 'at', '<UNK>', 'like', '<UNK>', '&', '<UNK>', 'or', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', 'and', '<UNK>', '``', '<UNK>', '<UNK>', '<UNK>', "''", '.']
# Observations after preprocessing: ['in', 'short', ',', 'and', 'to', '<UNK>', 'an', '<UNK>', '<UNK>', ',', '<UNK>', 'timber', '.']
# Observations after preprocessing: ['well', ',', 'the', '<UNK>', 'little', '<UNK>', '<UNK>', 'along', '<UNK>', 'animals', 'and', '<UNK>', 'who', '<UNK>', '<UNK>', ',', 'and', 'in', 'due', 'course', ',', 'as', 'was', '<UNK>', ',', '<UNK>', 'himself', '.']
# Observations after preprocessing: ['one', '<UNK>', ',', 'we', 'discovered', 'not', 'only', 'that', 'the', '<UNK>', 'were', '<UNK>', 'from', 'the', '<UNK>', 'but', 'that', 'a', '<UNK>', 'had', 'been', '<UNK>', 'out', 'in', 'its', '<UNK>', '.']
# Observations after preprocessing: ['``', 'now', '<UNK>', '<UNK>', 'it', "''", ',', 'said', 'my', 'wife', '<UNK>', '.']
# Observations after preprocessing: ['``', 'no', '<UNK>', 'will', 'hold', 'still', 'for', 'that', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', '<UNK>', 'for', 'it', "''", '.']
# Observations after preprocessing: ['and', 'how', 'right', '<UNK>', 'was', '.']
# Observations after preprocessing: ['the', 'next', 'time', 'we', '<UNK>', 'him', ',', 'he', 'was', 'a', 'changed', 'person', ';', ';']
# Observations after preprocessing: ['he', 'had', '<UNK>', '<UNK>', 'years', ',', 'and', 'his', 'face', ',', 'the', '<UNK>', 'of', '<UNK>', ',', 'was', '<UNK>', 'with', '<UNK>', ',', 'as', 'though', 'it', 'had', 'been', '<UNK>', 'in', '<UNK>', 'wire', '.']
# Observations after preprocessing: ['some', '<UNK>', 'of', '<UNK>', 'was', '<UNK>', 'his', '<UNK>', ',', 'he', '<UNK>', 'us', 'in', 'a', '<UNK>', 'voice', '--', 'either', 'an', '<UNK>', '<UNK>', 'or', '<UNK>', '<UNK>', ',', 'a', '<UNK>', ',', 'we', '<UNK>', 'determine', 'which', '.']
# Observations after preprocessing: ['his', 'eyes', 'had', 'the', 'same', '<UNK>', '<UNK>', '<UNK>', 'as', 'dr.', '<UNK>', '<UNK>', 'when', 'he', 'was', 'found', 'before', 'his', 'open', '<UNK>', '<UNK>', 'the', '<UNK>', 'band', '.']
# Observations after preprocessing: ['the', '<UNK>', 'the', '<UNK>', 'worked', 'for', 'soon', '<UNK>', 'of', 'his', '<UNK>', 'effect', 'on', '<UNK>', ',', 'most', 'of', 'whom', 'were', 'sufficiently', '<UNK>', 'without', 'the', 'threat', 'of', '<UNK>', ',', 'and', 'let', 'him', 'go', '.']
# Observations after preprocessing: ['the', '<UNK>', ',', 'the', '<UNK>', 'part', 'of', 'his', '<UNK>', ',', 'however', ',', 'was', 'the', '<UNK>', 'way', 'the', '<UNK>', '<UNK>', 'him', 'off', '.']
# Observations after preprocessing: ['reduced', 'to', '<UNK>', ',', 'he', 'at', 'last', '<UNK>', 'a', 'job', 'as', 'office', '<UNK>', 'to', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['his', '<UNK>', ',', '<UNK>', 'of', '<UNK>', ',', 'and', '<UNK>', 'carried', 'him', '<UNK>', 'to', 'the', 'top', '.']
# Observations after preprocessing: ['he', '<UNK>', 'programs', 'that', '<UNK>', 'new', '<UNK>', 'of', '<UNK>', 'and', '<UNK>', 'whole', '<UNK>', ',', 'and', 'quickly', '<UNK>', 'his', '<UNK>', '.']
# Observations after preprocessing: ['not', 'long', 'ago', ',', 'i', '<UNK>', 'down', 'with', 'him', 'in', 'an', '<UNK>', 'in', 'radio', 'city', ';', ';']
# Observations after preprocessing: ['he', 'was', '<UNK>', 'to', 'himself', '<UNK>', 'to', 'the', '<UNK>', 'and', '<UNK>', 'two', '<UNK>', 'at', 'once', ',', 'clearly', 'a', 'man', 'in', '<UNK>', '.']
# Observations after preprocessing: ['``', 'see', 'that', '<UNK>', "''", '?', '?']
# Observations after preprocessing: ['the', '<UNK>', 'asked', '<UNK>', '.']
# Observations after preprocessing: ['``', 'i', '<UNK>', 'be', 'in', 'his', '<UNK>', 'for', 'all', 'the', 'rice', 'in', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'some', 'kind', 'of', 'a', '<UNK>', '<UNK>', 'his', '<UNK>', "''", '.']
# Observations after preprocessing: ['however', 'one', 'looks', 'at', 'it', ',', 'therefore', ',', '<UNK>', 'say', 'that', 'your', '<UNK>', 'for', 'this', '<UNK>', 'is', 'the', '<UNK>', 'of', '<UNK>', '.']
# Observations after preprocessing: ['the', 'inventory', 'you', 'acquired', 'from', 'me', '<UNK>', 'going', 'to', 'be', 'easy', 'to', 'move', ';', ';']
# Observations after preprocessing: ['you', '<UNK>', 'very', 'well', '<UNK>', 'up', 'to', 'people', 'on', 'the', 'street', 'and', 'ask', 'if', 'they', 'want', 'to', 'buy', 'a', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', ',', 'since', '<UNK>', 'going', 'to', 'be', '<UNK>', 'de', '<UNK>', '<UNK>', 'soon', 'with', '<UNK>', ',', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'the', '<UNK>', '<UNK>', ',', '<UNK>', '<UNK>', ',', '<UNK>', ',', 'and', 'a', 'host', 'of', 'other', '<UNK>', 'of', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'you', '<UNK>', 'expect', 'to', 'be', '<UNK>', '<UNK>', '.']
# Observations after preprocessing: ['my', 'advice', ',', 'if', 'you', 'live', 'long', 'enough', 'to', 'continue', 'your', '<UNK>', ',', 'is', 'that', 'the', 'next', 'time', '<UNK>', '<UNK>', 'by', 'the', '<UNK>', ',', 'pass', 'it', 'up', '--', '<UNK>', 'nothing', 'but', 'a', '<UNK>', '.']
# Observations after preprocessing: ['as', 'you', 'can', '<UNK>', 'on', 'me', 'to', 'do', 'the', 'same', '.']
# Observations after preprocessing: ['<UNK>', '<UNK>', ',']
# Observations after preprocessing: ['s.', 'j.', '<UNK>']
# Observations after preprocessing: ['<UNK>', 'in', 'the', '<UNK>']
# Observations after preprocessing: ['the', '<UNK>', 'of', 'the', 'd', '<UNK>', '<UNK>', '<UNK>', ',', 'and', 'as', 'i', '<UNK>', 'into', 'a', '<UNK>', 'and', ',', '<UNK>', ',', '<UNK>', 'up', 'across', 'the', '<UNK>', ',', 'the', 'whole', '<UNK>', 'in', 'my', 'head', '<UNK>', 'into', '<UNK>', '.']
# Observations after preprocessing: ['<UNK>', 'was', 'a', 'living', '<UNK>', 'and', 'no', '<UNK>', '--', 'the', '<UNK>', '<UNK>', ',', 'the', 'wide', '<UNK>', ',', '<UNK>', ',', 'that', '<UNK>', 'the', '<UNK>', '<UNK>', 'in', 'her', '<UNK>', '<UNK>', ',', 'and', 'the', '<UNK>', 'whose', 'only', '<UNK>', ',', 'in', 'the', '<UNK>', '<UNK>', '<UNK>', ',', 'was', 'that', 'the', 'lower', '<UNK>', 'was', 'a', '<UNK>', 'too', '<UNK>', '.']
# Observations after preprocessing: ['from', 'what', 'i', 'was', 'able', 'to', '<UNK>', 'in', 'a', '<UNK>', ',', '<UNK>', '<UNK>', ',', 'the', 'figure', 'inside', 'the', '<UNK>', '<UNK>', '<UNK>', 'was', '<UNK>', '.']
# HMM (Viterbi) accuracy, universal-mapped : 0.8750
# Pretrained Perceptron, universal-mapped  : 0.9113
# Gap                                      : +0.0363

# %%
# Side-by-side bar chart of the two taggers.
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 5))
bars = plt.bar(["HMM (scratch)", "Perceptron (pretrained)"],
               [hmm_universal_acc, baseline_acc],
               color=["#b87333", "#4c4c4c"])
plt.ylabel("Token Accuracy (universal tagset)")
plt.title("HMM vs Pretrained Baseline - Humor Test Set")
plt.ylim(0, 1)
for b, v in zip(bars, [hmm_universal_acc, baseline_acc]):
    plt.text(b.get_x() + b.get_width()/2, v + 0.01, f"{v:.2%}", ha="center")
plt.show()

# %% [markdown]
# ## Cell 28 Discussion and Takeaway. Why the HMM trailed the pretrained tagger
#
# **1. Domain mismatch (the dominant factor).** Our HMM learned its emission and
# transition statistics exclusively from the *government* corpus, but is tested on
# *humor*. Word usage, sentence structure, and tag-pair frequencies differ
# substantially between the two genres, so both matrices are miscalibrated for the
# test distribution. The pretrained Perceptron tagger was trained on large,
# diverse corpora and generalises across genres.
#
# **2. Out-of-vocabulary handling.** Every unseen humor word collapses to a single
# `<UNK>` emission profile, discarding all morphological and orthographic
# evidence. The Perceptron tagger uses rich features — word suffixes, prefixes,
# capitalisation, and surrounding word identities — letting it tag novel words far
# more accurately.
#
# **3. Limited context (first-order Markov assumption).** Our bigram HMM conditions
# each tag only on the immediately preceding tag. The Perceptron tagger uses a wide
# feature window (previous two tags, neighbouring words, word shape), capturing
# longer-range dependencies the HMM structurally cannot.
#
# **4. Generative vs. discriminative modelling.** The HMM is generative and
# maximises joint likelihood under independence assumptions that real language
# violates. The Perceptron is discriminative and directly optimises tagging
# accuracy, so it makes better use of correlated, overlapping features.
#
# **5. Training-data volume.** The government category is small; MLE estimates for
# rare tags and transitions are noisy. The pretrained model benefits from orders
# of magnitude more training data.
#
# **Takeaway:** the HMM is a transparent, fully-from-scratch probabilistic baseline
# that performs respectably given its constraints, but domain shift, weak OOV
# handling, the first-order assumption, and limited features explain the gap to the
# state-of-the-art pretrained tagger.

# %% [markdown]
# ## Cell 29 Screenshot for BITS Cloud
#
# ![image.png](attachment:image.png)
